# %%
data_path_list = [
    "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/rmi_risk_validate_feedback/output_data/output_20250423-113029_part01.xlsx",
    "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/rmi_risk_validate_feedback/output_data/output_20250423-115301_part02.xlsx",
    "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/rmi_risk_validate_feedback/output_data/output_20250423-131034_part03.xlsx",
    "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/rmi_risk_validate_feedback/output_data/output_20250423-142011_part04.xlsx",
    "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/rmi_risk_validate_feedback/output_data/output_20250423-143516_part00.xlsx",
]

# %%
import os
import pandas as pd

list_df = []
for data_path in data_path_list:
    df = pd.read_excel(data_path)
    list_df.append(df)
    print(df.shape)
# Out:
# (274, 31)
# (271, 31)
# (274, 31)
# (274, 31)
# (273, 31)

# %%
merge_df = pd.concat(list_df)
merge_df.shape
# save to excel
merge_df.to_excel("merge_df.xlsx")
