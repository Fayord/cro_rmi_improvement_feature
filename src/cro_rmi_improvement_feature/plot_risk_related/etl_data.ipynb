# %%
import os
import pandas as pd

df_path = "250327_data_from_RMI_from_productionbuild_Q3-2024_label 1.xlsx"
df = pd.read_excel(df_path)
print(df.shape)
df.head()
# Out:
# (1783, 82)
#    id control_name control_owner  have_control  control_freq  \
# 0 NaN          NaN           NaN         False           NaN
# 1 NaN          NaN           NaN         False           NaN
# 2 NaN          NaN           NaN         False           NaN
# 3 NaN          NaN           NaN         False           NaN
# 4 NaN          NaN           NaN         False           NaN
#
#   control_effective_date  risk_question_id control_des control_design  \
# 0                    NaN             96383         NaN            NaN
# 1                    NaN             96318         NaN            NaN
# 2                    NaN             96321         NaN            NaN
# 3                    NaN             96299         NaN            NaN
# 4                    NaN             96300         NaN            NaN
#
#   response_type  ... mitigation_target_final_score mitigation_cost_support  \
# 0           NaN  ...                           NaN                     NaN
# 1           NaN  ...                           NaN                     NaN
# 2           NaN  ...                           NaN                     NaN
# 3           NaN  ...                           NaN                     NaN
# 4           NaN  ...                           NaN                     NaN
#
#   mitigation_other_support mitigation_target_date mitigation_plan_start_date  \
# 0                      NaN                    NaN                        NaN
# 1                      NaN                    NaN                        NaN
# 2                      NaN                    NaN                        NaN
# 3                      NaN                    NaN                        NaN
# 4                      NaN                    NaN                        NaN
#
#    mitigation_plan_end_date  mitigation_plan_processes  \
# 0                       NaN                         []
# 1                       NaN                         []
# 2                       NaN                         []
# 3                       NaN                         []
# 4                       NaN                         []
#
#    mitigation_plan_causes mitigation_plan_external_organization  \
# 0                      []                                    []
# 1                      []                                    []
# 2                      []                                    []
# 3                      []                                    []
# 4                      []                                    []
#
#   existing_control_external_organization
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 82 columns]

# %%
df2 = df.groupby(["company", "risk"], as_index=False).agg(
    {
        "risk_desc": set,
        "risk_cat": "first",
        "iscustom": set,  #'first', # risk
        "company_sector": set,
        "risk_subcat": set,
        "control_name": set,
        "control_des": set,
        "rootcause": set,
        "rootcause_desc": set,
        "process": set,
        "process_desc": set,
    }
)

# %%
print(df2.shape)
df2.head()
# Out:
# (1186, 13)
#    company                                  risk  \
# 0  ALL NOW  Ineffective IT Operations Management
# 1  ALL NOW               Negative media coverage
# 2  ALL NOW              Outsourcing inefficiency
# 3  ALL NOW                Product safety concern
# 4  ALL NOW                               Protest
#
#                                            risk_desc          risk_cat  \
# 0  {ระบบสารสนเทศ IT ไม่พร้อมรองรับการให้บริการในท...  Operational risk
# 1  {ข้อร้องเรียนจากการทำงาน การปฏิบัติที่ไม่สอดคล...    Strategic Risk
# 2  {ออลล์ นาว ใช้ Subcontractor 100% ในการให้บริก...  Operational risk
# 3  {ความปลอดภัยจากการนำรถ EV มาใช้ (การออกแบบที่เ...  Operational risk
# 4  {การร้องเรียน ประท้วง และนัดหยุดงานของพนักงานข...    Strategic Risk
#
#   iscustom company_sector  risk_subcat  \
# 0  {False}     {Services}         {IT}
# 1  {False}     {Services}     {Social}
# 2  {False}     {Services}  {Operation}
# 3  {False}     {Services}  {Operation}
# 4  {False}     {Services}  {Political}
#
#                                         control_name  \
# 0  {การพัฒนาความรู้ความสามารถของผู้พัฒนาระบบ, การ...
# 1  {การกำหนดขั้นตอนและกระบวนการติดตาม, การติดตามข...
# 2  {เพิ่มเครือข่ายผู้ประกอบการ, การบริหารจัดการต้...
# 3               {การตรวจสอบความพร้อม และสภาพรถขนส่ง}
# 4  {การกำหนดมาตรฐานการจ่ายเงิน และโครงสร้างราคา, ...
#
#                                          control_des  \
# 0  {มีการพัฒนาความรู้ความสามารถของบุคลากรและนักพั...
# 1  {มีบทลงโทษที่ชัดเจน กรณีกระทำความผิดเกี่ยวกับก...
# 2  {1. จัดทำ New Cost structure Model เพื่ออัพเดท...
# 3  {1. การตรวจสอบสภาพรถประจำวัน 2. ระบบแจ้งเตือนส...
# 4  {1. กำหนดมาตรฐานในการจ่ายเงินให้พขร. และมาตรกา...
#
#                                            rootcause  \
# 0  {['1.ความพร้อมของบุคลากรและนักพัฒนาระบบมีจำนวน...
# 1  {['1. ลูกค้า หรือพนักงานขนส่ง ได้รับการปฏิบัติ...
# 2  {['การพึ่งพาผู้รับจ้างภายนอกมากเกินไปสำหรับงาน...
# 3  {['ความไม่สมบูรณ์ของแบตเตอรี่ หรือการใช้งานที่...
# 4  {['1. พนักงานจัดส่ง มีการเปรียบเทียบการทำงานแล...
#
#                                       rootcause_desc  \
# 0  {['1.ความพร้อมของบุคลากรและนักพัฒนาระบบมีจำนวน...
# 1  {['1. ลูกค้า หรือพนักงานขนส่ง ได้รับการปฏิบัติ...
# 2  {['', '1.ราคาจ่ายค่าขนส่งที่ค่อนข้างต่ำหรือเป็...
# 3  {['ความไม่สมบูรณ์ของแบตเตอรี่ หรือการใช้งานที่...
# 4  {['1. พนักงานจัดส่ง มีการเปรียบเทียบการทำงานแล...
#
#                                              process  \
# 0       {['Transportation Management System (TMS)']}
# 1  {['Corporate Communication', 'Service', 'Trans...
# 2                                        {['Other']}
# 3                                        {['Other']}
# 4                      {['Transportation', 'Other']}
#
#                   process_desc
# 0                       {['']}
# 1               {['', '', '']}
# 2      {['Vendor Management']}
# 3   {['ปฏิบัติการโลจิสติกส์']}
# 4  {['', 'Vendor Management']}

# %%
df2.company.value_counts()
# Out:
# company
# CPCRT                                 135
# True Properties                        86
# PCG                                    71
# CPLI                                   71
# Advance AQ                             69
# True Lifestyle Retail                  65
# TIDC                                   64
# Altervim                               61
# Thana Digital Life_Game                57
# Ascend Commerce Group                  53
# W&W_BPD                                52
# CPPC                                   44
# CPMC                                   42
# Ascend Money                           39
# Freewill                               38
# KPI/KSP                                38
# Thana Digital Life_True Click Life     21
# W&W_CCTS                               20
# Advance-AHBG                           20
# Chia Tai                               19
# SLF                                    19
# W&W_IT                                 18
# W&W_DSRO                               15
# ALL NOW                                12
# True Space                             11
# CPLAND                                 10
# CPFC                                    9
# W&W_CS                                  9
# True Leasing                            8
# W&W_HR                                  4
# ECI                                     3
# W&W_CCM                                 2
# W&W_FA                                  1
# Name: count, dtype: int64

# %%
df3 = df2[df2["company"].isin(["PCG", "Advance AQ"])]
print(df3.shape)
df3.company.value_counts()
# Out:
# (140, 13)
# company
# PCG           71
# Advance AQ    69
# Name: count, dtype: int64

# %%
df3.head()
# Out:
#        company                                        risk  \
# 12  Advance AQ  After-sale service-related dissatisfaction
# 13  Advance AQ                               Air pollution
# 14  Advance AQ                Animal or insect infestation
# 15  Advance AQ     Business interruption from fire hazards
# 16  Advance AQ            Business interruption from flood
#
#                                             risk_desc          risk_cat  \
# 12  {ขั้นตอนในการเคลมสินค้า เพื่อขอชดเชย มีหลายขั้...  Operational risk
# 13                                                {-}    Strategic Risk
# 14                  {มีผลต่อคุณภาพในการจัดเก็บสินค้า}    Strategic Risk
# 15                                                {-}  Operational risk
# 16             {-, น้ำท่วมคลังสินค้า และเส้นทางขนส่ง}  Operational risk
#
#    iscustom     company_sector    risk_subcat  \
# 12  {False}  {Pharmaceuticals}    {Operation}
# 13  {False}  {Pharmaceuticals}  {Environment}
# 14  {False}  {Pharmaceuticals}  {Environment}
# 15  {False}  {Pharmaceuticals}    {Operation}
# 16  {False}  {Pharmaceuticals}    {Operation}
#
#                                          control_name  \
# 12                                              {nan}
# 13                            {การตรวจวัดสิ่งแวดล้อม}
# 14                                              {nan}
# 15          {การฝึกอบรมพนักงานความปลอดภัยจากอัคคีภัย}
# 16  {nan, แผนการปิดปฏิบัติการชั่วคราวระหว่างน้ำท่ว...
#
#                                           control_des  \
# 12                                              {nan}
# 13  {จัดให้มีการตรวจวัดค่าฝุ่นในบรรยากาศการทำงานแล...
# 14                                              {nan}
# 15         {อบรมการดับเพลิงขั้นและเข้มงวดในการทำ 5ส.}
# 16  {ติดตามการแก้ไขปัญหาน้ำท่วมกับทางนิคมอย่างใกล้...
#
#                                             rootcause  \
# 12  {['ขั้นตอนการคืนสินค้า การแลกเปลี่ยน หรือการคื...
# 13                         {['ฝุ่นจากกระบวนการผลิต']}
# 14  {['วิธีการและเทคโนโลยีการควบคุมศัตรูพืชที่ไม่เ...
# 15  {['ความประมาทหรือข้อผิดพลาดของพนักงานในการจัดก...
# 16  {['เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การ...
#
#                                        rootcause_desc  \
# 12  {['ขั้นตอนการตรวจสอบการคืนสินค้าที่มีปัญหา หลา...
# 13                         {['ฝุ่นจากกระบวนการผลิต']}
# 14                                             {['']}
# 15                                         {['', '']}
# 16  {['เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การ...
#
#                                               process  \
# 12      {['Procurement', 'Research and Development']}
# 13  {['Health, Safety, and Environment (HSE)', 'Pr...
# 14               {['Quality Assurance', 'Warehouse']}
# 15        {['Health, Safety, and Environment (HSE)']}
# 16       {['Warehouse', 'Transportation'], ['Other']}
#
#                                          process_desc
# 12  {['กระบวนการเคลมสินค้า กับ Supplier ต้องมีหลัก...
# 13                                         {['', '']}
# 14                                         {['', '']}
# 15                                             {['']}
# 16  {['การควบคุมดูแลเครื่องสูบน้ำของนิคมอุตสาหกรรม...

# %%
df3.columns
# Out:
# Index(['company', 'risk', 'risk_desc', 'risk_cat', 'iscustom',
#        'company_sector', 'risk_subcat', 'control_name', 'control_des',
#        'rootcause', 'rootcause_desc', 'process', 'process_desc'],
#       dtype='object')

# %%
select_columns = [
    "company",
    "risk_cat",
    "risk",
    "risk_desc",
    "rootcause",
    "rootcause_desc",
    "process",
    "process_desc",
]
df4 = df3[select_columns]
print(df4.shape)
df4.head()
# Out:
# (140, 8)
#        company          risk_cat                                        risk  \
# 12  Advance AQ  Operational risk  After-sale service-related dissatisfaction
# 13  Advance AQ    Strategic Risk                               Air pollution
# 14  Advance AQ    Strategic Risk                Animal or insect infestation
# 15  Advance AQ  Operational risk     Business interruption from fire hazards
# 16  Advance AQ  Operational risk            Business interruption from flood
#
#                                             risk_desc  \
# 12  {ขั้นตอนในการเคลมสินค้า เพื่อขอชดเชย มีหลายขั้...
# 13                                                {-}
# 14                  {มีผลต่อคุณภาพในการจัดเก็บสินค้า}
# 15                                                {-}
# 16             {-, น้ำท่วมคลังสินค้า และเส้นทางขนส่ง}
#
#                                             rootcause  \
# 12  {['ขั้นตอนการคืนสินค้า การแลกเปลี่ยน หรือการคื...
# 13                         {['ฝุ่นจากกระบวนการผลิต']}
# 14  {['วิธีการและเทคโนโลยีการควบคุมศัตรูพืชที่ไม่เ...
# 15  {['ความประมาทหรือข้อผิดพลาดของพนักงานในการจัดก...
# 16  {['เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การ...
#
#                                        rootcause_desc  \
# 12  {['ขั้นตอนการตรวจสอบการคืนสินค้าที่มีปัญหา หลา...
# 13                         {['ฝุ่นจากกระบวนการผลิต']}
# 14                                             {['']}
# 15                                         {['', '']}
# 16  {['เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การ...
#
#                                               process  \
# 12      {['Procurement', 'Research and Development']}
# 13  {['Health, Safety, and Environment (HSE)', 'Pr...
# 14               {['Quality Assurance', 'Warehouse']}
# 15        {['Health, Safety, and Environment (HSE)']}
# 16       {['Warehouse', 'Transportation'], ['Other']}
#
#                                          process_desc
# 12  {['กระบวนการเคลมสินค้า กับ Supplier ต้องมีหลัก...
# 13                                         {['', '']}
# 14                                         {['', '']}
# 15                                             {['']}
# 16  {['การควบคุมดูแลเครื่องสูบน้ำของนิคมอุตสาหกรรม...

# %%
# select first row of column risk_desc
cell = df4.iloc[4, 4]
# cell = df4.iloc[2, 3]
# cell = df4.iloc[3, 3]
print(type(cell))
print(cell)
import json
import traceback
from typing import Union


def list_string_to_list(list_string) -> tuple[bool, Union[list, str]]:
    is_list = False
    if ((list_string.count("'") % 2 != 0) and (list_string.count("'") != 0)) or (
        (list_string.count('"') % 2 != 0) and (list_string.count('"') != 0)
    ):

        return is_list, list_string
    # print(f"pass list_string :{type(list_string)} {list_string}")
    is_list = True
    # swap "'" to '"' and swap '"' to "'"
    list_string = list_string.replace('"', "###")
    list_string = list_string.replace("'", '"')
    list_string = list_string.replace("###", "'")
    try:
        list_cell = json.loads(list_string)
    except:
        is_list = False
        # print(f"here list_string : {list_string}")
        # print(traceback.format_exc())
        return is_list, list_string
    return is_list, list_cell


def cell_to_list(cell):
    empty_element_list = ["", "-"]
    if type(cell) == set:
        new_cell = []
        for list_string_candidate in cell:
            if list_string_candidate in empty_element_list:
                continue
            try:
                # if list_string count "'" or '"' have to be even and not 0
                # print(f"list_string_candidate : >>>{list_string_candidate}<<<")

                is_list, new_list_string_candidate = list_string_to_list(
                    list_string_candidate
                )
                # print(new_list_string_candidate == list_string_candidate)
                # print("is_list", is_list)
                # print(f"new_list_string_candidate : >>>{new_list_string_candidate}<<<")
                if is_list is False:
                    new_cell.append(new_list_string_candidate)
                    continue
                for i in new_list_string_candidate:
                    if i in empty_element_list:
                        continue

                    is_list, i = list_string_to_list(i)
                    # print(f"i : {is_list}>>>{i}<<<")
                    if is_list is False:
                        new_cell.append(i)
                        continue
                    new_cell.extend(i)

            except:
                # print(f"list_string : {list_string}")
                # print(traceback.format_exc())
                new_cell.append(list_string)
        return new_cell
    return cell


result = cell_to_list(cell)
print(cell_to_list(cell))
print(type(cell_to_list(cell)))

# print(cell_to_list(cell)[0])
# print(type(cell_to_list(cell)[0]))
# Out:
# <class 'set'>
# {"['เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การระบายน้ำล่าช้า']", "['ขาดเทคโนโลยีกันน้ำและป้องกันน้ำท่วม', 'ไม่มีแผนรับมือน้ำท่วม']"}
# ['เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การระบายน้ำล่าช้า', 'ขาดเทคโนโลยีกันน้ำและป้องกันน้ำท่วม', 'ไม่มีแผนรับมือน้ำท่วม']
# <class 'list'>

# %%
result
# Out:
# ['เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การระบายน้ำล่าช้า',
#  'ขาดเทคโนโลยีกันน้ำและป้องกันน้ำท่วม',
#  'ไม่มีแผนรับมือน้ำท่วม']

# %%
list_string = "ขั้นตอนในการเคลมสินค้า เพื่อขอชดเชย มีหลายขั้นตอน ซึ่งขึ้นอยู่แต่ละปัญหาของสินค้า"
if ((list_string.count("'") % 2 != 0) and (list_string.count("'") != 0)) or (
    (list_string.count('"') % 2 != 0) and (list_string.count('"') != 0)
):
    print("yes")

# %%
# df5 is df4 with pass each cell with cell_to_list
# convert set of list_string to list
df5 = df4.applymap(cell_to_list)
df5.head()
# Out:
# /var/folders/wr/0gwyb5t142l5ys9ymbzy5z380000gn/T/ipykernel_32207/139688506.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df5 = df4.applymap(cell_to_list)
#        company          risk_cat                                        risk  \
# 12  Advance AQ  Operational risk  After-sale service-related dissatisfaction
# 13  Advance AQ    Strategic Risk                               Air pollution
# 14  Advance AQ    Strategic Risk                Animal or insect infestation
# 15  Advance AQ  Operational risk     Business interruption from fire hazards
# 16  Advance AQ  Operational risk            Business interruption from flood
#
#                                             risk_desc  \
# 12  [ขั้นตอนในการเคลมสินค้า เพื่อขอชดเชย มีหลายขั้...
# 13                                                 []
# 14                  [มีผลต่อคุณภาพในการจัดเก็บสินค้า]
# 15                                                 []
# 16                [น้ำท่วมคลังสินค้า และเส้นทางขนส่ง]
#
#                                             rootcause  \
# 12  [ขั้นตอนการคืนสินค้า การแลกเปลี่ยน หรือการคืนเ...
# 13                             [ฝุ่นจากกระบวนการผลิต]
# 14  [วิธีการและเทคโนโลยีการควบคุมศัตรูพืชที่ไม่เหม...
# 15  [ความประมาทหรือข้อผิดพลาดของพนักงานในการจัดการ...
# 16  [เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การระ...
#
#                                        rootcause_desc  \
# 12  [ขั้นตอนการตรวจสอบการคืนสินค้าที่มีปัญหา หลายข...
# 13                             [ฝุ่นจากกระบวนการผลิต]
# 14                                                 []
# 15                                                 []
# 16  [เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การระ...
#
#                                               process  \
# 12            [Procurement, Research and Development]
# 13  [Health, Safety, and Environment (HSE), Produc...
# 14                     [Quality Assurance, Warehouse]
# 15            [Health, Safety, and Environment (HSE)]
# 16                 [Warehouse, Transportation, Other]
#
#                                          process_desc
# 12  [กระบวนการเคลมสินค้า กับ Supplier ต้องมีหลักฐา...
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16      [การควบคุมดูแลเครื่องสูบน้ำของนิคมอุตสาหกรรม]

# %%
# df6 convert list to string with join
df6 = df5.applymap(lambda x: ",".join(x) if isinstance(x, list) else x)
df6.head()
# Out:
# /var/folders/wr/0gwyb5t142l5ys9ymbzy5z380000gn/T/ipykernel_32207/3479902738.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df6 = df5.applymap(lambda x: ",".join(x) if isinstance(x, list) else x)
#        company          risk_cat                                        risk  \
# 12  Advance AQ  Operational risk  After-sale service-related dissatisfaction
# 13  Advance AQ    Strategic Risk                               Air pollution
# 14  Advance AQ    Strategic Risk                Animal or insect infestation
# 15  Advance AQ  Operational risk     Business interruption from fire hazards
# 16  Advance AQ  Operational risk            Business interruption from flood
#
#                                             risk_desc  \
# 12  ขั้นตอนในการเคลมสินค้า เพื่อขอชดเชย มีหลายขั้น...
# 13
# 14                    มีผลต่อคุณภาพในการจัดเก็บสินค้า
# 15
# 16                  น้ำท่วมคลังสินค้า และเส้นทางขนส่ง
#
#                                             rootcause  \
# 12  ขั้นตอนการคืนสินค้า การแลกเปลี่ยน หรือการคืนเง...
# 13                               ฝุ่นจากกระบวนการผลิต
# 14  วิธีการและเทคโนโลยีการควบคุมศัตรูพืชที่ไม่เหมาะสม
# 15  ความประมาทหรือข้อผิดพลาดของพนักงานในการจัดการก...
# 16  เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การระบ...
#
#                                        rootcause_desc  \
# 12  ขั้นตอนการตรวจสอบการคืนสินค้าที่มีปัญหา หลายขั...
# 13                               ฝุ่นจากกระบวนการผลิต
# 14
# 15
# 16  เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ทำให้การระบ...
#
#                                              process  \
# 12              Procurement,Research and Development
# 13  Health, Safety, and Environment (HSE),Production
# 14                       Quality Assurance,Warehouse
# 15             Health, Safety, and Environment (HSE)
# 16                    Warehouse,Transportation,Other
#
#                                          process_desc
# 12  กระบวนการเคลมสินค้า กับ Supplier ต้องมีหลักฐาน...
# 13
# 14
# 15
# 16        การควบคุมดูแลเครื่องสูบน้ำของนิคมอุตสาหกรรม

# %%
df7 = df6.copy()


# new_rootcause is 'rootcause : ' + rootcause column +\n+ 'rootcause_desc : ' rootcause_desc if it not '' empty string
# fundction to apply
def merge_rootcause(row):
    rootcause = row["rootcause"]
    rootcause_desc = row["rootcause_desc"]
    if rootcause == "" and rootcause_desc == "":
        return ""
    elif rootcause == "":
        return "rootcause_desc :" + rootcause_desc
    elif rootcause_desc == "":
        return "rootcause :" + rootcause
    else:
        return "rootcause :" + rootcause + "\n" + "rootcause_desc :" + rootcause_desc


df7["new_rootcause"] = df7.apply(merge_rootcause, axis=1)


def merge_process(row):
    process = row["process"]
    process_desc = row["process_desc"]
    if process == "" and process_desc == "":
        return ""
    elif process == "":
        return "process_desc :" + process_desc
    elif process_desc == "":
        return "process :" + process
    else:
        return "process :" + process + "\n" + "process_desc :" + process_desc


df7["new_process"] = df7.apply(merge_process, axis=1)
# remove rootcause and process column
df7.drop(
    ["rootcause", "rootcause_desc", "process", "process_desc"], axis=1, inplace=True
)
# rename new_rootcause and new_process to rootcause and process
df7.rename(
    columns={"new_rootcause": "rootcause", "new_process": "process"}, inplace=True
)
df7.head()
# Out:
#        company          risk_cat                                        risk  \
# 12  Advance AQ  Operational risk  After-sale service-related dissatisfaction
# 13  Advance AQ    Strategic Risk                               Air pollution
# 14  Advance AQ    Strategic Risk                Animal or insect infestation
# 15  Advance AQ  Operational risk     Business interruption from fire hazards
# 16  Advance AQ  Operational risk            Business interruption from flood
#
#                                             risk_desc  \
# 12  ขั้นตอนในการเคลมสินค้า เพื่อขอชดเชย มีหลายขั้น...
# 13
# 14                    มีผลต่อคุณภาพในการจัดเก็บสินค้า
# 15
# 16                  น้ำท่วมคลังสินค้า และเส้นทางขนส่ง
#
#                                             rootcause  \
# 12  rootcause :ขั้นตอนการคืนสินค้า การแลกเปลี่ยน ห...
# 13  rootcause :ฝุ่นจากกระบวนการผลิต\nrootcause_des...
# 14  rootcause :วิธีการและเทคโนโลยีการควบคุมศัตรูพื...
# 15  rootcause :ความประมาทหรือข้อผิดพลาดของพนักงานใ...
# 16  rootcause :เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ...
#
#                                               process
# 12  process :Procurement,Research and Development\...
# 13  process :Health, Safety, and Environment (HSE)...
# 14               process :Quality Assurance,Warehouse
# 15     process :Health, Safety, and Environment (HSE)
# 16  process :Warehouse,Transportation,Other\nproce...

# %%
risk_df_path = "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/plot_risk_related/20240811_ALL_risks.xlsx"
risk_df = pd.read_excel(risk_df_path, sheet_name="Risks")
selected_cols = [
    "Risk-EN",
    "Description-EN",
]
print(risk_df.columns)
risk_and_risk_desc_df = risk_df[selected_cols]
# apply strip to all columns
risk_and_risk_desc_df = risk_and_risk_desc_df.applymap(lambda x: x.strip())

risk_and_risk_desc_df.head()
# create map_dict
risk_to_desc_dict = risk_and_risk_desc_df.set_index("Risk-EN")[
    "Description-EN"
].to_dict()
len(risk_to_desc_dict)
# Out:
# Index(['#', 'Risk category', 'Risk subcategory', 'Risk-EN', 'Description-EN',
#        'Root cause-EN', 'Risk-TH', 'Description-TH', 'Root cause-TH',
#        'Grouping index'],
#       dtype='object')
# /var/folders/wr/0gwyb5t142l5ys9ymbzy5z380000gn/T/ipykernel_32207/152532629.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   risk_and_risk_desc_df = risk_and_risk_desc_df.applymap(lambda x: x.strip())
# 165

# %%
df8 = df7.copy()
# print number cell == NaN
print(df8.isnull().sum().sum())
# risk column map with risk_to_desc_dict
# apply strip to df8["risk"]
df8["risk"] = df8["risk"].str.strip()
df8["risk_desc_catalog"] = df8["risk"].map(risk_to_desc_dict)

df8.head()
# is nan in risk_desc_catalog
print(df8["risk_desc_catalog"].isnull().sum())
# fill risk_desc_catalog nan with ""
df8["risk_desc_catalog"] = df8["risk_desc_catalog"].fillna("")
df8["risk_desc_catalog"] = df8["risk_desc_catalog"].str.strip()
# print row that risk_desc_catalog is nan
df8[df8["risk_desc_catalog"].isnull()]
# concat risk_desc_catalog and risk_desc
df8["risk_desc"] = df8["risk_desc_catalog"] + " " + df8["risk_desc"]
# strip df8["risk_desc"]
df8["risk_desc"] = df8["risk_desc"].str.strip()
# remove risk_desc_catalog
df8.drop("risk_desc_catalog", axis=1, inplace=True)
all_risk_cat = risk_df["Risk category"].unique().tolist()
# check is all df8['risk_cat'] in all_risk_cat
assert all([x in all_risk_cat for x in df8["risk_cat"].unique().tolist()])
# add new data to df8 from risk_and_risk_cat_and_risk_desc_df
print(df8.shape)

new_rows = []
for index, row in risk_df.iterrows():
    risk_cat = row["Risk category"]
    risk_desc = row["Description-EN"]
    risk_name = row["Risk-EN"]
    risk_rootcause = row["Root cause-EN"]
    data = {
        # company	risk_cat	risk	risk_desc	rootcause	process
        "company": "risk_catalog",
        "risk_cat": risk_cat,
        "risk": risk_name,
        "risk_desc": risk_desc,
        "rootcause": risk_rootcause,
        "process": "",
    }
    new_rows.append(data)
df8 = pd.concat([df8, pd.DataFrame(new_rows)], ignore_index=True)
print(df8.shape)
print("nan", df8.isnull().sum().sum())

df8.head()
# Out:
# 0
# 5
# (140, 6)
# (305, 6)
# nan 0
#       company          risk_cat                                        risk  \
# 0  Advance AQ  Operational risk  After-sale service-related dissatisfaction
# 1  Advance AQ    Strategic Risk                               Air pollution
# 2  Advance AQ    Strategic Risk                Animal or insect infestation
# 3  Advance AQ  Operational risk     Business interruption from fire hazards
# 4  Advance AQ  Operational risk            Business interruption from flood
#
#                                            risk_desc  \
# 0  The risk of customers experiencing dissatisfac...
# 1  The presence of harmful substances in the air ...
# 2  Risk of the invasion and proliferation of pest...
# 3  The business interruption due to a fire incide...
# 4  The business interruption due to flooding in t...
#
#                                            rootcause  \
# 0  rootcause :ขั้นตอนการคืนสินค้า การแลกเปลี่ยน ห...
# 1  rootcause :ฝุ่นจากกระบวนการผลิต\nrootcause_des...
# 2  rootcause :วิธีการและเทคโนโลยีการควบคุมศัตรูพื...
# 3  rootcause :ความประมาทหรือข้อผิดพลาดของพนักงานใ...
# 4  rootcause :เครื่องสูบน้ำของนิคมชำรุดบ่อยครั้ง ...
#
#                                              process
# 0  process :Procurement,Research and Development\...
# 1  process :Health, Safety, and Environment (HSE)...
# 2               process :Quality Assurance,Warehouse
# 3     process :Health, Safety, and Environment (HSE)
# 4  process :Warehouse,Transportation,Other\nproce...

# %%
df_final = df8.copy()

# %%
# convert df6:dataframe to data_dict
result_list = df_final.to_dict(orient="records")
result_list[:3]
# Out:
# [{'company': 'Advance AQ',
#   'risk_cat': 'Operational risk',
#   'risk': 'After-sale service-related dissatisfaction',
#   'risk_desc': 'The risk of customers experiencing dissatisfaction with the post-purchase support, assistance, or follow-up provided by the organization, leading to negative perceptions, reviews, or repurchase behavior. ขั้นตอนในการเคลมสินค้า เพื่อขอชดเชย มีหลายขั้นตอน ซึ่งขึ้นอยู่แต่ละปัญหาของสินค้า',
#   'rootcause': 'rootcause :ขั้นตอนการคืนสินค้า การแลกเปลี่ยน หรือการคืนเงินที่ซับซ้อน ยืดเยื้อ หรือไม่มีประสิทธิภาพ ส่งผลกระทบต่อความสามารถของลูกค้าในการหาทางแก้ไขปัญหาที่เกี่ยวข้องกับผลิตภัณฑ์\nrootcause_desc :ขั้นตอนการตรวจสอบการคืนสินค้าที่มีปัญหา หลายขั้นตอน และใช้เวลานาน',
#   'process': 'process :Procurement,Research and Development\nprocess_desc :กระบวนการเคลมสินค้า กับ Supplier ต้องมีหลักฐานเอกสารประกอบ,ต้องทำการตรวจสอบจากหน่วยงาน R&D ก่อน'},
#  {'company': 'Advance AQ',
#   'risk_cat': 'Strategic Risk',
#   'risk': 'Air pollution',
#   'risk_desc': 'The presence of harmful substances in the air that can adversely affect health, environment, and quality of life.',
#   'rootcause': 'rootcause :ฝุ่นจากกระบวนการผลิต\nrootcause_desc :ฝุ่นจากกระบวนการผลิต',
#   'process': 'process :Health, Safety, and Environment (HSE),Production'},
#  {'company': 'Advance AQ',
#   'risk_cat': 'Strategic Risk',
#   'risk': 'Animal or insect infestation',
#   'risk_desc': 'Risk of the invasion and proliferation of pests, such as rodents, insects, or other animals, in homes, businesses, or agricultural settings. มีผลต่อคุณภาพในการจัดเก็บสินค้า',
#   'rootcause': 'rootcause :วิธีการและเทคโนโลยีการควบคุมศัตรูพืชที่ไม่เหมาะสม',
#   'process': 'process :Quality Assurance,Warehouse'}]

# %%
# save it as json
import os

dir_path = os.getcwd()
save_file_path = f"{dir_path}/company_risk_data.json"
# save result_list as json
import json

with open(save_file_path, "w") as f:
    json.dump(result_list, f, ensure_ascii=False)
