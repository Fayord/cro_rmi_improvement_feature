# %%
import pandas as pd
import pickle

# load exists_data
relation_df_dict = {}
# for company, df in result_dict.items():
company = "risk_catalog-250528"
# load f"relation_df_{company}.pkl"s
print(f"company: {company}")
relation_df = pickle.load(open(f"relation_df_{company}.pkl", "rb"))
relation_df_dict[company] = relation_df
# if source_risk ='Intense market competition'
if "Intense market competition" in relation_df["source_risk"].values:
    display(relation_df[relation_df["source_risk"] == "Intense market competition"])
# relation_df.info()
# Out:
# company: risk_catalog-250528
#                     source_risk  \
# 768  Intense market competition
# 769  Intense market competition
# 770  Intense market competition
# 771  Intense market competition
# 772  Intense market competition
# 773  Intense market competition
# 774  Intense market competition
# 775  Intense market competition
# 776  Intense market competition
#
#                                          target_risk direction  \
# 768                   New competitor into the market   [1, -1]
# 769                               Product substitute    [1, 0]
# 770                            Uncompetitive service   [-1, 0]
# 771                           Customer concentration    [1, 0]
# 772   Uncompetitive e-commerce distribution channels   [-1, 0]
# 773  Uncompetitive traditional distribution channels   [-1, 0]
# 774                Geopolitical conflicts (US-China)   [-1, 0]
# 775                      Inappropriate price setting    [1, 0]
# 776     Low in consumer ability and purchasing power   [-1, 0]
#
#                                       ori_relationship  \
# 768                           be_a_cause_to_each_other
# 769                          be_a_caused_by_each_other
# 770  Intense market competition_caused_by_Uncompeti...
# 771                          be_a_caused_by_each_other
# 772  Intense market competition_caused_by_Uncompeti...
# 773  Intense market competition_caused_by_Uncompeti...
# 774  Intense market competition_caused_by_Geopoliti...
# 775                          be_a_caused_by_each_other
# 776  Intense market competition_caused_by_Low in co...
#
#                                                 reason  \
# 768  Both risks influence each other, as intense ma...
# 769  Intense market competition can lead to the eme...
# 770  Uncompetitive service can lead to a loss of cu...
# 771  Both risks influence each other, as intense ma...
# 772  Intense market competition can lead to uncompe...
# 773  Uncompetitive traditional distribution channel...
# 774  Geopolitical conflicts can lead to trade restr...
# 775  Both risks influence each other, as inappropri...
# 776  Low consumer ability and purchasing power lead...
#
#                  relationship
# 768  be_a_cause_to_each_other
# 769         cause_then_effect
# 770         effect_then_cause
# 771         cause_then_effect
# 772         effect_then_cause
# 773         effect_then_cause
# 774         effect_then_cause
# 775         cause_then_effect
# 776         effect_then_cause

# %%
# find rows where source_risk or target_risk is Poor product quality
selected_relation_df = relation_df[
    (relation_df["source_risk"] == "Poor product quality")
    | (relation_df["target_risk"] == "Poor product quality")
]
print(selected_relation_df.shape)
selected_relation_df
# Out:
# (18, 6)
#                                     source_risk  \
# 6                               Supply shortage
# 10                          Poor supply quality
# 40                   Machinery / equipment loss
# 70                         Poor product quality
# 71                         Poor product quality
# 72                         Poor product quality
# 73                         Poor product quality
# 74                         Poor product quality
# 75                         Poor product quality
# 76                         Poor product quality
# 77                         Poor product quality
# 78                         Poor product quality
# 106                   Product development delay
# 139                 Inappropriate price setting
# 194                     Understocking inventory
# 271  After-sale service-related dissatisfaction
# 279                              Customer churn
# 370                    Low employee performance
#
#                          target_risk direction  \
# 6               Poor product quality   [-1, 0]
# 10              Poor product quality    [1, 0]
# 40              Poor product quality   [-1, 0]
# 70              Poor service quality    [1, 0]
# 71            Product safety concern   [-1, 0]
# 72   Product-related dissatisfaction    [1, 0]
# 73                    Wrong delivery    [0, 0]
# 74        Product & Service Failures   [1, -1]
# 75   Service-related dissatisfaction   [-1, 0]
# 76       Product development failure    [1, 0]
# 77             Uncompetitive product    [1, 0]
# 78             Uncompetitive service   [-1, 0]
# 106             Poor product quality   [1, -1]
# 139             Poor product quality    [1, 0]
# 194             Poor product quality   [-1, 0]
# 271             Poor product quality   [-1, 0]
# 279             Poor product quality   [-1, 0]
# 370             Poor product quality    [1, 0]
#
#                                       ori_relationship  \
# 6       Supply shortage_caused_by_Poor product quality
# 10                           be_a_caused_by_each_other
# 40   Machinery / equipment loss_caused_by_Poor prod...
# 70                           be_a_caused_by_each_other
# 71   Poor product quality_caused_by_Product safety ...
# 72   Product-related dissatisfaction_caused_by_Poor...
# 73                                     no_relationship
# 74                            be_a_cause_to_each_other
# 75   Poor product quality_caused_by_Service-related...
# 76   Product development failure_caused_by_Poor pro...
# 77                           be_a_caused_by_each_other
# 78   Poor product quality_caused_by_Uncompetitive s...
# 106                           be_a_cause_to_each_other
# 139  Poor product quality_caused_by_Inappropriate p...
# 194  Understocking inventory_caused_by_Poor product...
# 271  After-sale service-related dissatisfaction_cau...
# 279      Customer churn_caused_by_Poor product quality
# 370                          be_a_caused_by_each_other
#
#                                                 reason  \
# 6    Supply shortages can lead to the use of substa...
# 10   Poor supply quality can lead to poor product q...
# 40   Poor product quality can lead to machinery or ...
# 70   Both poor product quality and poor service qua...
# 71   Poor product quality can lead to product safet...
# 72   Poor product quality directly leads to product...
# 73   Poor product quality and wrong delivery are di...
# 74   Both Poor product quality and Product & Servic...
# 75   Poor product quality can lead to service-relat...
# 76   Poor product quality can lead to product devel...
# 77   Uncompetitive products can lead to poor produc...
# 78   Poor product quality can lead to uncompetitive...
# 106  Both risks influence each other, as delays can...
# 139  Inappropriate price setting can lead to cost-c...
# 194  Understocking inventory can lead to poor produ...
# 271  Poor product quality leads to customer dissati...
# 279  Poor product quality leads to customer dissati...
# 370  Both risks influence each other, as low employ...
#
#                  relationship
# 6           effect_then_cause
# 10          cause_then_effect
# 40          effect_then_cause
# 70          cause_then_effect
# 71          effect_then_cause
# 72          cause_then_effect
# 73            no_relationship
# 74   be_a_cause_to_each_other
# 75          effect_then_cause
# 76          cause_then_effect
# 77          cause_then_effect
# 78          effect_then_cause
# 106  be_a_cause_to_each_other
# 139         cause_then_effect
# 194         effect_then_cause
# 271         effect_then_cause
# 279         effect_then_cause
# 370         cause_then_effect

# %%
import pandas as pd
import pickle

# import re
from langchain_community.cache import SQLiteCache
from langchain.globals import set_llm_cache

set_llm_cache(SQLiteCache(database_path=".langchain.db"))
file_name = "merge-company_risk_data_with_embedding"
# file_name = "250528-company_risk_data_with_embedding"
snapshot_file_path = f"result/{file_name}-10percent_edges.pkl"
snapshot_data_list = pickle.load(open(snapshot_file_path, "rb"))
real_data_path = f"result/{file_name}.pkl"
raw_risk_data = pickle.load(open(real_data_path, "rb"))
company = "PCG"
print(len(snapshot_data_list))
snapshot_data_list[:3]
# Out:
# 303
# [{'data': {'id': 'risk_PCG_0',
#    'label': 'Accounting errors',
#    'raw_size': np.float64(5408.358040415423),
#    'size_level': 1,
#    'size': 1,
#    'color': 'rgb(54, 162, 235)',
#    'risk_level': 1,
#    'story': ''},
#   'position': {'x': 304.85011934462636, 'y': 322.70451602321697}},
#  {'data': {'id': 'risk_PCG_1',
#    'label': 'Business interruption from fire hazards',
#    'raw_size': np.float64(5949.1581742316075),
#    'size_level': 2,
#    'size': 50,
#    'color': 'rgb(54, 162, 235)',
#    'risk_level': 2,
#    'story': 'A fire incident within the workplace can lead to significant business interruptions, resulting in damage to property and equipment, which may halt operations temporarily or permanently. This risk is primarily driven by negligence in handling flammable materials, inadequate fire safety training, and insufficient maintenance of fire safety equipment. Without a robust fire emergency response plan and effective communication procedures, the likelihood of such incidents increases, ultimately leading to reduced operational efficiency and financial losses for the business.'},
#   'position': {'x': 329.5280127430215, 'y': 519.1298510032696}},
#  {'data': {'id': 'risk_PCG_2',
#    'label': 'Business interruption from flood',
#    'raw_size': np.float64(5818.718664538319),
#    'size_level': 1,
#    'size': 50,
#    'color': 'rgb(54, 162, 235)',
#    'risk_level': 1,
#    'story': ''},
#   'position': {'x': 173.91668789943057, 'y': 294.0906010086348}}]

# %% [markdown]
# compare 4o-mini, 4.1-mini, o3-mini.

# %%
from collections import Counter


def get_risk_data_from_risk_name(risk_name, risk_data_list):
    for risk in risk_data_list:
        if risk["risk"] == risk_name:
            return risk
    return None


interested_risk_name_list = [
    "Intense market competition",
    "New competitor into the market",
    "Product substitute",
    "Uncompetitive service",
]
raw_risk_selected_keys = ["risk", "risk_desc", "rootcause", "process"]
raw_risk_selected_data_list = []
selected_raw_risk_data = [i for i in raw_risk_data if i["company"] == company]
for i in selected_raw_risk_data:
    raw_risk_selected_data_list.append({k: i[k] for k in raw_risk_selected_keys})
node_data_list = []
edge_data_list = []
for node_edge in snapshot_data_list:
    if node_edge["data"].get("source") is not None:
        # it a edge
        # edge_company = node_edge["data"]["source"].split("_")[1]
        # if edge_company != "PCG":
        #     continue
        source_risk_name = node_edge["data"]["source_risk_data"]["risk"]
        target_risk_name = node_edge["data"]["target_risk_data"]["risk"]
        if (
            source_risk_name in interested_risk_name_list
            or target_risk_name in interested_risk_name_list
        ):
            # print(source_risk_name, target_risk_name)
            edge_data_list.append(node_edge["data"])
    else:
        node_data_list.append(node_edge["data"])
print(len(edge_data_list))
# Out:
# 18

# %%
edge_data_list
# Out:
# [{'source': 'risk_PCG_24',
#   'target': 'risk_PCG_32',
#   'weight': 6,
#   'raw_weight': np.float64(138.70816818505583),
#   'color': 'rgb(128, 128, 128)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Intense market competition',
#    'risk_desc': 'A highly competitive market environment where businesses within the same industry are fiercely competing for customers and market share, potentially leading to decreased profitability and market share. ตลาดอาหารสุนัขมีการเติบโตอย่างต่อเนื่อง มีสินค้าใหม่และ Brand ใหม่เกิดขึ้นในตลาดจำนวนมาก และหลายแบรนด์หลายบริษัทมีการทำการตลาดเชิงรุก หรืออาจจะมีการใช้กลยุทธการขายสินค้าราคาถูกมากในกลุ่มสินค้าที่ price sensitive เพื่อแย่งลูกค้าและส่วนแบ่งทางการตลาด ส่งผลให้ทาง PCG อาจจะไม่สามารถทำยอดขาย อัตราการเติบโต รวมถึงส่วนแบ่งตลาด ได้ตามที่วางแผนไว้,สถานการณ์ที่ธุรกิจต่างๆในอุตสาหกรรมเดียวกันมีการแข่งขันที่รุนแรง ซึ่งอาจส่งผลกระทบต่อกำไรและส่วนแบ่งตลาด,ความเสี่ยงจากการแข่งขันในตลาดบนช่องทางออนไลน์และอีคอมเมิร์ซ การแข่งขันที่รุนแรงจากแบรนด์เดิมและคู่แข่งรายใหม่ อาจส่งผลต่อยอดขายและการรักษาฐานลูกค้า,ตลาดอาหารสัตว์เลี้ยงมีอัตราการเติบโตต่อเนื่องทุกปี  ทำให้เป็นแรงจูงใจให้ผู้ผลิตและผู้จัดจำหน่ายสินค้ากลุ่มอื่นๆ ทั้งรายเก่ามีการขยายธุรกิจมากขึ้น และรายใหม่ๆเข้ามาในธุรกิจนี้มากขึ้นด้วย,ขาดกิจกรรมที่ตอบสนองต่อความต้องการของลูกค้า,มีคู่แข่งรายใหม่เข้าสู่ตลาดหรือคู่แข่งเดิมใช้กลยุทธ์การตลาดเชิงรุก ส่งผลให้ยอดขายไม่เป็นไปตามเป้าหมาย',
#    'risk_level': 4,
#    'risk_cat': 'Strategic Risk',
#    'process': 'process :Marketing and Sales: จัดโปรโมชั่นพิเศษเฉพาะงาน,Research and Development: พัฒณาสูตรให้มีคุณภาพดีเท่าเดิม แต่สามารถลดต้นทุน RM ได้, Production: ผลิตได้มีประสิทธิภาพ สามารถลดต้นทุนการผลิตได้, Marketing and Sales: จัดรายการส่งเสริมการขายให้สามารถแข่งขันและกันคู่แข่งในตลาดโดยเฉพาะรายใหม่ที่เข้ามา และ\nจะต้องพัฒนาและออกผลิตภัณฑ์ใหม่ให้ได้ตามแผนที่วางไว้,Planning: ต้องใช้ข้อมูลด้านการตลาดและพฤติกรรมของลูกค้าเพื่อวางแผนทางการตลาดและกำหนดกลุ่มเป้าหมาย รวมถึงการใช้สื่อโฆษณาต่างๆให้เข้าถึงเป้าหมายที่ตรงกลุ่มชัดเจน วิเคราะห์กลยุทธ์ทางการตลาดและผลักดันให้ทันกับการแข่งขันในตลาดที่สูงในปัจจุบัน โดยเฉพาะบนช่องทางอีคอมเมิร์ซ  รวมถึงการประเมิณจัดสรรค่าใช้จ่าย ทั้งค่าโฆษณาและค่าใช้จ่ายอื่นๆ ให้อยู่ในความคุ้มค่าสูงสุดตามงบประมาณที่วางแผนไว้, Marketing and Sales: บริหารงานขาย ด้านราคาสินค้า , โปรโมชั่น และค่าใช้จ่ายๆ ต่างให้ตอบโจทย์และคุ้มค่ามากที่สุดจากการวัดที่ผลลัพธ์ โดยเปรียบเทียบกลยุทธ์เพิ่มเติมกับคู่แข่งในตลาด โฟกัสเป้าหมายและการเติบโตของช่องทางการขายในแต่ละแพลตฟอร์ม,Procurement: จัดซื้อสินค้าและวัตถุดิบที่ได้ต้นทุนที่แข่งขันได้, Quality Assurance: มี QA ตรวจสอบคุณภาพสินค้าก่อนออกสู่ตลาด, Planning: วางแผนเพื่อเตรียมให้สินค้าพร้อมในการขาย, Finance and Accounting: สนับสนุนข้อมูลด้านต้นทุนสินค้า และ P&L ได้ถูกต้องและรวดเร็ว, Marketing and Sales: เป็นหน่วยงานหลักในการวางแผนกลยุทธ์เพื่อแข่งขันได้, After Sale Service: การบริการหลังการขายเพื่อสร้างความพอใจให้ลูกค้า, Research and Development: พัฒนาสินค้าที่มีคุณภาพและแข่งขันได้, Warehouse: เก็บสินค้าที่เพียงพอและพร้อมในการขาย, Information Technology (IT): สนับสนุนพัฒนาระบบในการทำงานได้คล่องตัว สะดวก รวดเร็ว, Production: ผลิตสินค้าที่มีคุณภาพและเพียงพอกับความต้องการขาย, Transportation: จัดส่งสินค้าที่มีคุณภาพ รวดเร็ว ไม่ชำรุดเสียหาย,Research and Development: การพํฒนาสินค้าที่มีคุณภาพและตอบโจทย์ความต้องการของตลาดในต้นทุนที่สามารถแข่งขันได้, Production: การผลิตสินค้าที่มีคุณภาพ ด้วยเทคโนโลยีที่ทันสมัย สามารถผลิตสินค้าที่ตอบโจทย์ความต้องการของตลาดได้, Marketing and Sales: การวางกลยุทธการตลาดและการขายเชิงรุก เข้าถึงผู้บริโภคได้อย่างทั่วถึงและทุก touch point  ,Information Technology (IT): เครื่องมือเทคโนโลยี่ที่ทันสมัยช่วยสนับสนุนการทำงานทั้งด้านข้อมูล ความถูกต้อง สะดวก และทันต่อสถานการณ์, Research and Development: R&D มีความจำเป็นด้านพัฒนาสินค้าให้ตรงตามความต้องการของตลาด, Business Development: เทรนด์ตลาดมีการเปลี่ยนแปลงตลอด กระบวนการจัดการควรต้องมีการพัฒนาให้สอดคล้องกับตลาด, Planning: การวางแผนผลิต วางแผนกลยุทธ์ และวางแผนการทำงานทุกขั้นตอน มีความจำเป็นอย่างยิ่ง และสามารถปรับแผนการทำงานให้สอดคล้องกับตลาดได้, Production: ผลิตสินค้าคุณภาพให้เพียงพอและทันเวลากับความต้องการการขา, Quality Assurance: เป็นสิ่งสำคัญกับการสร้างความมั่นใจให้ลูกค้าและผู้บริโภค, Warehouse: คลังสินค้ามีพื้นที่เพียงพอในการเก็บสต้อคให้พร้อมกับการขาย และการจัดเก็บสินค้าที่ถูกต้อง มีการ FIFO และดูแลคุณภาพสินค้า, Distribution Center (DC): ช่วยให้การกระจายจัดส่งสินค้าได้ทันเวลา, Transportation: การขนส่งที่รวดเร็ว สินค้าไม่เกิดชำรุดเสียหาย, Marketing and Sales: หน่วยงานหลักของการวางกลยุทธ์เพื่อการขายและกระจายสินค้าเข้าสู่ตลาด, After Sale Service: สร้างความมั่นใจเชื่อมั่นให้ผู้บริโภค',
#    'rootcause': 'rootcause :High number of competitors in the market: ธุรกิจอาหารสัตว์เลี้ยงเติบโตมากอย่างต่อเนื่องทำให้ผู้ผลิตอาหารอื่นๆเข้ามาในตลาดนี้มากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยที่มีต้นทุนต่ำได้เปรียบในการแข่นขันด้านราคา,High number of competitors in the market: ตลาดอาหารแมวในประเทศไทยเติบโตอย่างต่อเนื่อง มีคู่แข่งเข้ามาในตลาดจำนวนมากทั้งอาหารเม็ดและอาหารเปียก , Aggressive pricing strategies: คู่แข่งใช้กลยุทธ์ราคาถูกในการเข้าตลาด ได้แก่ สินค้าเป็นกลุ่มที่ดูเรื่อง Product benefits เป็นกลุ่ม Premium ตั้งราคาเท่ากลุ่ม Standard ให้ดูว่าจับต้องได้ง่าย หรือตลาดล่างที่เติบโตมาขึ้น ก็มีการเข้าตลาดด้วยการใช้กลยุทธ์ทำราคาถูกเช่นกัน,Aggressive pricing strategies: ราคาหรือโปรโมชั่นที่จำหน่ายในงานกิจกรรมต่างๆ สู้คู่แข่งขันไม่ได้,High number of competitors in the market: การแข่งขันที่รุนแรงจากจำนวนคู่แข่งที่เพิ่มขึ้นอาจส่งผลให้สูญเสียลูกค้า รายได้ และส่วนแบ่งทางการตลาด, Aggressive pricing strategies: การลดราคาหนักในตลาด รวมถึงการส่งสินค้าฟรี และมีโปรโมชั่นพิเศษอย่างต่อเนื่อง,High number of competitors in the market: ผู้ผลิตทั้ง Branded & OEM มีจำนวนมากขึ้น และมีการนำเข้าสินค้าจากต่างประเทศมากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยและบริษัทที่ทำธุรกิจจ้างผลิตที่มีต้นทุนการผลิตต่ำได้เปรียบในการแข่งขันด้านราคา, Other: กำลังซื้อของผู้บริโภคลดลง และการตัดสินใจซื้อยากขึ้น,High number of competitors in the market: จำนวนคู่แข่งในตลาดมีจำนวนมากทั้งในส่วนของจำนวน Manufacturer และจำนวน Brand , Aggressive pricing strategies: หลาย Brand ในตลาดกลุ่ม Economy และ Super Economy ใช้กลยุทธการแข่งขันด้านราคาเป็นหลัก ซึ่งทาง PCG อาจจะไม่สามารถแข่งขันโดยการใช้กลุยุทธการทำราคาถูกมากได้ , Other: คู่แข่งมีการทำตลาดอย่างเข้มข้นมากขึ้นทั้งส่วนของการใช้ Media การทำโปรโมชั่น และกิจกรรมต่างๆ ที่เข้าถึงผู้บริโภค รวมถึงใช้กลยุทธการตัดราคาในสินค้ากลุ่มที่ price sensitive'},
#   'target_risk_data': {'risk': 'New competitor into the market',
#    'risk_desc': 'The entry of new competitors can saturate the market, driving down prices and increasing competition. This challenges existing businesses to maintain their market position. การเข้ามาขอคู่แข่งในตลาดอาหารแมวทั้งชนิดเปียก และแห้ง ทำให้เกิดการแข่งขันทั้งคุณภาพและราคา มีผลกระทบกับยอดขายสินค้าและตำแหน่งในตลาดของผลิตภัณฑ์ของบริษัท,ตลาดอาหารสุนัขมีการเติบโตอย่างต่อเนื่อง ส่งผลให้มีคู่แข่งใหม่เข้าสู่ตลาดจำนวนมากทั้งคู่แข่งในประเทศและคู่แข่งจากต่างประเทศ ส่งผลให้มีการแข่งขันในตลาดสูงขึ้น และมีผู้เล่นที่มา share ยอดขายและ market share ในตลาดมากขึ้นด้วย รวมถึงคู่แข่งใหม่สามารถทำสินค้าที่มีคุณภาพดีแต่ขายในราคาที่ไม่แพงมาก จึงได้รับความสนใจจากผู้บริโภคได้ง่าย และขายได้ดี ดังนั้นอาจทำให้บริษัทฯ ไม่สามารถทำยอดขายหรืออัตราการเติบโตได้ตามเป้าหมายที่กำหนดไว้,ตลาดอาหารปลาคาร์พ  กระต่าย  นกแก้วและนกสวยงาม มักจะมีสินค้าใหม่เข้าสู่ตลาด ทั้งสินค้าที่ผลิตในประเทศและนำเข้าจากต่างประเทศ ซึ่งตลาดของผลิตภัณฑ์ดังกล่าวจะเป็นสินค้าเฉพาะกลุ่มอยู่แล้ว  และยิ่งมีแบรนด์ใหม่เข้ามาเพิ่ม จึงส่งผลให้กลยุทธ์การทำตลาดจะเน้นไปในเรื่องของกิจกรรมส่งเสริมการขาย เช่น จัด promotion ราคาพิเศษ หรือการแย่งชิงลูกค้ารายใหญ่เช่น การเข้าฟาร์ม หรือพื้นที่ดิสเพลย์ใน pet shop เป็นต้น   ดังนั้นหากไม่วางกลยุทธ์ที่สามารถกันคู่แข่งรายใหม่เหล่านี้ได้ ก็จะทำให้ส่งผลกระทบต่อยอดขาย และส่วนแบ่งการตลาดที่ลดลง',
#    'risk_level': 2,
#    'risk_cat': 'Strategic Risk',
#    'process': 'process :Marketing and Sales: จัดโปรโมชั่นพิเศษเฉพาะงาน,Research and Development: พัฒณาสูตรให้มีคุณภาพดีเท่าเดิม แต่สามารถลดต้นทุน RM ได้, Production: ผลิตได้มีประสิทธิภาพ สามารถลดต้นทุนการผลิตได้, Marketing and Sales: จัดรายการส่งเสริมการขายให้สามารถแข่งขันและกันคู่แข่งในตลาดโดยเฉพาะรายใหม่ที่เข้ามา และ\nจะต้องพัฒนาและออกผลิตภัณฑ์ใหม่ให้ได้ตามแผนที่วางไว้,Planning: ต้องใช้ข้อมูลด้านการตลาดและพฤติกรรมของลูกค้าเพื่อวางแผนทางการตลาดและกำหนดกลุ่มเป้าหมาย รวมถึงการใช้สื่อโฆษณาต่างๆให้เข้าถึงเป้าหมายที่ตรงกลุ่มชัดเจน วิเคราะห์กลยุทธ์ทางการตลาดและผลักดันให้ทันกับการแข่งขันในตลาดที่สูงในปัจจุบัน โดยเฉพาะบนช่องทางอีคอมเมิร์ซ  รวมถึงการประเมิณจัดสรรค่าใช้จ่าย ทั้งค่าโฆษณาและค่าใช้จ่ายอื่นๆ ให้อยู่ในความคุ้มค่าสูงสุดตามงบประมาณที่วางแผนไว้, Marketing and Sales: บริหารงานขาย ด้านราคาสินค้า , โปรโมชั่น และค่าใช้จ่ายๆ ต่างให้ตอบโจทย์และคุ้มค่ามากที่สุดจากการวัดที่ผลลัพธ์ โดยเปรียบเทียบกลยุทธ์เพิ่มเติมกับคู่แข่งในตลาด โฟกัสเป้าหมายและการเติบโตของช่องทางการขายในแต่ละแพลตฟอร์ม,Procurement: จัดซื้อสินค้าและวัตถุดิบที่ได้ต้นทุนที่แข่งขันได้, Quality Assurance: มี QA ตรวจสอบคุณภาพสินค้าก่อนออกสู่ตลาด, Planning: วางแผนเพื่อเตรียมให้สินค้าพร้อมในการขาย, Finance and Accounting: สนับสนุนข้อมูลด้านต้นทุนสินค้า และ P&L ได้ถูกต้องและรวดเร็ว, Marketing and Sales: เป็นหน่วยงานหลักในการวางแผนกลยุทธ์เพื่อแข่งขันได้, After Sale Service: การบริการหลังการขายเพื่อสร้างความพอใจให้ลูกค้า, Research and Development: พัฒนาสินค้าที่มีคุณภาพและแข่งขันได้, Warehouse: เก็บสินค้าที่เพียงพอและพร้อมในการขาย, Information Technology (IT): สนับสนุนพัฒนาระบบในการทำงานได้คล่องตัว สะดวก รวดเร็ว, Production: ผลิตสินค้าที่มีคุณภาพและเพียงพอกับความต้องการขาย, Transportation: จัดส่งสินค้าที่มีคุณภาพ รวดเร็ว ไม่ชำรุดเสียหาย,Research and Development: การพํฒนาสินค้าที่มีคุณภาพและตอบโจทย์ความต้องการของตลาดในต้นทุนที่สามารถแข่งขันได้, Production: การผลิตสินค้าที่มีคุณภาพ ด้วยเทคโนโลยีที่ทันสมัย สามารถผลิตสินค้าที่ตอบโจทย์ความต้องการของตลาดได้, Marketing and Sales: การวางกลยุทธการตลาดและการขายเชิงรุก เข้าถึงผู้บริโภคได้อย่างทั่วถึงและทุก touch point  ,Information Technology (IT): เครื่องมือเทคโนโลยี่ที่ทันสมัยช่วยสนับสนุนการทำงานทั้งด้านข้อมูล ความถูกต้อง สะดวก และทันต่อสถานการณ์, Research and Development: R&D มีความจำเป็นด้านพัฒนาสินค้าให้ตรงตามความต้องการของตลาด, Business Development: เทรนด์ตลาดมีการเปลี่ยนแปลงตลอด กระบวนการจัดการควรต้องมีการพัฒนาให้สอดคล้องกับตลาด, Planning: การวางแผนผลิต วางแผนกลยุทธ์ และวางแผนการทำงานทุกขั้นตอน มีความจำเป็นอย่างยิ่ง และสามารถปรับแผนการทำงานให้สอดคล้องกับตลาดได้, Production: ผลิตสินค้าคุณภาพให้เพียงพอและทันเวลากับความต้องการการขา, Quality Assurance: เป็นสิ่งสำคัญกับการสร้างความมั่นใจให้ลูกค้าและผู้บริโภค, Warehouse: คลังสินค้ามีพื้นที่เพียงพอในการเก็บสต้อคให้พร้อมกับการขาย และการจัดเก็บสินค้าที่ถูกต้อง มีการ FIFO และดูแลคุณภาพสินค้า, Distribution Center (DC): ช่วยให้การกระจายจัดส่งสินค้าได้ทันเวลา, Transportation: การขนส่งที่รวดเร็ว สินค้าไม่เกิดชำรุดเสียหาย, Marketing and Sales: หน่วยงานหลักของการวางกลยุทธ์เพื่อการขายและกระจายสินค้าเข้าสู่ตลาด, After Sale Service: สร้างความมั่นใจเชื่อมั่นให้ผู้บริโภค',
#    'rootcause': 'rootcause :High number of competitors in the market: ธุรกิจอาหารสัตว์เลี้ยงเติบโตมากอย่างต่อเนื่องทำให้ผู้ผลิตอาหารอื่นๆเข้ามาในตลาดนี้มากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยที่มีต้นทุนต่ำได้เปรียบในการแข่นขันด้านราคา,High number of competitors in the market: ตลาดอาหารแมวในประเทศไทยเติบโตอย่างต่อเนื่อง มีคู่แข่งเข้ามาในตลาดจำนวนมากทั้งอาหารเม็ดและอาหารเปียก , Aggressive pricing strategies: คู่แข่งใช้กลยุทธ์ราคาถูกในการเข้าตลาด ได้แก่ สินค้าเป็นกลุ่มที่ดูเรื่อง Product benefits เป็นกลุ่ม Premium ตั้งราคาเท่ากลุ่ม Standard ให้ดูว่าจับต้องได้ง่าย หรือตลาดล่างที่เติบโตมาขึ้น ก็มีการเข้าตลาดด้วยการใช้กลยุทธ์ทำราคาถูกเช่นกัน,Aggressive pricing strategies: ราคาหรือโปรโมชั่นที่จำหน่ายในงานกิจกรรมต่างๆ สู้คู่แข่งขันไม่ได้,High number of competitors in the market: การแข่งขันที่รุนแรงจากจำนวนคู่แข่งที่เพิ่มขึ้นอาจส่งผลให้สูญเสียลูกค้า รายได้ และส่วนแบ่งทางการตลาด, Aggressive pricing strategies: การลดราคาหนักในตลาด รวมถึงการส่งสินค้าฟรี และมีโปรโมชั่นพิเศษอย่างต่อเนื่อง,High number of competitors in the market: ผู้ผลิตทั้ง Branded & OEM มีจำนวนมากขึ้น และมีการนำเข้าสินค้าจากต่างประเทศมากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยและบริษัทที่ทำธุรกิจจ้างผลิตที่มีต้นทุนการผลิตต่ำได้เปรียบในการแข่งขันด้านราคา, Other: กำลังซื้อของผู้บริโภคลดลง และการตัดสินใจซื้อยากขึ้น,High number of competitors in the market: จำนวนคู่แข่งในตลาดมีจำนวนมากทั้งในส่วนของจำนวน Manufacturer และจำนวน Brand , Aggressive pricing strategies: หลาย Brand ในตลาดกลุ่ม Economy และ Super Economy ใช้กลยุทธการแข่งขันด้านราคาเป็นหลัก ซึ่งทาง PCG อาจจะไม่สามารถแข่งขันโดยการใช้กลุยุทธการทำราคาถูกมากได้ , Other: คู่แข่งมีการทำตลาดอย่างเข้มข้นมากขึ้นทั้งส่วนของการใช้ Media การทำโปรโมชั่น และกิจกรรมต่างๆ ที่เข้าถึงผู้บริโภค รวมถึงใช้กลยุทธการตัดราคาในสินค้ากลุ่มที่ price sensitive'}},
#  {'source': 'risk_PCG_24',
#   'target': 'risk_PCG_47',
#   'weight': 2,
#   'raw_weight': np.float64(105.7261833590136),
#   'color': 'rgb(201, 203, 207)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Intense market competition',
#    'risk_desc': 'A highly competitive market environment where businesses within the same industry are fiercely competing for customers and market share, potentially leading to decreased profitability and market share. ตลาดอาหารสุนัขมีการเติบโตอย่างต่อเนื่อง มีสินค้าใหม่และ Brand ใหม่เกิดขึ้นในตลาดจำนวนมาก และหลายแบรนด์หลายบริษัทมีการทำการตลาดเชิงรุก หรืออาจจะมีการใช้กลยุทธการขายสินค้าราคาถูกมากในกลุ่มสินค้าที่ price sensitive เพื่อแย่งลูกค้าและส่วนแบ่งทางการตลาด ส่งผลให้ทาง PCG อาจจะไม่สามารถทำยอดขาย อัตราการเติบโต รวมถึงส่วนแบ่งตลาด ได้ตามที่วางแผนไว้,สถานการณ์ที่ธุรกิจต่างๆในอุตสาหกรรมเดียวกันมีการแข่งขันที่รุนแรง ซึ่งอาจส่งผลกระทบต่อกำไรและส่วนแบ่งตลาด,ความเสี่ยงจากการแข่งขันในตลาดบนช่องทางออนไลน์และอีคอมเมิร์ซ การแข่งขันที่รุนแรงจากแบรนด์เดิมและคู่แข่งรายใหม่ อาจส่งผลต่อยอดขายและการรักษาฐานลูกค้า,ตลาดอาหารสัตว์เลี้ยงมีอัตราการเติบโตต่อเนื่องทุกปี  ทำให้เป็นแรงจูงใจให้ผู้ผลิตและผู้จัดจำหน่ายสินค้ากลุ่มอื่นๆ ทั้งรายเก่ามีการขยายธุรกิจมากขึ้น และรายใหม่ๆเข้ามาในธุรกิจนี้มากขึ้นด้วย,ขาดกิจกรรมที่ตอบสนองต่อความต้องการของลูกค้า,มีคู่แข่งรายใหม่เข้าสู่ตลาดหรือคู่แข่งเดิมใช้กลยุทธ์การตลาดเชิงรุก ส่งผลให้ยอดขายไม่เป็นไปตามเป้าหมาย',
#    'risk_level': 4,
#    'risk_cat': 'Strategic Risk',
#    'process': 'process :Marketing and Sales: จัดโปรโมชั่นพิเศษเฉพาะงาน,Research and Development: พัฒณาสูตรให้มีคุณภาพดีเท่าเดิม แต่สามารถลดต้นทุน RM ได้, Production: ผลิตได้มีประสิทธิภาพ สามารถลดต้นทุนการผลิตได้, Marketing and Sales: จัดรายการส่งเสริมการขายให้สามารถแข่งขันและกันคู่แข่งในตลาดโดยเฉพาะรายใหม่ที่เข้ามา และ\nจะต้องพัฒนาและออกผลิตภัณฑ์ใหม่ให้ได้ตามแผนที่วางไว้,Planning: ต้องใช้ข้อมูลด้านการตลาดและพฤติกรรมของลูกค้าเพื่อวางแผนทางการตลาดและกำหนดกลุ่มเป้าหมาย รวมถึงการใช้สื่อโฆษณาต่างๆให้เข้าถึงเป้าหมายที่ตรงกลุ่มชัดเจน วิเคราะห์กลยุทธ์ทางการตลาดและผลักดันให้ทันกับการแข่งขันในตลาดที่สูงในปัจจุบัน โดยเฉพาะบนช่องทางอีคอมเมิร์ซ  รวมถึงการประเมิณจัดสรรค่าใช้จ่าย ทั้งค่าโฆษณาและค่าใช้จ่ายอื่นๆ ให้อยู่ในความคุ้มค่าสูงสุดตามงบประมาณที่วางแผนไว้, Marketing and Sales: บริหารงานขาย ด้านราคาสินค้า , โปรโมชั่น และค่าใช้จ่ายๆ ต่างให้ตอบโจทย์และคุ้มค่ามากที่สุดจากการวัดที่ผลลัพธ์ โดยเปรียบเทียบกลยุทธ์เพิ่มเติมกับคู่แข่งในตลาด โฟกัสเป้าหมายและการเติบโตของช่องทางการขายในแต่ละแพลตฟอร์ม,Procurement: จัดซื้อสินค้าและวัตถุดิบที่ได้ต้นทุนที่แข่งขันได้, Quality Assurance: มี QA ตรวจสอบคุณภาพสินค้าก่อนออกสู่ตลาด, Planning: วางแผนเพื่อเตรียมให้สินค้าพร้อมในการขาย, Finance and Accounting: สนับสนุนข้อมูลด้านต้นทุนสินค้า และ P&L ได้ถูกต้องและรวดเร็ว, Marketing and Sales: เป็นหน่วยงานหลักในการวางแผนกลยุทธ์เพื่อแข่งขันได้, After Sale Service: การบริการหลังการขายเพื่อสร้างความพอใจให้ลูกค้า, Research and Development: พัฒนาสินค้าที่มีคุณภาพและแข่งขันได้, Warehouse: เก็บสินค้าที่เพียงพอและพร้อมในการขาย, Information Technology (IT): สนับสนุนพัฒนาระบบในการทำงานได้คล่องตัว สะดวก รวดเร็ว, Production: ผลิตสินค้าที่มีคุณภาพและเพียงพอกับความต้องการขาย, Transportation: จัดส่งสินค้าที่มีคุณภาพ รวดเร็ว ไม่ชำรุดเสียหาย,Research and Development: การพํฒนาสินค้าที่มีคุณภาพและตอบโจทย์ความต้องการของตลาดในต้นทุนที่สามารถแข่งขันได้, Production: การผลิตสินค้าที่มีคุณภาพ ด้วยเทคโนโลยีที่ทันสมัย สามารถผลิตสินค้าที่ตอบโจทย์ความต้องการของตลาดได้, Marketing and Sales: การวางกลยุทธการตลาดและการขายเชิงรุก เข้าถึงผู้บริโภคได้อย่างทั่วถึงและทุก touch point  ,Information Technology (IT): เครื่องมือเทคโนโลยี่ที่ทันสมัยช่วยสนับสนุนการทำงานทั้งด้านข้อมูล ความถูกต้อง สะดวก และทันต่อสถานการณ์, Research and Development: R&D มีความจำเป็นด้านพัฒนาสินค้าให้ตรงตามความต้องการของตลาด, Business Development: เทรนด์ตลาดมีการเปลี่ยนแปลงตลอด กระบวนการจัดการควรต้องมีการพัฒนาให้สอดคล้องกับตลาด, Planning: การวางแผนผลิต วางแผนกลยุทธ์ และวางแผนการทำงานทุกขั้นตอน มีความจำเป็นอย่างยิ่ง และสามารถปรับแผนการทำงานให้สอดคล้องกับตลาดได้, Production: ผลิตสินค้าคุณภาพให้เพียงพอและทันเวลากับความต้องการการขา, Quality Assurance: เป็นสิ่งสำคัญกับการสร้างความมั่นใจให้ลูกค้าและผู้บริโภค, Warehouse: คลังสินค้ามีพื้นที่เพียงพอในการเก็บสต้อคให้พร้อมกับการขาย และการจัดเก็บสินค้าที่ถูกต้อง มีการ FIFO และดูแลคุณภาพสินค้า, Distribution Center (DC): ช่วยให้การกระจายจัดส่งสินค้าได้ทันเวลา, Transportation: การขนส่งที่รวดเร็ว สินค้าไม่เกิดชำรุดเสียหาย, Marketing and Sales: หน่วยงานหลักของการวางกลยุทธ์เพื่อการขายและกระจายสินค้าเข้าสู่ตลาด, After Sale Service: สร้างความมั่นใจเชื่อมั่นให้ผู้บริโภค',
#    'rootcause': 'rootcause :High number of competitors in the market: ธุรกิจอาหารสัตว์เลี้ยงเติบโตมากอย่างต่อเนื่องทำให้ผู้ผลิตอาหารอื่นๆเข้ามาในตลาดนี้มากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยที่มีต้นทุนต่ำได้เปรียบในการแข่นขันด้านราคา,High number of competitors in the market: ตลาดอาหารแมวในประเทศไทยเติบโตอย่างต่อเนื่อง มีคู่แข่งเข้ามาในตลาดจำนวนมากทั้งอาหารเม็ดและอาหารเปียก , Aggressive pricing strategies: คู่แข่งใช้กลยุทธ์ราคาถูกในการเข้าตลาด ได้แก่ สินค้าเป็นกลุ่มที่ดูเรื่อง Product benefits เป็นกลุ่ม Premium ตั้งราคาเท่ากลุ่ม Standard ให้ดูว่าจับต้องได้ง่าย หรือตลาดล่างที่เติบโตมาขึ้น ก็มีการเข้าตลาดด้วยการใช้กลยุทธ์ทำราคาถูกเช่นกัน,Aggressive pricing strategies: ราคาหรือโปรโมชั่นที่จำหน่ายในงานกิจกรรมต่างๆ สู้คู่แข่งขันไม่ได้,High number of competitors in the market: การแข่งขันที่รุนแรงจากจำนวนคู่แข่งที่เพิ่มขึ้นอาจส่งผลให้สูญเสียลูกค้า รายได้ และส่วนแบ่งทางการตลาด, Aggressive pricing strategies: การลดราคาหนักในตลาด รวมถึงการส่งสินค้าฟรี และมีโปรโมชั่นพิเศษอย่างต่อเนื่อง,High number of competitors in the market: ผู้ผลิตทั้ง Branded & OEM มีจำนวนมากขึ้น และมีการนำเข้าสินค้าจากต่างประเทศมากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยและบริษัทที่ทำธุรกิจจ้างผลิตที่มีต้นทุนการผลิตต่ำได้เปรียบในการแข่งขันด้านราคา, Other: กำลังซื้อของผู้บริโภคลดลง และการตัดสินใจซื้อยากขึ้น,High number of competitors in the market: จำนวนคู่แข่งในตลาดมีจำนวนมากทั้งในส่วนของจำนวน Manufacturer และจำนวน Brand , Aggressive pricing strategies: หลาย Brand ในตลาดกลุ่ม Economy และ Super Economy ใช้กลยุทธการแข่งขันด้านราคาเป็นหลัก ซึ่งทาง PCG อาจจะไม่สามารถแข่งขันโดยการใช้กลุยุทธการทำราคาถูกมากได้ , Other: คู่แข่งมีการทำตลาดอย่างเข้มข้นมากขึ้นทั้งส่วนของการใช้ Media การทำโปรโมชั่น และกิจกรรมต่างๆ ที่เข้าถึงผู้บริโภค รวมถึงใช้กลยุทธการตัดราคาในสินค้ากลุ่มที่ price sensitive'},
#   'target_risk_data': {'risk': 'Product substitute',
#    'risk_desc': 'Alternative products potentially decrease market share and revenue. ธุรกิจม้าแข่งเริ่มถดถอยลงมาเป็นระยะเวลากว่า 5 ปี บางรายต้องเลิกกิจการ แต่ก็ยังมีม้าที่ยังต้องดูแล ดังนั้น การมองหาผลิตภัณฑ์ที่สามารถให้ม้ากินแล้วมีสุขภาพที่เหมาะสมกับการใช้งาน ส่วนใหญ่จึงเปลี่ยนไปใช้อาหารสำเร็จรูปที่มีราคาถูกลงหรือถูกที่สุด หรือให้หญ้าแพงโกล่าที่มีราคาถูกทดแทน ซึ่งส่งผลกระทบต่อยอดขายและส่วนแบ่งการตลาดของบริษัท (เฉพาะช่องทาง Traditional Trade)',
#    'risk_level': 2,
#    'risk_cat': 'Strategic Risk',
#    'process': 'process :Marketing and Sales: จัดโปรโมชั่นพิเศษเฉพาะงาน,Research and Development: พัฒณาสูตรให้มีคุณภาพดีเท่าเดิม แต่สามารถลดต้นทุน RM ได้, Production: ผลิตได้มีประสิทธิภาพ สามารถลดต้นทุนการผลิตได้, Marketing and Sales: จัดรายการส่งเสริมการขายให้สามารถแข่งขันและกันคู่แข่งในตลาดโดยเฉพาะรายใหม่ที่เข้ามา และ\nจะต้องพัฒนาและออกผลิตภัณฑ์ใหม่ให้ได้ตามแผนที่วางไว้,Planning: ต้องใช้ข้อมูลด้านการตลาดและพฤติกรรมของลูกค้าเพื่อวางแผนทางการตลาดและกำหนดกลุ่มเป้าหมาย รวมถึงการใช้สื่อโฆษณาต่างๆให้เข้าถึงเป้าหมายที่ตรงกลุ่มชัดเจน วิเคราะห์กลยุทธ์ทางการตลาดและผลักดันให้ทันกับการแข่งขันในตลาดที่สูงในปัจจุบัน โดยเฉพาะบนช่องทางอีคอมเมิร์ซ  รวมถึงการประเมิณจัดสรรค่าใช้จ่าย ทั้งค่าโฆษณาและค่าใช้จ่ายอื่นๆ ให้อยู่ในความคุ้มค่าสูงสุดตามงบประมาณที่วางแผนไว้, Marketing and Sales: บริหารงานขาย ด้านราคาสินค้า , โปรโมชั่น และค่าใช้จ่ายๆ ต่างให้ตอบโจทย์และคุ้มค่ามากที่สุดจากการวัดที่ผลลัพธ์ โดยเปรียบเทียบกลยุทธ์เพิ่มเติมกับคู่แข่งในตลาด โฟกัสเป้าหมายและการเติบโตของช่องทางการขายในแต่ละแพลตฟอร์ม,Procurement: จัดซื้อสินค้าและวัตถุดิบที่ได้ต้นทุนที่แข่งขันได้, Quality Assurance: มี QA ตรวจสอบคุณภาพสินค้าก่อนออกสู่ตลาด, Planning: วางแผนเพื่อเตรียมให้สินค้าพร้อมในการขาย, Finance and Accounting: สนับสนุนข้อมูลด้านต้นทุนสินค้า และ P&L ได้ถูกต้องและรวดเร็ว, Marketing and Sales: เป็นหน่วยงานหลักในการวางแผนกลยุทธ์เพื่อแข่งขันได้, After Sale Service: การบริการหลังการขายเพื่อสร้างความพอใจให้ลูกค้า, Research and Development: พัฒนาสินค้าที่มีคุณภาพและแข่งขันได้, Warehouse: เก็บสินค้าที่เพียงพอและพร้อมในการขาย, Information Technology (IT): สนับสนุนพัฒนาระบบในการทำงานได้คล่องตัว สะดวก รวดเร็ว, Production: ผลิตสินค้าที่มีคุณภาพและเพียงพอกับความต้องการขาย, Transportation: จัดส่งสินค้าที่มีคุณภาพ รวดเร็ว ไม่ชำรุดเสียหาย,Research and Development: การพํฒนาสินค้าที่มีคุณภาพและตอบโจทย์ความต้องการของตลาดในต้นทุนที่สามารถแข่งขันได้, Production: การผลิตสินค้าที่มีคุณภาพ ด้วยเทคโนโลยีที่ทันสมัย สามารถผลิตสินค้าที่ตอบโจทย์ความต้องการของตลาดได้, Marketing and Sales: การวางกลยุทธการตลาดและการขายเชิงรุก เข้าถึงผู้บริโภคได้อย่างทั่วถึงและทุก touch point  ,Information Technology (IT): เครื่องมือเทคโนโลยี่ที่ทันสมัยช่วยสนับสนุนการทำงานทั้งด้านข้อมูล ความถูกต้อง สะดวก และทันต่อสถานการณ์, Research and Development: R&D มีความจำเป็นด้านพัฒนาสินค้าให้ตรงตามความต้องการของตลาด, Business Development: เทรนด์ตลาดมีการเปลี่ยนแปลงตลอด กระบวนการจัดการควรต้องมีการพัฒนาให้สอดคล้องกับตลาด, Planning: การวางแผนผลิต วางแผนกลยุทธ์ และวางแผนการทำงานทุกขั้นตอน มีความจำเป็นอย่างยิ่ง และสามารถปรับแผนการทำงานให้สอดคล้องกับตลาดได้, Production: ผลิตสินค้าคุณภาพให้เพียงพอและทันเวลากับความต้องการการขา, Quality Assurance: เป็นสิ่งสำคัญกับการสร้างความมั่นใจให้ลูกค้าและผู้บริโภค, Warehouse: คลังสินค้ามีพื้นที่เพียงพอในการเก็บสต้อคให้พร้อมกับการขาย และการจัดเก็บสินค้าที่ถูกต้อง มีการ FIFO และดูแลคุณภาพสินค้า, Distribution Center (DC): ช่วยให้การกระจายจัดส่งสินค้าได้ทันเวลา, Transportation: การขนส่งที่รวดเร็ว สินค้าไม่เกิดชำรุดเสียหาย, Marketing and Sales: หน่วยงานหลักของการวางกลยุทธ์เพื่อการขายและกระจายสินค้าเข้าสู่ตลาด, After Sale Service: สร้างความมั่นใจเชื่อมั่นให้ผู้บริโภค',
#    'rootcause': 'rootcause :High number of competitors in the market: ธุรกิจอาหารสัตว์เลี้ยงเติบโตมากอย่างต่อเนื่องทำให้ผู้ผลิตอาหารอื่นๆเข้ามาในตลาดนี้มากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยที่มีต้นทุนต่ำได้เปรียบในการแข่นขันด้านราคา,High number of competitors in the market: ตลาดอาหารแมวในประเทศไทยเติบโตอย่างต่อเนื่อง มีคู่แข่งเข้ามาในตลาดจำนวนมากทั้งอาหารเม็ดและอาหารเปียก , Aggressive pricing strategies: คู่แข่งใช้กลยุทธ์ราคาถูกในการเข้าตลาด ได้แก่ สินค้าเป็นกลุ่มที่ดูเรื่อง Product benefits เป็นกลุ่ม Premium ตั้งราคาเท่ากลุ่ม Standard ให้ดูว่าจับต้องได้ง่าย หรือตลาดล่างที่เติบโตมาขึ้น ก็มีการเข้าตลาดด้วยการใช้กลยุทธ์ทำราคาถูกเช่นกัน,Aggressive pricing strategies: ราคาหรือโปรโมชั่นที่จำหน่ายในงานกิจกรรมต่างๆ สู้คู่แข่งขันไม่ได้,High number of competitors in the market: การแข่งขันที่รุนแรงจากจำนวนคู่แข่งที่เพิ่มขึ้นอาจส่งผลให้สูญเสียลูกค้า รายได้ และส่วนแบ่งทางการตลาด, Aggressive pricing strategies: การลดราคาหนักในตลาด รวมถึงการส่งสินค้าฟรี และมีโปรโมชั่นพิเศษอย่างต่อเนื่อง,High number of competitors in the market: ผู้ผลิตทั้ง Branded & OEM มีจำนวนมากขึ้น และมีการนำเข้าสินค้าจากต่างประเทศมากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยและบริษัทที่ทำธุรกิจจ้างผลิตที่มีต้นทุนการผลิตต่ำได้เปรียบในการแข่งขันด้านราคา, Other: กำลังซื้อของผู้บริโภคลดลง และการตัดสินใจซื้อยากขึ้น,High number of competitors in the market: จำนวนคู่แข่งในตลาดมีจำนวนมากทั้งในส่วนของจำนวน Manufacturer และจำนวน Brand , Aggressive pricing strategies: หลาย Brand ในตลาดกลุ่ม Economy และ Super Economy ใช้กลยุทธการแข่งขันด้านราคาเป็นหลัก ซึ่งทาง PCG อาจจะไม่สามารถแข่งขันโดยการใช้กลุยุทธการทำราคาถูกมากได้ , Other: คู่แข่งมีการทำตลาดอย่างเข้มข้นมากขึ้นทั้งส่วนของการใช้ Media การทำโปรโมชั่น และกิจกรรมต่างๆ ที่เข้าถึงผู้บริโภค รวมถึงใช้กลยุทธการตัดราคาในสินค้ากลุ่มที่ price sensitive'}},
#  {'source': 'risk_PCG_24',
#   'target': 'risk_PCG_59',
#   'weight': 2,
#   'raw_weight': np.float64(104.1538679395602),
#   'color': 'rgb(201, 203, 207)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Intense market competition',
#    'risk_desc': 'A highly competitive market environment where businesses within the same industry are fiercely competing for customers and market share, potentially leading to decreased profitability and market share. ตลาดอาหารสุนัขมีการเติบโตอย่างต่อเนื่อง มีสินค้าใหม่และ Brand ใหม่เกิดขึ้นในตลาดจำนวนมาก และหลายแบรนด์หลายบริษัทมีการทำการตลาดเชิงรุก หรืออาจจะมีการใช้กลยุทธการขายสินค้าราคาถูกมากในกลุ่มสินค้าที่ price sensitive เพื่อแย่งลูกค้าและส่วนแบ่งทางการตลาด ส่งผลให้ทาง PCG อาจจะไม่สามารถทำยอดขาย อัตราการเติบโต รวมถึงส่วนแบ่งตลาด ได้ตามที่วางแผนไว้,สถานการณ์ที่ธุรกิจต่างๆในอุตสาหกรรมเดียวกันมีการแข่งขันที่รุนแรง ซึ่งอาจส่งผลกระทบต่อกำไรและส่วนแบ่งตลาด,ความเสี่ยงจากการแข่งขันในตลาดบนช่องทางออนไลน์และอีคอมเมิร์ซ การแข่งขันที่รุนแรงจากแบรนด์เดิมและคู่แข่งรายใหม่ อาจส่งผลต่อยอดขายและการรักษาฐานลูกค้า,ตลาดอาหารสัตว์เลี้ยงมีอัตราการเติบโตต่อเนื่องทุกปี  ทำให้เป็นแรงจูงใจให้ผู้ผลิตและผู้จัดจำหน่ายสินค้ากลุ่มอื่นๆ ทั้งรายเก่ามีการขยายธุรกิจมากขึ้น และรายใหม่ๆเข้ามาในธุรกิจนี้มากขึ้นด้วย,ขาดกิจกรรมที่ตอบสนองต่อความต้องการของลูกค้า,มีคู่แข่งรายใหม่เข้าสู่ตลาดหรือคู่แข่งเดิมใช้กลยุทธ์การตลาดเชิงรุก ส่งผลให้ยอดขายไม่เป็นไปตามเป้าหมาย',
#    'risk_level': 4,
#    'risk_cat': 'Strategic Risk',
#    'process': 'process :Marketing and Sales: จัดโปรโมชั่นพิเศษเฉพาะงาน,Research and Development: พัฒณาสูตรให้มีคุณภาพดีเท่าเดิม แต่สามารถลดต้นทุน RM ได้, Production: ผลิตได้มีประสิทธิภาพ สามารถลดต้นทุนการผลิตได้, Marketing and Sales: จัดรายการส่งเสริมการขายให้สามารถแข่งขันและกันคู่แข่งในตลาดโดยเฉพาะรายใหม่ที่เข้ามา และ\nจะต้องพัฒนาและออกผลิตภัณฑ์ใหม่ให้ได้ตามแผนที่วางไว้,Planning: ต้องใช้ข้อมูลด้านการตลาดและพฤติกรรมของลูกค้าเพื่อวางแผนทางการตลาดและกำหนดกลุ่มเป้าหมาย รวมถึงการใช้สื่อโฆษณาต่างๆให้เข้าถึงเป้าหมายที่ตรงกลุ่มชัดเจน วิเคราะห์กลยุทธ์ทางการตลาดและผลักดันให้ทันกับการแข่งขันในตลาดที่สูงในปัจจุบัน โดยเฉพาะบนช่องทางอีคอมเมิร์ซ  รวมถึงการประเมิณจัดสรรค่าใช้จ่าย ทั้งค่าโฆษณาและค่าใช้จ่ายอื่นๆ ให้อยู่ในความคุ้มค่าสูงสุดตามงบประมาณที่วางแผนไว้, Marketing and Sales: บริหารงานขาย ด้านราคาสินค้า , โปรโมชั่น และค่าใช้จ่ายๆ ต่างให้ตอบโจทย์และคุ้มค่ามากที่สุดจากการวัดที่ผลลัพธ์ โดยเปรียบเทียบกลยุทธ์เพิ่มเติมกับคู่แข่งในตลาด โฟกัสเป้าหมายและการเติบโตของช่องทางการขายในแต่ละแพลตฟอร์ม,Procurement: จัดซื้อสินค้าและวัตถุดิบที่ได้ต้นทุนที่แข่งขันได้, Quality Assurance: มี QA ตรวจสอบคุณภาพสินค้าก่อนออกสู่ตลาด, Planning: วางแผนเพื่อเตรียมให้สินค้าพร้อมในการขาย, Finance and Accounting: สนับสนุนข้อมูลด้านต้นทุนสินค้า และ P&L ได้ถูกต้องและรวดเร็ว, Marketing and Sales: เป็นหน่วยงานหลักในการวางแผนกลยุทธ์เพื่อแข่งขันได้, After Sale Service: การบริการหลังการขายเพื่อสร้างความพอใจให้ลูกค้า, Research and Development: พัฒนาสินค้าที่มีคุณภาพและแข่งขันได้, Warehouse: เก็บสินค้าที่เพียงพอและพร้อมในการขาย, Information Technology (IT): สนับสนุนพัฒนาระบบในการทำงานได้คล่องตัว สะดวก รวดเร็ว, Production: ผลิตสินค้าที่มีคุณภาพและเพียงพอกับความต้องการขาย, Transportation: จัดส่งสินค้าที่มีคุณภาพ รวดเร็ว ไม่ชำรุดเสียหาย,Research and Development: การพํฒนาสินค้าที่มีคุณภาพและตอบโจทย์ความต้องการของตลาดในต้นทุนที่สามารถแข่งขันได้, Production: การผลิตสินค้าที่มีคุณภาพ ด้วยเทคโนโลยีที่ทันสมัย สามารถผลิตสินค้าที่ตอบโจทย์ความต้องการของตลาดได้, Marketing and Sales: การวางกลยุทธการตลาดและการขายเชิงรุก เข้าถึงผู้บริโภคได้อย่างทั่วถึงและทุก touch point  ,Information Technology (IT): เครื่องมือเทคโนโลยี่ที่ทันสมัยช่วยสนับสนุนการทำงานทั้งด้านข้อมูล ความถูกต้อง สะดวก และทันต่อสถานการณ์, Research and Development: R&D มีความจำเป็นด้านพัฒนาสินค้าให้ตรงตามความต้องการของตลาด, Business Development: เทรนด์ตลาดมีการเปลี่ยนแปลงตลอด กระบวนการจัดการควรต้องมีการพัฒนาให้สอดคล้องกับตลาด, Planning: การวางแผนผลิต วางแผนกลยุทธ์ และวางแผนการทำงานทุกขั้นตอน มีความจำเป็นอย่างยิ่ง และสามารถปรับแผนการทำงานให้สอดคล้องกับตลาดได้, Production: ผลิตสินค้าคุณภาพให้เพียงพอและทันเวลากับความต้องการการขา, Quality Assurance: เป็นสิ่งสำคัญกับการสร้างความมั่นใจให้ลูกค้าและผู้บริโภค, Warehouse: คลังสินค้ามีพื้นที่เพียงพอในการเก็บสต้อคให้พร้อมกับการขาย และการจัดเก็บสินค้าที่ถูกต้อง มีการ FIFO และดูแลคุณภาพสินค้า, Distribution Center (DC): ช่วยให้การกระจายจัดส่งสินค้าได้ทันเวลา, Transportation: การขนส่งที่รวดเร็ว สินค้าไม่เกิดชำรุดเสียหาย, Marketing and Sales: หน่วยงานหลักของการวางกลยุทธ์เพื่อการขายและกระจายสินค้าเข้าสู่ตลาด, After Sale Service: สร้างความมั่นใจเชื่อมั่นให้ผู้บริโภค',
#    'rootcause': 'rootcause :High number of competitors in the market: ธุรกิจอาหารสัตว์เลี้ยงเติบโตมากอย่างต่อเนื่องทำให้ผู้ผลิตอาหารอื่นๆเข้ามาในตลาดนี้มากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยที่มีต้นทุนต่ำได้เปรียบในการแข่นขันด้านราคา,High number of competitors in the market: ตลาดอาหารแมวในประเทศไทยเติบโตอย่างต่อเนื่อง มีคู่แข่งเข้ามาในตลาดจำนวนมากทั้งอาหารเม็ดและอาหารเปียก , Aggressive pricing strategies: คู่แข่งใช้กลยุทธ์ราคาถูกในการเข้าตลาด ได้แก่ สินค้าเป็นกลุ่มที่ดูเรื่อง Product benefits เป็นกลุ่ม Premium ตั้งราคาเท่ากลุ่ม Standard ให้ดูว่าจับต้องได้ง่าย หรือตลาดล่างที่เติบโตมาขึ้น ก็มีการเข้าตลาดด้วยการใช้กลยุทธ์ทำราคาถูกเช่นกัน,Aggressive pricing strategies: ราคาหรือโปรโมชั่นที่จำหน่ายในงานกิจกรรมต่างๆ สู้คู่แข่งขันไม่ได้,High number of competitors in the market: การแข่งขันที่รุนแรงจากจำนวนคู่แข่งที่เพิ่มขึ้นอาจส่งผลให้สูญเสียลูกค้า รายได้ และส่วนแบ่งทางการตลาด, Aggressive pricing strategies: การลดราคาหนักในตลาด รวมถึงการส่งสินค้าฟรี และมีโปรโมชั่นพิเศษอย่างต่อเนื่อง,High number of competitors in the market: ผู้ผลิตทั้ง Branded & OEM มีจำนวนมากขึ้น และมีการนำเข้าสินค้าจากต่างประเทศมากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยและบริษัทที่ทำธุรกิจจ้างผลิตที่มีต้นทุนการผลิตต่ำได้เปรียบในการแข่งขันด้านราคา, Other: กำลังซื้อของผู้บริโภคลดลง และการตัดสินใจซื้อยากขึ้น,High number of competitors in the market: จำนวนคู่แข่งในตลาดมีจำนวนมากทั้งในส่วนของจำนวน Manufacturer และจำนวน Brand , Aggressive pricing strategies: หลาย Brand ในตลาดกลุ่ม Economy และ Super Economy ใช้กลยุทธการแข่งขันด้านราคาเป็นหลัก ซึ่งทาง PCG อาจจะไม่สามารถแข่งขันโดยการใช้กลุยุทธการทำราคาถูกมากได้ , Other: คู่แข่งมีการทำตลาดอย่างเข้มข้นมากขึ้นทั้งส่วนของการใช้ Media การทำโปรโมชั่น และกิจกรรมต่างๆ ที่เข้าถึงผู้บริโภค รวมถึงใช้กลยุทธการตัดราคาในสินค้ากลุ่มที่ price sensitive'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. บริการที่ไม่สามารถแข่งขันได้ อาจบังคับให้องค์กรต้องปรับตัวแบบไม่มีแผนระยะยาว ส่งผลกระทบต่อประสิทธิภาพการดำเนินงาน, พนักงานอาจรู้สึกหมดกำลังใจเมื่อเห็นว่าองค์กรไม่มีความสามารถแข่งขันในตลาด และคู่ค้าเห็นว่าองค์กรไม่มีศักยภาพในการแข่งขัน อาจลดความสนใจหรือยุติความร่วมมือ',
#    'risk_level': 1,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: จัดโปรโมชั่นพิเศษเฉพาะงาน,Research and Development: พัฒณาสูตรให้มีคุณภาพดีเท่าเดิม แต่สามารถลดต้นทุน RM ได้, Production: ผลิตได้มีประสิทธิภาพ สามารถลดต้นทุนการผลิตได้, Marketing and Sales: จัดรายการส่งเสริมการขายให้สามารถแข่งขันและกันคู่แข่งในตลาดโดยเฉพาะรายใหม่ที่เข้ามา และ\nจะต้องพัฒนาและออกผลิตภัณฑ์ใหม่ให้ได้ตามแผนที่วางไว้,Planning: ต้องใช้ข้อมูลด้านการตลาดและพฤติกรรมของลูกค้าเพื่อวางแผนทางการตลาดและกำหนดกลุ่มเป้าหมาย รวมถึงการใช้สื่อโฆษณาต่างๆให้เข้าถึงเป้าหมายที่ตรงกลุ่มชัดเจน วิเคราะห์กลยุทธ์ทางการตลาดและผลักดันให้ทันกับการแข่งขันในตลาดที่สูงในปัจจุบัน โดยเฉพาะบนช่องทางอีคอมเมิร์ซ  รวมถึงการประเมิณจัดสรรค่าใช้จ่าย ทั้งค่าโฆษณาและค่าใช้จ่ายอื่นๆ ให้อยู่ในความคุ้มค่าสูงสุดตามงบประมาณที่วางแผนไว้, Marketing and Sales: บริหารงานขาย ด้านราคาสินค้า , โปรโมชั่น และค่าใช้จ่ายๆ ต่างให้ตอบโจทย์และคุ้มค่ามากที่สุดจากการวัดที่ผลลัพธ์ โดยเปรียบเทียบกลยุทธ์เพิ่มเติมกับคู่แข่งในตลาด โฟกัสเป้าหมายและการเติบโตของช่องทางการขายในแต่ละแพลตฟอร์ม,Procurement: จัดซื้อสินค้าและวัตถุดิบที่ได้ต้นทุนที่แข่งขันได้, Quality Assurance: มี QA ตรวจสอบคุณภาพสินค้าก่อนออกสู่ตลาด, Planning: วางแผนเพื่อเตรียมให้สินค้าพร้อมในการขาย, Finance and Accounting: สนับสนุนข้อมูลด้านต้นทุนสินค้า และ P&L ได้ถูกต้องและรวดเร็ว, Marketing and Sales: เป็นหน่วยงานหลักในการวางแผนกลยุทธ์เพื่อแข่งขันได้, After Sale Service: การบริการหลังการขายเพื่อสร้างความพอใจให้ลูกค้า, Research and Development: พัฒนาสินค้าที่มีคุณภาพและแข่งขันได้, Warehouse: เก็บสินค้าที่เพียงพอและพร้อมในการขาย, Information Technology (IT): สนับสนุนพัฒนาระบบในการทำงานได้คล่องตัว สะดวก รวดเร็ว, Production: ผลิตสินค้าที่มีคุณภาพและเพียงพอกับความต้องการขาย, Transportation: จัดส่งสินค้าที่มีคุณภาพ รวดเร็ว ไม่ชำรุดเสียหาย,Research and Development: การพํฒนาสินค้าที่มีคุณภาพและตอบโจทย์ความต้องการของตลาดในต้นทุนที่สามารถแข่งขันได้, Production: การผลิตสินค้าที่มีคุณภาพ ด้วยเทคโนโลยีที่ทันสมัย สามารถผลิตสินค้าที่ตอบโจทย์ความต้องการของตลาดได้, Marketing and Sales: การวางกลยุทธการตลาดและการขายเชิงรุก เข้าถึงผู้บริโภคได้อย่างทั่วถึงและทุก touch point  ,Information Technology (IT): เครื่องมือเทคโนโลยี่ที่ทันสมัยช่วยสนับสนุนการทำงานทั้งด้านข้อมูล ความถูกต้อง สะดวก และทันต่อสถานการณ์, Research and Development: R&D มีความจำเป็นด้านพัฒนาสินค้าให้ตรงตามความต้องการของตลาด, Business Development: เทรนด์ตลาดมีการเปลี่ยนแปลงตลอด กระบวนการจัดการควรต้องมีการพัฒนาให้สอดคล้องกับตลาด, Planning: การวางแผนผลิต วางแผนกลยุทธ์ และวางแผนการทำงานทุกขั้นตอน มีความจำเป็นอย่างยิ่ง และสามารถปรับแผนการทำงานให้สอดคล้องกับตลาดได้, Production: ผลิตสินค้าคุณภาพให้เพียงพอและทันเวลากับความต้องการการขา, Quality Assurance: เป็นสิ่งสำคัญกับการสร้างความมั่นใจให้ลูกค้าและผู้บริโภค, Warehouse: คลังสินค้ามีพื้นที่เพียงพอในการเก็บสต้อคให้พร้อมกับการขาย และการจัดเก็บสินค้าที่ถูกต้อง มีการ FIFO และดูแลคุณภาพสินค้า, Distribution Center (DC): ช่วยให้การกระจายจัดส่งสินค้าได้ทันเวลา, Transportation: การขนส่งที่รวดเร็ว สินค้าไม่เกิดชำรุดเสียหาย, Marketing and Sales: หน่วยงานหลักของการวางกลยุทธ์เพื่อการขายและกระจายสินค้าเข้าสู่ตลาด, After Sale Service: สร้างความมั่นใจเชื่อมั่นให้ผู้บริโภค',
#    'rootcause': 'rootcause :High number of competitors in the market: ธุรกิจอาหารสัตว์เลี้ยงเติบโตมากอย่างต่อเนื่องทำให้ผู้ผลิตอาหารอื่นๆเข้ามาในตลาดนี้มากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยที่มีต้นทุนต่ำได้เปรียบในการแข่นขันด้านราคา,High number of competitors in the market: ตลาดอาหารแมวในประเทศไทยเติบโตอย่างต่อเนื่อง มีคู่แข่งเข้ามาในตลาดจำนวนมากทั้งอาหารเม็ดและอาหารเปียก , Aggressive pricing strategies: คู่แข่งใช้กลยุทธ์ราคาถูกในการเข้าตลาด ได้แก่ สินค้าเป็นกลุ่มที่ดูเรื่อง Product benefits เป็นกลุ่ม Premium ตั้งราคาเท่ากลุ่ม Standard ให้ดูว่าจับต้องได้ง่าย หรือตลาดล่างที่เติบโตมาขึ้น ก็มีการเข้าตลาดด้วยการใช้กลยุทธ์ทำราคาถูกเช่นกัน,Aggressive pricing strategies: ราคาหรือโปรโมชั่นที่จำหน่ายในงานกิจกรรมต่างๆ สู้คู่แข่งขันไม่ได้,High number of competitors in the market: การแข่งขันที่รุนแรงจากจำนวนคู่แข่งที่เพิ่มขึ้นอาจส่งผลให้สูญเสียลูกค้า รายได้ และส่วนแบ่งทางการตลาด, Aggressive pricing strategies: การลดราคาหนักในตลาด รวมถึงการส่งสินค้าฟรี และมีโปรโมชั่นพิเศษอย่างต่อเนื่อง,High number of competitors in the market: ผู้ผลิตทั้ง Branded & OEM มีจำนวนมากขึ้น และมีการนำเข้าสินค้าจากต่างประเทศมากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยและบริษัทที่ทำธุรกิจจ้างผลิตที่มีต้นทุนการผลิตต่ำได้เปรียบในการแข่งขันด้านราคา, Other: กำลังซื้อของผู้บริโภคลดลง และการตัดสินใจซื้อยากขึ้น,High number of competitors in the market: จำนวนคู่แข่งในตลาดมีจำนวนมากทั้งในส่วนของจำนวน Manufacturer และจำนวน Brand , Aggressive pricing strategies: หลาย Brand ในตลาดกลุ่ม Economy และ Super Economy ใช้กลยุทธการแข่งขันด้านราคาเป็นหลัก ซึ่งทาง PCG อาจจะไม่สามารถแข่งขันโดยการใช้กลุยุทธการทำราคาถูกมากได้ , Other: คู่แข่งมีการทำตลาดอย่างเข้มข้นมากขึ้นทั้งส่วนของการใช้ Media การทำโปรโมชั่น และกิจกรรมต่างๆ ที่เข้าถึงผู้บริโภค รวมถึงใช้กลยุทธการตัดราคาในสินค้ากลุ่มที่ price sensitive'}},
#  {'source': 'risk_PCG_27',
#   'target': 'risk_PCG_59',
#   'weight': 2,
#   'raw_weight': np.float64(103.75606751579372),
#   'color': 'rgb(201, 203, 207)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Loss of talent and expertise',
#    'risk_desc': 'This risk occurs when the organization struggles to attract or retain top talent or subject matter experts due to perceptions of stagnation, limited career advancement opportunities, or uncompetitive compensation packages. การขาดแคลนผู้ปฏิบัติงานในสายงานการตลาด',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: -, Human Resources: -',
#    'rootcause': 'rootcause :Scrambling for personnel by business competitors: -'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. บริการที่ไม่สามารถแข่งขันได้ อาจบังคับให้องค์กรต้องปรับตัวแบบไม่มีแผนระยะยาว ส่งผลกระทบต่อประสิทธิภาพการดำเนินงาน, พนักงานอาจรู้สึกหมดกำลังใจเมื่อเห็นว่าองค์กรไม่มีความสามารถแข่งขันในตลาด และคู่ค้าเห็นว่าองค์กรไม่มีศักยภาพในการแข่งขัน อาจลดความสนใจหรือยุติความร่วมมือ',
#    'risk_level': 1,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: -, Human Resources: -',
#    'rootcause': 'rootcause :Scrambling for personnel by business competitors: -'}},
#  {'source': 'risk_PCG_32',
#   'target': 'risk_PCG_44',
#   'weight': 2,
#   'raw_weight': np.float64(103.9312121450358),
#   'color': 'rgb(201, 203, 207)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'New competitor into the market',
#    'risk_desc': 'The entry of new competitors can saturate the market, driving down prices and increasing competition. This challenges existing businesses to maintain their market position. การเข้ามาขอคู่แข่งในตลาดอาหารแมวทั้งชนิดเปียก และแห้ง ทำให้เกิดการแข่งขันทั้งคุณภาพและราคา มีผลกระทบกับยอดขายสินค้าและตำแหน่งในตลาดของผลิตภัณฑ์ของบริษัท,ตลาดอาหารสุนัขมีการเติบโตอย่างต่อเนื่อง ส่งผลให้มีคู่แข่งใหม่เข้าสู่ตลาดจำนวนมากทั้งคู่แข่งในประเทศและคู่แข่งจากต่างประเทศ ส่งผลให้มีการแข่งขันในตลาดสูงขึ้น และมีผู้เล่นที่มา share ยอดขายและ market share ในตลาดมากขึ้นด้วย รวมถึงคู่แข่งใหม่สามารถทำสินค้าที่มีคุณภาพดีแต่ขายในราคาที่ไม่แพงมาก จึงได้รับความสนใจจากผู้บริโภคได้ง่าย และขายได้ดี ดังนั้นอาจทำให้บริษัทฯ ไม่สามารถทำยอดขายหรืออัตราการเติบโตได้ตามเป้าหมายที่กำหนดไว้,ตลาดอาหารปลาคาร์พ  กระต่าย  นกแก้วและนกสวยงาม มักจะมีสินค้าใหม่เข้าสู่ตลาด ทั้งสินค้าที่ผลิตในประเทศและนำเข้าจากต่างประเทศ ซึ่งตลาดของผลิตภัณฑ์ดังกล่าวจะเป็นสินค้าเฉพาะกลุ่มอยู่แล้ว  และยิ่งมีแบรนด์ใหม่เข้ามาเพิ่ม จึงส่งผลให้กลยุทธ์การทำตลาดจะเน้นไปในเรื่องของกิจกรรมส่งเสริมการขาย เช่น จัด promotion ราคาพิเศษ หรือการแย่งชิงลูกค้ารายใหญ่เช่น การเข้าฟาร์ม หรือพื้นที่ดิสเพลย์ใน pet shop เป็นต้น   ดังนั้นหากไม่วางกลยุทธ์ที่สามารถกันคู่แข่งรายใหม่เหล่านี้ได้ ก็จะทำให้ส่งผลกระทบต่อยอดขาย และส่วนแบ่งการตลาดที่ลดลง',
#    'risk_level': 2,
#    'risk_cat': 'Strategic Risk',
#    'process': 'process :Research and Development: -เมื่อมีสินค้าใหม่ออกสู่ตลาดแล้วไม่มีการมอนิเตอร์   ไม่มีการวิเคราะห์ ทดสอบเปรียบเทียบกับสินค้าบริษัท  แล้วถ้าสินค้านั้นคุณภาพใกล้เคียงกับของบริษัทแต่ราคาถูกกว่า อาจส่งผลกระทบให้ลูกค้าเปลี่ยนไปใช้ยี่ห้อคู่แข่งแทน\n-หากไม่มีการมอนิเตอร์คุณภาพสินค้าของบริษัทอยู่เป็นประจำ เช่น การทดสอบความน่ากินไม่ให้แพ้คู่แข่ง อาจทำให้ไม่รู้สถานะของสินค้าตัวเองว่าต้องมีการปรับปรุงหรือแก้ไข อาจส่งผลให้ลูกค้าเปลี่ยนไปใช้ยี่ห้องคู่แข่งแทนได้เช่นเดียวกัน, Production: -หากไม่มีการควบคุมหรือไม่มีขั้นตอนตรวจสอบคุณภาพ เพื่อลดความผิดพลาดในการผลิตให้น้อยที่สุด อาจส่งผลต่อการจำหน่ายสินค้าที่ไม่มีคุณภาพ ซึ่งมีโอกาสที่ลูกค้าจะเปลี่ยนไปใช้สินค้าคู่แข่งแทนได้\n-หากไม่ควบคุมต้นทุนการผลิต อาจส่งผลต่อต้นทุนสินค้าที่สูงและทำให้ไม่สามารถวางกลยุทธ์ทางด้านราคาที่สู้คู่แข่งได้ หรือไม่สามารถทำรายการส่งเสริมการขายเพื่อรักษาส่วนแบ่งการตลาดไว้ได้ \n-หากไม่สามารถปรับแผนการผลิตหรือมีความยืดหยุ่น เพื่อรองรับหรือตอบสนองความต้องการของลูกค้า อาจส่งผลให้ลูกค้าเปลี่ยนไปใช้สินค้าคู่แข่งแทนได้, Marketing and Sales: ฝ่ายการตลาด >>\n-ไม่มีการสำรวจตลาดและไม่รู้ความเคลื่อนไหวของตลาดและคู่แข่ง\n-ไม่มีการวิเคราะห์จุดแข็งจุดอ่อนสินค้าของบริษัทและคู่แข่ง\n-ไม่วางกลยุทธ์ให้ตอบโจทย์ consumers ทุก segment ทั้งตัวสินค้า และการเลือกใช้เครื่องมือสื่อสารทางการตลาด จัด promotion ให้ตอบโจทย์ลูกค้าแต่ละช่องทาง\n\n ฝ่ายขาย >>\n-ไม่มีข้อมูลสินค้าคู่แข่ง และไม่อัพเดตความเคลื่อนไหวของสินค้าคู่แข่งให้กับบริษัท\n-ไม่ใกล้ชิดลูกค้า เพื่อทราบสถานการณ์ในการนำสินค้าใหม่ของคู่แข่งเข้าไปจำหน่ายในร้านค้า  และไม่เตรียมแผนรองรับสำหรับการต่อรองจากร้านค้า\n-ไม่มีการเพิ่ม distribution ขยายเข้าสู่ช่องทางอื่นๆ เพิ่มขึ้น  ไม่วางสินค้าคลอบคลุมทุกช่องทางที่มีสินค้าคู่แข่ง\n\nสิ่งเหล่านี้จะส่งผลกระทบต่อการเสียลูกค้า ยอดขาย และสัดส่วนการตลาดไปให้กับคู่แข่งรายใหม่ที่พร้อมจะวางกลยุทธิ์เพื่อแย่งฐานลูกค้าจากบริษัท ,Research and Development: พัฒนาสินค้าให้มีคุณภาพ ความน่ากิน มากกว่าคู่แข่ง และมีต้นทุน RM ที่สามารถแข่งขันในตลาดได้, Planning: เตรียมสินค้าให้ครบตาม Forecast, Production: ผลิตได้สินค้าตามมาตราฐาน ลดต้นทุนการผลิค, Service: ให้บริการดีกว่าคู่แข่ง สร้างความประทับใจ, Quality Assurance: ควบคุมคุณภาพสินค้าให้ได้ตามมาตราฐาน, Marketing and Sales: มีกลยุทธ์สู้คู่แข่ง รักษาฐานลูกค้าเดิม สร้างลูกค้ารายใหม่, After Sale Service: ทีม CRM รับ Complain เรื่องผลิตภัฯฑ์ทางช่องทางต่างๆ Call Center / Social Media และบริการเรื่องปัญหาสุขภาพสัตว์จากสัตว์แพทยของบริษัท,Research and Development: การพัฒนาสินค้าที่มีคุณภาพ ตรงกับความต้องการของตลาด มีนวัตกรรมใหม่ๆ ที่คู่แข่งยังทำไม่ได้ หรือทำได้ยาก ในตันทุนที่สามารถแข่งขันได้, Production: การผลิตสินค้าที่มีคุณภาพ เป็นไปตามมาตรฐานและความคาดหวังของผู้บริโภค ใช้เทคโนโลยีการผลิตทีทันสมัยและมีนวัตกรรมใหม่ๆ เพื่อรักษาความเป็นผู้นำในตลาด, Marketing and Sales: การวางกลยุทธการขายและการตลาดเชิงรุก เข้าถึงทุกกลุ่มเป้าหมาย เพื่อครองความเป็นผู้นำในตลาดอาหารสัตว์เลี้ยง',
#    'rootcause': 'rootcause :Market conditions that allow new competitors to enter with relatively low investment or operational requirements: 1.ต้นทุนการผลิตของอาหารปลาคาร์พ กระต่าย นกแก้วและนกสวยงาม ไม่สูงมาก อาจทำให้ผู้ผลิตรายใหม่ หรือรายเดิม สามารถผลิตได้ง่าย\n2.สินค้าบางบริษัท บางแบรนด์ เลือกใช้วัตถุดิบหรือบรรจจุภัณฑ์ ที่จะส่งผลให้เกิดต้นทุนการผลิตที่ต่ำ เพื่อให้สามารถตั้งราคาขายที่ถูกกว่า, Changes in regulations that lower entry barriers or make it easier for new companies to enter the market: อาหารปลาคาร์พ นกแก้วและนกสวยงาม ไม่ต้องจดทะเบียนอาหารสัตว์ ไม่มีหน่วยงานราชการเข้ามาควบคุม มีอิสระในการผลิตและนำเข้าสินค้า สามารถ over claim สินค้าได้ จึงทำให้การออกสินค้าใหม่สามารถสร้างจุดขายสินค้าให้มีคุณภาพดีกว่าสินค้าจริงก็ทำได้โดยอิสระ , Other: สินค้าบางแบรนด์เข้าสู่ตลาดด้วยการเข้าไปจำหน่ายใน platform E-Commerce ช่วยให้เข้าถึงลูกค้าได้เร็ว ง่าย และกว้าง บางแบรนด์อาจจะไม่วางหรือไม่เน้นจำหน่ายในช่องทาง Pet Shop / Modern Trade ซึ่งสามารถลดต้นทุนในเรื่องของ trade margin  ที่ต้องให้ร้านค้า ส่งผลให้ลดต้นทุนสินค้าลงได้ และทำให้สามารถทำราคาพิเศษในช่องทาง E-Commerce ได้ ,Market growth potential or profitability: ตลาดอาหารแมวเติบโตอย่างต่อเนื่องในประเทศไทย, Market conditions that allow new competitors to enter with relatively low investment or operational requirements: มีคู่แข่งเข้ามาในตลาดหลากหลายไม่ว่าจะเป็นผู้ผลิตเอง หรือ จ้างผลิต รวมถึงนำเข้าจากต่างประเทศ โดยเสนอสินค้าที่มีคุณภาพดี มี functional benefit ในราคาที่จับต้องได้,Market growth potential or profitability: -, Market conditions that allow new competitors to enter with relatively low investment or operational requirements: เนื่องจากหลายบริษํทมีกำลังการผลิตที่สามารถผลิตอาหารสัตว์เลี้ยงได้ โดยไม่ต้องลงทุนมากนัก, Other: -'},
#   'target_risk_data': {'risk': 'Product development delay',
#    'risk_desc': 'The planned schedule or timeline for developing new products or improving existing products is extended, resulting in delays in bringing the products to market or in responding to market demands. กำหนดการออกสินค้าใหม่เกิดความล่าช้าเนื่องจากระยะเวลาการยื่นเอกสารและได้รับอนุมัติเลขทะเบียนอาหารสัตว์เพื่อระบุบนฉลากใช้เวลานานกว่า 3 เดือน,ปัจจุบันตลาดอาหารสัตว์เลี้ยงมีอัตราการเติบโตอย่างต่อเนื่อง และมีสินค้าใหม่เข้ามาแข่งขันในตลาดมากขึ้น ประกอบกับ Trend ของ Pet Parents ที่นิยมเลี้ยงสัตว์เลี้ยงเหมือนลูกและสมาชิกในครอบครัว และใส่ใจในการเลือกซื้ออาหารที่มีคุณภาพและช่วยส่งเสริม well being ของสัตว์เลี้ยง ดังนั้นการพัฒนาผลิตภัณฑ์ใหม่ที่ตอบสนองความต้องการของตลาดเพื่อวางจำหน่ายในเวลาที่เหมาะสมและทันกับความต้องการจึงเป็นสิ่งสำคัญ ความล่าช้าในขั้นตอนดังกล่าวอาจส่งผลให้บริษัทสูญเสียความสามารถในการแข่งขันหรือเสียส่วนแบ่งตลาดให้คู่แข่งได้,ความล่าช้าในการพัฒนาสินค้า หรือการปรับปรุงผลิตภัณฑ์เดิม มีผลค่อนข้างมากทำให้ไม่สามารถนำสินค้าเข้าสู่ตลาดเพื่อการแข่งขันกับคู่แข่ง',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Research and Development: -เมื่อมีสินค้าใหม่ออกสู่ตลาดแล้วไม่มีการมอนิเตอร์   ไม่มีการวิเคราะห์ ทดสอบเปรียบเทียบกับสินค้าบริษัท  แล้วถ้าสินค้านั้นคุณภาพใกล้เคียงกับของบริษัทแต่ราคาถูกกว่า อาจส่งผลกระทบให้ลูกค้าเปลี่ยนไปใช้ยี่ห้อคู่แข่งแทน\n-หากไม่มีการมอนิเตอร์คุณภาพสินค้าของบริษัทอยู่เป็นประจำ เช่น การทดสอบความน่ากินไม่ให้แพ้คู่แข่ง อาจทำให้ไม่รู้สถานะของสินค้าตัวเองว่าต้องมีการปรับปรุงหรือแก้ไข อาจส่งผลให้ลูกค้าเปลี่ยนไปใช้ยี่ห้องคู่แข่งแทนได้เช่นเดียวกัน, Production: -หากไม่มีการควบคุมหรือไม่มีขั้นตอนตรวจสอบคุณภาพ เพื่อลดความผิดพลาดในการผลิตให้น้อยที่สุด อาจส่งผลต่อการจำหน่ายสินค้าที่ไม่มีคุณภาพ ซึ่งมีโอกาสที่ลูกค้าจะเปลี่ยนไปใช้สินค้าคู่แข่งแทนได้\n-หากไม่ควบคุมต้นทุนการผลิต อาจส่งผลต่อต้นทุนสินค้าที่สูงและทำให้ไม่สามารถวางกลยุทธ์ทางด้านราคาที่สู้คู่แข่งได้ หรือไม่สามารถทำรายการส่งเสริมการขายเพื่อรักษาส่วนแบ่งการตลาดไว้ได้ \n-หากไม่สามารถปรับแผนการผลิตหรือมีความยืดหยุ่น เพื่อรองรับหรือตอบสนองความต้องการของลูกค้า อาจส่งผลให้ลูกค้าเปลี่ยนไปใช้สินค้าคู่แข่งแทนได้, Marketing and Sales: ฝ่ายการตลาด >>\n-ไม่มีการสำรวจตลาดและไม่รู้ความเคลื่อนไหวของตลาดและคู่แข่ง\n-ไม่มีการวิเคราะห์จุดแข็งจุดอ่อนสินค้าของบริษัทและคู่แข่ง\n-ไม่วางกลยุทธ์ให้ตอบโจทย์ consumers ทุก segment ทั้งตัวสินค้า และการเลือกใช้เครื่องมือสื่อสารทางการตลาด จัด promotion ให้ตอบโจทย์ลูกค้าแต่ละช่องทาง\n\n ฝ่ายขาย >>\n-ไม่มีข้อมูลสินค้าคู่แข่ง และไม่อัพเดตความเคลื่อนไหวของสินค้าคู่แข่งให้กับบริษัท\n-ไม่ใกล้ชิดลูกค้า เพื่อทราบสถานการณ์ในการนำสินค้าใหม่ของคู่แข่งเข้าไปจำหน่ายในร้านค้า  และไม่เตรียมแผนรองรับสำหรับการต่อรองจากร้านค้า\n-ไม่มีการเพิ่ม distribution ขยายเข้าสู่ช่องทางอื่นๆ เพิ่มขึ้น  ไม่วางสินค้าคลอบคลุมทุกช่องทางที่มีสินค้าคู่แข่ง\n\nสิ่งเหล่านี้จะส่งผลกระทบต่อการเสียลูกค้า ยอดขาย และสัดส่วนการตลาดไปให้กับคู่แข่งรายใหม่ที่พร้อมจะวางกลยุทธิ์เพื่อแย่งฐานลูกค้าจากบริษัท ,Research and Development: พัฒนาสินค้าให้มีคุณภาพ ความน่ากิน มากกว่าคู่แข่ง และมีต้นทุน RM ที่สามารถแข่งขันในตลาดได้, Planning: เตรียมสินค้าให้ครบตาม Forecast, Production: ผลิตได้สินค้าตามมาตราฐาน ลดต้นทุนการผลิค, Service: ให้บริการดีกว่าคู่แข่ง สร้างความประทับใจ, Quality Assurance: ควบคุมคุณภาพสินค้าให้ได้ตามมาตราฐาน, Marketing and Sales: มีกลยุทธ์สู้คู่แข่ง รักษาฐานลูกค้าเดิม สร้างลูกค้ารายใหม่, After Sale Service: ทีม CRM รับ Complain เรื่องผลิตภัฯฑ์ทางช่องทางต่างๆ Call Center / Social Media และบริการเรื่องปัญหาสุขภาพสัตว์จากสัตว์แพทยของบริษัท,Research and Development: การพัฒนาสินค้าที่มีคุณภาพ ตรงกับความต้องการของตลาด มีนวัตกรรมใหม่ๆ ที่คู่แข่งยังทำไม่ได้ หรือทำได้ยาก ในตันทุนที่สามารถแข่งขันได้, Production: การผลิตสินค้าที่มีคุณภาพ เป็นไปตามมาตรฐานและความคาดหวังของผู้บริโภค ใช้เทคโนโลยีการผลิตทีทันสมัยและมีนวัตกรรมใหม่ๆ เพื่อรักษาความเป็นผู้นำในตลาด, Marketing and Sales: การวางกลยุทธการขายและการตลาดเชิงรุก เข้าถึงทุกกลุ่มเป้าหมาย เพื่อครองความเป็นผู้นำในตลาดอาหารสัตว์เลี้ยง',
# ...
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. บริการที่ไม่สามารถแข่งขันได้ อาจบังคับให้องค์กรต้องปรับตัวแบบไม่มีแผนระยะยาว ส่งผลกระทบต่อประสิทธิภาพการดำเนินงาน, พนักงานอาจรู้สึกหมดกำลังใจเมื่อเห็นว่าองค์กรไม่มีความสามารถแข่งขันในตลาด และคู่ค้าเห็นว่าองค์กรไม่มีศักยภาพในการแข่งขัน อาจลดความสนใจหรือยุติความร่วมมือ',
#    'risk_level': 1,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: -,After Sale Service: ทีมบริการหลังการขายจะต้องตรวจสอบความพึงพอใจ รวมถึงนำปัญหาของลูกค้า ไปปรับปรุง และแก้ไข ร่วมกับแผนกอื่นที่เกี่ยวข้อง, Transportation: ทีมขนส่งจะต้องให้บริการการจัดส่งอย่างมีคุณภาพ และรวดเร็ว, Marketing and Sales: ทีมฝ่ายขายจะต้องสื่อสารสิ่งที่ลูกค้าต้องการ หรือเงื่อนไขพิเศษ ให้กับแผนกอื่นที่เกี่ยวข้อง เพื่อให้เข้าใจ และปฏิบัติตาม',
#    'rootcause': "rootcause :Constraints on frontline staff's authority, discretion, or empowerment to resolve customer issues or complaints promptly and effectively: -, Fail to provide accurate, clear, or complete information to customers regarding pricing, terms of sale, product information, privacy policies, warranties, and other relevant details: -, Negative interactions with service personnel characterized by rudeness, apathy, or incompetence: -, Lack of timely, clear, or effective communication with customers regarding service inquiries, updates, or resolutions: -, Delays, errors, or inconsistencies in addressing customer inquiries, requests, or complaints: -,Customer Relationship Management (CRM) systems that are poorly integrated with other business systems (like sales, marketing, or operations): การติดตามปัญหา และแนวทางการแก้ไขภายในต้องรวดเร็ว แล้วต่อเนื่อง เพื่อให้ตรงกับสิ่งที่ลูกค้าต้องการ, Delays, errors, or inconsistencies in addressing customer inquiries, requests, or complaints: ความคาดหวังของลูกค้า คือ สามารถจัดส่งได้รวดเร็ว, ครบถ้วน และสินค้าสภาพดี, Lack of timely, clear, or effective communication with customers regarding service inquiries, updates, or resolutions: การตอบสนองเรื่องการแก้ไขปัญหาต้องรวดเร็ว และตรวจสอบ พร้อมแจ้งกลับลูกค้าให้ถูกต้อง และตรงประเด็น"}},
#  {'source': 'risk_lotus_south_7',
#   'target': 'risk_lotus_south_33',
#   'weight': 2,
#   'raw_weight': np.float64(95.81584442942986),
#   'color': 'rgb(201, 203, 207)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Delayed product delivery',
#    'risk_desc': 'Delayed product delivery refers to the risk of experiencing delays in delivering goods or materials to customers or recipients beyond the expected or agreed-upon timeframe. 商品缺货、O2O配送不及时等导致顾客买不到或延迟送达，顾客体验下降。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Procurement: 商品部, Marketing and Sales: O2O、各门店',
#    'rootcause': 'rootcause :Other: 订货不足、供应商管理、O2O配送能力'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. 超市的服务水平一般，不能吸引顾客复购。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Procurement: 商品部, Marketing and Sales: O2O、各门店',
#    'rootcause': 'rootcause :Other: 订货不足、供应商管理、O2O配送能力'}},
#  {'source': 'risk_lotus_south_14',
#   'target': 'risk_lotus_south_33',
#   'weight': 2,
#   'raw_weight': np.float64(99.1021885874942),
#   'color': 'rgb(201, 203, 207)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Inappropriate price setting',
#    'risk_desc': 'Organization sets prices for its goods or services that do not accurately reflect market demand, production costs, or competitive dynamics, leading to negative consequences for both the organization and its customers. 商品或服务设定的价格未能准确反映市场需求、生产成本或竞争动态，从而影响销售和利润。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Procurement: 商品部',
#    'rootcause': 'rootcause :Lack of comprehensive market research to understand customer preferences: 市场调研不足或竞争分析不充分, Lack of clear pricing strategies: 定价策略不合理'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. 超市的服务水平一般，不能吸引顾客复购。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Procurement: 商品部',
#    'rootcause': 'rootcause :Lack of comprehensive market research to understand customer preferences: 市场调研不足或竞争分析不充分, Lack of clear pricing strategies: 定价策略不合理'}},
#  {'source': 'risk_lotus_south_17',
#   'target': 'risk_lotus_south_31',
#   'weight': 4,
#   'raw_weight': np.float64(101.68751564120852),
#   'color': 'rgb(169, 169, 169)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Intense market competition',
#    'risk_desc': 'A highly competitive market environment where businesses within the same industry are fiercely competing for customers and market share, potentially leading to decreased profitability and market share. 因竞争对手进入、竞争方法变化等，导致市场占有率下降的风险。',
#    'risk_level': 3,
#    'risk_cat': 'Strategic Risk',
#    'process': 'process :Marketing and Sales: 市场部和O2O',
#    'rootcause': 'rootcause :Other: 竞争激烈；未能适应市场趋势。'},
#   'target_risk_data': {'risk': 'Uncompetitive e-commerce distribution channels',
#    'risk_desc': 'The risk of selling products or services through inefficient online channels, leading to a decline in competitiveness and market access. 超市的线上渠道体验差，界面不友好，导致顾客流失。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: 市场部和O2O',
#    'rootcause': 'rootcause :Other: 竞争激烈；未能适应市场趋势。'}},
#  {'source': 'risk_lotus_south_17',
#   'target': 'risk_lotus_south_32',
#   'weight': 4,
#   'raw_weight': np.float64(109.58834309337423),
#   'color': 'rgb(169, 169, 169)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Intense market competition',
#    'risk_desc': 'A highly competitive market environment where businesses within the same industry are fiercely competing for customers and market share, potentially leading to decreased profitability and market share. 因竞争对手进入、竞争方法变化等，导致市场占有率下降的风险。',
#    'risk_level': 3,
#    'risk_cat': 'Strategic Risk',
#    'process': 'process :Marketing and Sales: 市场部和O2O',
#    'rootcause': 'rootcause :Other: 竞争激烈；未能适应市场趋势。'},
#   'target_risk_data': {'risk': 'Uncompetitive product',
#    'risk_desc': 'The risk of offering a product that fails to match or exceed the quality, features, and innovation provided by competitors, resulting in decreased market share, customer satisfaction, or profitability. 超市销售的产品与其他超市相比缺乏独特性，消费者无法感受到差异化价值。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: 市场部和O2O',
#    'rootcause': 'rootcause :Other: 竞争激烈；未能适应市场趋势。'}},
#  {'source': 'risk_lotus_south_17',
#   'target': 'risk_lotus_south_33',
#   'weight': 4,
#   'raw_weight': np.float64(107.04885135123246),
#   'color': 'rgb(169, 169, 169)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Intense market competition',
#    'risk_desc': 'A highly competitive market environment where businesses within the same industry are fiercely competing for customers and market share, potentially leading to decreased profitability and market share. 因竞争对手进入、竞争方法变化等，导致市场占有率下降的风险。',
#    'risk_level': 3,
#    'risk_cat': 'Strategic Risk',
#    'process': 'process :Marketing and Sales: 市场部和O2O',
#    'rootcause': 'rootcause :Other: 竞争激烈；未能适应市场趋势。'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. 超市的服务水平一般，不能吸引顾客复购。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: 市场部和O2O',
#    'rootcause': 'rootcause :Other: 竞争激烈；未能适应市场趋势。'}},
#  {'source': 'risk_lotus_south_20',
#   'target': 'risk_lotus_south_33',
#   'weight': 2,
#   'raw_weight': np.float64(96.50830999620139),
#   'color': 'rgb(201, 203, 207)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Low bargaining power with suppliers',
#    'risk_desc': 'Low bargaining power with suppliers can lead to results in trading disadvantages such as higher costs, compromised quality, and reduced flexibility in terms of delivery and service terms. 由于门店数减少，与供应商谈判时购买总量减少，无法获得更优惠的价格或灵活的付款条件，导致成本上升，利润减少。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Procurement: 商品部',
#    'rootcause': 'rootcause :Small purchase volumes: 门店销售体量下降，缺乏对供应商的议价筹码。'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. 超市的服务水平一般，不能吸引顾客复购。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Procurement: 商品部',
#    'rootcause': 'rootcause :Small purchase volumes: 门店销售体量下降，缺乏对供应商的议价筹码。'}},
#  {'source': 'risk_lotus_south_22',
#   'target': 'risk_lotus_south_33',
#   'weight': 2,
#   'raw_weight': np.float64(97.82929821234838),
#   'color': 'rgb(201, 203, 207)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'New business execution failure',
#    'risk_desc': 'The risk that a new business may not achieve its business goals or may not be able to continue operations as planned, potentially leading to losses, business closure, or bankruptcy. These risks can arise from several factors. 超市尝试推出新的业务模式，但由于执行、能力、技术和市场推广不足等原因，未能达到预期效果，从而影响经营。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: 市场部',
#    'rootcause': 'rootcause :Lack of market understanding: Inability to attract new customers or losing current customers: 市场调研不足、业务能力或执行力不到位、技术准备不充分或推广策略不当。'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. 超市的服务水平一般，不能吸引顾客复购。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: 市场部',
#    'rootcause': 'rootcause :Lack of market understanding: Inability to attract new customers or losing current customers: 市场调研不足、业务能力或执行力不到位、技术准备不充分或推广策略不当。'}},
#  {'source': 'risk_lotus_south_28',
#   'target': 'risk_lotus_south_33',
#   'weight': 2,
#   'raw_weight': np.float64(98.90073144880546),
#   'color': 'rgb(201, 203, 207)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Poor product quality',
#    'risk_desc': "Products that do not meet the company's standards or specifications have led to customer dissatisfaction, complaints, and business losses. 销售商品被发现存在质量问题，导致顾客投诉并要求退货，超市声誉受损。",
#    'risk_level': 1,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Quality Assurance: QAQC',
#    'rootcause': 'rootcause :Inadequate or ineffective quality control processes: 供应商质量控制不严或进货检验流程不完善。'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. 超市的服务水平一般，不能吸引顾客复购。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Quality Assurance: QAQC',
#    'rootcause': 'rootcause :Inadequate or ineffective quality control processes: 供应商质量控制不严或进货检验流程不完善。'}},
#  {'source': 'risk_lotus_south_31',
#   'target': 'risk_lotus_south_33',
#   'weight': 4,
#   'raw_weight': np.float64(118.61333782428716),
#   'color': 'rgb(169, 169, 169)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Uncompetitive e-commerce distribution channels',
#    'risk_desc': 'The risk of selling products or services through inefficient online channels, leading to a decline in competitiveness and market access. 超市的线上渠道体验差，界面不友好，导致顾客流失。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: O2O部',
#    'rootcause': 'rootcause :Lack of effective digital marketing strategies, such as search engine optimization (SEO), pay-per-click (PPC) advertising, or social media marketing: 对数字化转型的投入不足，技术开发和运营能力有限。'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. 超市的服务水平一般，不能吸引顾客复购。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Marketing and Sales: O2O部',
#    'rootcause': 'rootcause :Lack of effective digital marketing strategies, such as search engine optimization (SEO), pay-per-click (PPC) advertising, or social media marketing: 对数字化转型的投入不足，技术开发和运营能力有限。'}},
#  {'source': 'risk_lotus_south_32',
#   'target': 'risk_lotus_south_33',
#   'weight': 6,
#   'raw_weight': np.float64(178.09414219831277),
#   'color': 'rgb(128, 128, 128)',
#   'arrow_weight': 'none',
#   'do_not_cal_weight': False,
#   'edge_relation_reason': '',
#   'source_risk_data': {'risk': 'Uncompetitive product',
#    'risk_desc': 'The risk of offering a product that fails to match or exceed the quality, features, and innovation provided by competitors, resulting in decreased market share, customer satisfaction, or profitability. 超市销售的产品与其他超市相比缺乏独特性，消费者无法感受到差异化价值。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Procurement: 商品部',
#    'rootcause': 'rootcause :Other: 供应链管理不足，未能与优质供应商建立合作关系；产品选品策略缺乏市场调研和创新。'},
#   'target_risk_data': {'risk': 'Uncompetitive service',
#    'risk_desc': 'The risk of providing a service that fails to match or exceed the quality, features, and innovation provided by competitors, which can occur due to poor service delivery, or failure to keep up with industry best practices, leading to a decline in customer satisfaction, loyalty, or retention. 超市的服务水平一般，不能吸引顾客复购。',
#    'risk_level': 2,
#    'risk_cat': 'Operational Risk',
#    'process': 'process :Procurement: 商品部',
#    'rootcause': 'rootcause :Other: 供应链管理不足，未能与优质供应商建立合作关系；产品选品策略缺乏市场调研和创新。'}}]

# %%
# raise

# %%
from test_dynamic_pydantic import create_dynamic_pydantic_model
import pydantic
from typing import Type, Literal
import json

# old
# def create_edge_relationship_model(
#     risk_a: str, risk_b: str
# ) -> Type[pydantic.BaseModel]:
#     """
#     Creates an EdgeRelationship model with specific risk names.

#     Args:
#         risk_a (str): Name of the first risk
#         risk_b (str): Name of the second risk

#     Returns:
#         Type[pydantic.BaseModel]: A Pydantic model class for the edge relationship
#     """
#     relationship_choices_dict = {
#         f"{risk_a} lead to {risk_b}": f"{risk_a} is the cause and {risk_b} is the effect. Changes in {risk_a} directly influence or trigger {risk_b}.",
#         f"{risk_b} lead to {risk_a}": f"{risk_b} is the cause and {risk_a} is the effect. Changes in {risk_b} directly influence or trigger {risk_a}.",
#         "be a cause to each other": f"Both risks influence each other in a bidirectional relationship. Changes in either risk can affect the other.",
#         "correlated": f"The risks tend to occur together or show similar patterns, but there may not be a direct causal relationship between them.",
#         "no relationship": f"There is no significant connection or influence between these risks. They operate independently of each other.",
#     }
#     schema_definition_dict = {
#         "model_name": "EdgeRelationship",
#         "fields": {
#             "classification": (
#                 Literal[
#                     f"{risk_a} lead to {risk_b}",
#                     f"{risk_b} lead to {risk_a}",
#                     "be a cause to each other",
#                     "correlated",
#                     "no relationship",
#                 ],
#                 pydantic.Field(
#                     description=f"Select the type of relationship between {risk_a} and {risk_b}. Available choices: {json.dumps(relationship_choices_dict)}",
#                 ),
#             ),
#             "reason": (
#                 str,
#                 pydantic.Field(
#                     description="Brief reason for the relationship classification in 1-3 sentences"
#                 ),
#             ),
#         },
#     }

#     return create_dynamic_pydantic_model(
#         schema_definition_dict["model_name"],
#         schema_definition_dict["fields"],
#     )


# old#2
# def create_edge_relationship_model(
#     risk_a: str, risk_b: str
# ) -> Type[pydantic.BaseModel]:
#     """
#     Creates an EdgeRelationship model with specific risk names.

#     Args:
#         risk_a (str): Name of the first risk
#         risk_b (str): Name of the second risk

#     Returns:
#         Type[pydantic.BaseModel]: A Pydantic model class for the edge relationship
#     """
#     relationship_choices_dict = {
#         f"cause_effect": f"{risk_a} is the cause and {risk_b} is the effect. Changes in {risk_a} directly influence or trigger {risk_b}.",
#         f"effect_cause": f"{risk_b} is the cause and {risk_a} is the effect. Changes in {risk_b} directly influence or trigger {risk_a}.",
#         "bidirectional_relationship": f"Both risks influence each other in a bidirectional relationship. Changes in either risk can affect the other.",
#         "correlated": f"The risks tend to occur together or show similar patterns, but there may not be a direct causal relationship between them.",
#         "no_relationship": f"There is no significant connection or influence between these risks. They operate independently of each other.",
#     }
#     schema_definition_dict = {
#         "model_name": "EdgeRelationship",
#         "fields": {
#             "classification": (
#                 Literal[
#                     "cause_effect",
#                     "effect_cause",
#                     "bidirectional_relationship",
#                     "correlated",
#                     "no_relationship",
#                 ],
#                 pydantic.Field(
#                     description=f"Select the type of relationship between {risk_a} and {risk_b}. Available choices: {json.dumps(relationship_choices_dict)}",
#                 ),
#             ),
#             "reason": (
#                 str,
#                 pydantic.Field(
#                     description="Brief reason for the relationship classification in 1-3 sentences"
#                 ),
#             ),
#         },
#     }

#     return create_dynamic_pydantic_model(
#         schema_definition_dict["model_name"],
#         schema_definition_dict["fields"],
#     )


def create_edge_relationship_model(
    risk_a: str, risk_b: str
) -> Type[pydantic.BaseModel]:
    """
    Creates an EdgeRelationship model with specific risk names.

    Args:
        risk_a (str): Name of the first risk
        risk_b (str): Name of the second risk

    Returns:
        Type[pydantic.BaseModel]: A Pydantic model class for the edge relationship
    """

    schema_definition_dict = {
        "model_name": "EdgeRelationship",
        "fields": {
            f"{risk_a} lead to {risk_b}": (
                bool,
                pydantic.Field(
                    description=f"{risk_a} is the cause and {risk_b} is the effect.",
                ),
            ),
            f"{risk_a} lead to {risk_b} reason": (
                str,
                pydantic.Field(
                    description="Brief reason for the relationship classification in 1-3 sentences",
                ),
            ),
            f"{risk_b} lead to {risk_a}": (
                bool,
                pydantic.Field(
                    description=f"{risk_b} is the cause and {risk_a} is the effect.",
                ),
            ),
            f"{risk_b} lead to {risk_a} reason": (
                str,
                pydantic.Field(
                    description="Brief reason for the relationship classification in 1-3 sentences",
                ),
            ),
        },
    }

    return create_dynamic_pydantic_model(
        schema_definition_dict["model_name"],
        schema_definition_dict["fields"],
    )


sample_model = create_edge_relationship_model(
    risk_a="Intense market competition", risk_b="New competitor into the market"
)
sample_model.model_json_schema()
# Out:
# {'properties': {'Intense market competition lead to New competitor into the market': {'description': 'Intense market competition is the cause and New competitor into the market is the effect.',
#    'title': 'Intense Market Competition Lead To New Competitor Into The Market',
#    'type': 'boolean'},
#   'Intense market competition lead to New competitor into the market reason': {'description': 'Brief reason for the relationship classification in 1-3 sentences',
#    'title': 'Intense Market Competition Lead To New Competitor Into The Market Reason',
#    'type': 'string'},
#   'New competitor into the market lead to Intense market competition': {'description': 'New competitor into the market is the cause and Intense market competition is the effect.',
#    'title': 'New Competitor Into The Market Lead To Intense Market Competition',
#    'type': 'boolean'},
#   'New competitor into the market lead to Intense market competition reason': {'description': 'Brief reason for the relationship classification in 1-3 sentences',
#    'title': 'New Competitor Into The Market Lead To Intense Market Competition Reason',
#    'type': 'string'}},
#  'required': ['Intense market competition lead to New competitor into the market',
#   'Intense market competition lead to New competitor into the market reason',
#   'New competitor into the market lead to Intense market competition',
#   'New competitor into the market lead to Intense market competition reason'],
#  'title': 'EdgeRelationship',
#  'type': 'object'}

# %%
from typing import Any, Dict, Optional
from langchain_openai import ChatOpenAI


def get_llm(provider: str = "openai", model_name: Optional[str] = None):
    """Initialize an LLM based on the provider."""
    if provider == "openai":
        model = model_name if model_name else "gpt-4o-mini"
        temperature = None if model_name in ["o3-mini"] else 0.1
        return ChatOpenAI(model=model, temperature=temperature)

    else:
        raise ValueError(f"Unsupported provider: {provider}")


# test the model
# llm_4omini = get_llm("openai")
# llm_4omini.invoke("Hello, how are you?")
llm_41mini = get_llm("openai", "gpt-4.1-mini")
llm_41mini.invoke("Hello, how are you?")
# llm_o3mini = get_llm("openai", "o3-mini")
# llm_o3mini.invoke("Hello, how are u?")
# Out:
# AIMessage(content="Hello! I'm doing great, thank you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 13, 'total_tokens': 29, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_6f2eabb9a5', 'id': 'chatcmpl-BjNChymGDsFQ9rnlmY76WSHuAfcWT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6caf937c-adc7-42f6-9c4e-9d5fbf9eec89-0', usage_metadata={'input_tokens': 13, 'output_tokens': 16, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain.prompts.chat import ChatPromptTemplate
from typing import Any, Dict, Optional
from langchain_openai import ChatOpenAI
from langchain.output_parsers import PydanticOutputParser


def classify_edge_relationship(
    model_name: str, risk_a: Dict[str, Any], risk_b: Dict[str, Any]
) -> dict:
    print(risk_a.keys())
    risk_a_str = "\n".join([f"- {k}: {v}" for k, v in risk_a.items()])
    print(risk_a_str)
    raise
    try:
        llm = get_llm(model_name=model_name)
        EdgeRelationship = create_edge_relationship_model(
            risk_a=risk_a["risk"], risk_b=risk_b["risk"]
        )
        parser = PydanticOutputParser(pydantic_object=EdgeRelationship)

        # Format input data for the prompt
        risk_a_str = "\n".join([f"- {k}: {v}" for k, v in risk_a.items()])
        risk_b_str = "\n".join([f"- {k}: {v}" for k, v in risk_b.items()])
        risk_a_name = risk_a["risk"]
        risk_b_name = risk_b["risk"]
        prompt = ChatPromptTemplate.from_messages(
            [
                (
                    "system",
                    f"""You are an expert in risk assessment and business analysis. Your task is to classify the relationship between two risks based on their descriptions and context. your analysis will be from the perspective of business owner.

Analyze the provided data for {risk_a_name} and {risk_b_name} and determine the relationship type.



Provide the classification and a brief reason in the specified pydantic format.

""",
                ),
                (
                    "human",
                    f"Please classify the relationship between {risk_a_str} and  {risk_b_str}.",
                ),
            ]
        )
        structured_llm = llm.with_structured_output(EdgeRelationship)
        chain = prompt | structured_llm

        # Invoke the chain
        result = chain.invoke({})
        # print(f"{risk_a_str=}")
        # Return the relationship field from the parsed model
        return result

    except Exception as e:
        print(f"Error classifying edge relationship: {str(e)}")
        raise Exception(f"Error classifying edge relationship: {str(e)}")

# %%
len(edge_data_list), company
# Out:
# (18, 'PCG')

# %%
node_data_df = pd.DataFrame(node_data_list)
print(node_data_df.columns)
relation_counter = Counter()
relation_result = {}
all_result_list = []
for model_name in ["o3-mini", "gpt-4o-mini", "gpt-4.1-mini"]:
    for edge_data in edge_data_list:
        source_risk_id = edge_data["source"]
        # node_company = ("_").join(source_risk_id.split("_")[1:-1])
        # print(f"{node_company=}")
        # if node_company != company:
        #     continue
        target_risk_id = edge_data["target"]
        source_risk_name = node_data_df[node_data_df["id"] == source_risk_id][
            "label"
        ].values[0]
        target_risk_name = node_data_df[node_data_df["id"] == target_risk_id][
            "label"
        ].values[0]
        print(f"\t{source_risk_name=}")
        print(f"\t{target_risk_name=}")

        risk_a = get_risk_data_from_risk_name(
            source_risk_name, raw_risk_selected_data_list
        )
        risk_b = get_risk_data_from_risk_name(
            target_risk_name, raw_risk_selected_data_list
        )
        print("here")
        print(risk_a, risk_b)
        edge_relationship_a_b = classify_edge_relationship(
            model_name=model_name, risk_a=risk_a, risk_b=risk_b
        )
        edge_relationship_b_a = classify_edge_relationship(
            model_name=model_name, risk_a=risk_b, risk_b=risk_a
        )

        # all_result_list.append(
        #     {
        #         "model_name": model_name,
        #         "source_risk_name": source_risk_name,
        #         "target_risk_name": target_risk_name,
        #         "edge_relationship_a_b_classification": edge_relationship_a_b.model_dump(
        #             mode="json"
        #         )[
        #             "classification"
        #         ],
        #         "edge_relationship_a_b_reason": edge_relationship_a_b.model_dump(
        #             mode="json"
        #         )["reason"],
        #         "edge_relationship_b_a_classification": edge_relationship_b_a.model_dump(
        #             mode="json"
        #         )[
        #             "classification"
        #         ],
        #         "edge_relationship_b_a_reason": edge_relationship_b_a.model_dump(
        #             mode="json"
        #         )["reason"],
        #     }
        # )
        def postprocess_edge_relationship(
            edge_relationship_dict, source_risk_name, target_risk_name, prefix
        ):
            new_dict = {}
            for k, v in edge_relationship_dict.items():
                if k.find(source_risk_name) == 0:
                    if k.find("reason") != -1:
                        new_k = "cause_effect_reason"
                    else:
                        new_k = "cause_effect"
                elif k.find(target_risk_name) == 0:
                    if k.find("reason") != -1:
                        new_k = "effect_cause_reason"
                    else:
                        new_k = "effect_cause"
                else:
                    raise
                new_dict[prefix + new_k] = v
            return new_dict

        edge_relationship_a_b_dict = edge_relationship_a_b.model_dump(mode="json")
        final_relationship_a_b = postprocess_edge_relationship(
            edge_relationship_a_b_dict, source_risk_name, target_risk_name, "a_b_"
        )
        edge_relationship_b_a_dict = edge_relationship_b_a.model_dump(mode="json")
        final_relationship_b_a = postprocess_edge_relationship(
            edge_relationship_b_a_dict, target_risk_name, source_risk_name, "b_a_"
        )
        all_result_list.append(
            {
                "model_name": model_name,
                "source_risk_name": source_risk_name,
                "target_risk_name": target_risk_name,
                **final_relationship_a_b,
                **final_relationship_b_a,
            }
        )

# pickle.dump(new_edge_data_dict, open(edge_relationship_path, "wb"))
# Out:
# Index(['id', 'label', 'raw_size', 'size_level', 'size', 'color', 'risk_level',
#        'story'],
#       dtype='object')
# 	source_risk_name='Intense market competition'
# 	target_risk_name='New competitor into the market'
# here
# {'risk': 'Intense market competition', 'risk_desc': 'A highly competitive market environment where businesses within the same industry are fiercely competing for customers and market share, potentially leading to decreased profitability and market share. ตลาดอาหารสุนัขมีการเติบโตอย่างต่อเนื่อง มีสินค้าใหม่และ Brand ใหม่เกิดขึ้นในตลาดจำนวนมาก และหลายแบรนด์หลายบริษัทมีการทำการตลาดเชิงรุก หรืออาจจะมีการใช้กลยุทธการขายสินค้าราคาถูกมากในกลุ่มสินค้าที่ price sensitive เพื่อแย่งลูกค้าและส่วนแบ่งทางการตลาด ส่งผลให้ทาง PCG อาจจะไม่สามารถทำยอดขาย อัตราการเติบโต รวมถึงส่วนแบ่งตลาด ได้ตามที่วางแผนไว้,สถานการณ์ที่ธุรกิจต่างๆในอุตสาหกรรมเดียวกันมีการแข่งขันที่รุนแรง ซึ่งอาจส่งผลกระทบต่อกำไรและส่วนแบ่งตลาด,ความเสี่ยงจากการแข่งขันในตลาดบนช่องทางออนไลน์และอีคอมเมิร์ซ การแข่งขันที่รุนแรงจากแบรนด์เดิมและคู่แข่งรายใหม่ อาจส่งผลต่อยอดขายและการรักษาฐานลูกค้า,ตลาดอาหารสัตว์เลี้ยงมีอัตราการเติบโตต่อเนื่องทุกปี  ทำให้เป็นแรงจูงใจให้ผู้ผลิตและผู้จัดจำหน่ายสินค้ากลุ่มอื่นๆ ทั้งรายเก่ามีการขยายธุรกิจมากขึ้น และรายใหม่ๆเข้ามาในธุรกิจนี้มากขึ้นด้วย,ขาดกิจกรรมที่ตอบสนองต่อความต้องการของลูกค้า,มีคู่แข่งรายใหม่เข้าสู่ตลาดหรือคู่แข่งเดิมใช้กลยุทธ์การตลาดเชิงรุก ส่งผลให้ยอดขายไม่เป็นไปตามเป้าหมาย', 'rootcause': 'rootcause :High number of competitors in the market: ธุรกิจอาหารสัตว์เลี้ยงเติบโตมากอย่างต่อเนื่องทำให้ผู้ผลิตอาหารอื่นๆเข้ามาในตลาดนี้มากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยที่มีต้นทุนต่ำได้เปรียบในการแข่นขันด้านราคา,High number of competitors in the market: ตลาดอาหารแมวในประเทศไทยเติบโตอย่างต่อเนื่อง มีคู่แข่งเข้ามาในตลาดจำนวนมากทั้งอาหารเม็ดและอาหารเปียก , Aggressive pricing strategies: คู่แข่งใช้กลยุทธ์ราคาถูกในการเข้าตลาด ได้แก่ สินค้าเป็นกลุ่มที่ดูเรื่อง Product benefits เป็นกลุ่ม Premium ตั้งราคาเท่ากลุ่ม Standard ให้ดูว่าจับต้องได้ง่าย หรือตลาดล่างที่เติบโตมาขึ้น ก็มีการเข้าตลาดด้วยการใช้กลยุทธ์ทำราคาถูกเช่นกัน,Aggressive pricing strategies: ราคาหรือโปรโมชั่นที่จำหน่ายในงานกิจกรรมต่างๆ สู้คู่แข่งขันไม่ได้,High number of competitors in the market: การแข่งขันที่รุนแรงจากจำนวนคู่แข่งที่เพิ่มขึ้นอาจส่งผลให้สูญเสียลูกค้า รายได้ และส่วนแบ่งทางการตลาด, Aggressive pricing strategies: การลดราคาหนักในตลาด รวมถึงการส่งสินค้าฟรี และมีโปรโมชั่นพิเศษอย่างต่อเนื่อง,High number of competitors in the market: ผู้ผลิตทั้ง Branded & OEM มีจำนวนมากขึ้น และมีการนำเข้าสินค้าจากต่างประเทศมากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยและบริษัทที่ทำธุรกิจจ้างผลิตที่มีต้นทุนการผลิตต่ำได้เปรียบในการแข่งขันด้านราคา, Other: กำลังซื้อของผู้บริโภคลดลง และการตัดสินใจซื้อยากขึ้น,High number of competitors in the market: จำนวนคู่แข่งในตลาดมีจำนวนมากทั้งในส่วนของจำนวน Manufacturer และจำนวน Brand , Aggressive pricing strategies: หลาย Brand ในตลาดกลุ่ม Economy และ Super Economy ใช้กลยุทธการแข่งขันด้านราคาเป็นหลัก ซึ่งทาง PCG อาจจะไม่สามารถแข่งขันโดยการใช้กลุยุทธการทำราคาถูกมากได้ , Other: คู่แข่งมีการทำตลาดอย่างเข้มข้นมากขึ้นทั้งส่วนของการใช้ Media การทำโปรโมชั่น และกิจกรรมต่างๆ ที่เข้าถึงผู้บริโภค รวมถึงใช้กลยุทธการตัดราคาในสินค้ากลุ่มที่ price sensitive', 'process': 'process :Marketing and Sales: จัดโปรโมชั่นพิเศษเฉพาะงาน,Research and Development: พัฒณาสูตรให้มีคุณภาพดีเท่าเดิม แต่สามารถลดต้นทุน RM ได้, Production: ผลิตได้มีประสิทธิภาพ สามารถลดต้นทุนการผลิตได้, Marketing and Sales: จัดรายการส่งเสริมการขายให้สามารถแข่งขันและกันคู่แข่งในตลาดโดยเฉพาะรายใหม่ที่เข้ามา และ\nจะต้องพัฒนาและออกผลิตภัณฑ์ใหม่ให้ได้ตามแผนที่วางไว้,Planning: ต้องใช้ข้อมูลด้านการตลาดและพฤติกรรมของลูกค้าเพื่อวางแผนทางการตลาดและกำหนดกลุ่มเป้าหมาย รวมถึงการใช้สื่อโฆษณาต่างๆให้เข้าถึงเป้าหมายที่ตรงกลุ่มชัดเจน วิเคราะห์กลยุทธ์ทางการตลาดและผลักดันให้ทันกับการแข่งขันในตลาดที่สูงในปัจจุบัน โดยเฉพาะบนช่องทางอีคอมเมิร์ซ  รวมถึงการประเมิณจัดสรรค่าใช้จ่าย ทั้งค่าโฆษณาและค่าใช้จ่ายอื่นๆ ให้อยู่ในความคุ้มค่าสูงสุดตามงบประมาณที่วางแผนไว้, Marketing and Sales: บริหารงานขาย ด้านราคาสินค้า , โปรโมชั่น และค่าใช้จ่ายๆ ต่างให้ตอบโจทย์และคุ้มค่ามากที่สุดจากการวัดที่ผลลัพธ์ โดยเปรียบเทียบกลยุทธ์เพิ่มเติมกับคู่แข่งในตลาด โฟกัสเป้าหมายและการเติบโตของช่องทางการขายในแต่ละแพลตฟอร์ม,Procurement: จัดซื้อสินค้าและวัตถุ ...
# dict_keys(['risk', 'risk_desc', 'rootcause', 'process'])
# - risk: Intense market competition
# - risk_desc: A highly competitive market environment where businesses within the same industry are fiercely competing for customers and market share, potentially leading to decreased profitability and market share. ตลาดอาหารสุนัขมีการเติบโตอย่างต่อเนื่อง มีสินค้าใหม่และ Brand ใหม่เกิดขึ้นในตลาดจำนวนมาก และหลายแบรนด์หลายบริษัทมีการทำการตลาดเชิงรุก หรืออาจจะมีการใช้กลยุทธการขายสินค้าราคาถูกมากในกลุ่มสินค้าที่ price sensitive เพื่อแย่งลูกค้าและส่วนแบ่งทางการตลาด ส่งผลให้ทาง PCG อาจจะไม่สามารถทำยอดขาย อัตราการเติบโต รวมถึงส่วนแบ่งตลาด ได้ตามที่วางแผนไว้,สถานการณ์ที่ธุรกิจต่างๆในอุตสาหกรรมเดียวกันมีการแข่งขันที่รุนแรง ซึ่งอาจส่งผลกระทบต่อกำไรและส่วนแบ่งตลาด,ความเสี่ยงจากการแข่งขันในตลาดบนช่องทางออนไลน์และอีคอมเมิร์ซ การแข่งขันที่รุนแรงจากแบรนด์เดิมและคู่แข่งรายใหม่ อาจส่งผลต่อยอดขายและการรักษาฐานลูกค้า,ตลาดอาหารสัตว์เลี้ยงมีอัตราการเติบโตต่อเนื่องทุกปี  ทำให้เป็นแรงจูงใจให้ผู้ผลิตและผู้จัดจำหน่ายสินค้ากลุ่มอื่นๆ ทั้งรายเก่ามีการขยายธุรกิจมากขึ้น และรายใหม่ๆเข้ามาในธุรกิจนี้มากขึ้นด้วย,ขาดกิจกรรมที่ตอบสนองต่อความต้องการของลูกค้า,มีคู่แข่งรายใหม่เข้าสู่ตลาดหรือคู่แข่งเดิมใช้กลยุทธ์การตลาดเชิงรุก ส่งผลให้ยอดขายไม่เป็นไปตามเป้าหมาย
# - rootcause: rootcause :High number of competitors in the market: ธุรกิจอาหารสัตว์เลี้ยงเติบโตมากอย่างต่อเนื่องทำให้ผู้ผลิตอาหารอื่นๆเข้ามาในตลาดนี้มากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยที่มีต้นทุนต่ำได้เปรียบในการแข่นขันด้านราคา,High number of competitors in the market: ตลาดอาหารแมวในประเทศไทยเติบโตอย่างต่อเนื่อง มีคู่แข่งเข้ามาในตลาดจำนวนมากทั้งอาหารเม็ดและอาหารเปียก , Aggressive pricing strategies: คู่แข่งใช้กลยุทธ์ราคาถูกในการเข้าตลาด ได้แก่ สินค้าเป็นกลุ่มที่ดูเรื่อง Product benefits เป็นกลุ่ม Premium ตั้งราคาเท่ากลุ่ม Standard ให้ดูว่าจับต้องได้ง่าย หรือตลาดล่างที่เติบโตมาขึ้น ก็มีการเข้าตลาดด้วยการใช้กลยุทธ์ทำราคาถูกเช่นกัน,Aggressive pricing strategies: ราคาหรือโปรโมชั่นที่จำหน่ายในงานกิจกรรมต่างๆ สู้คู่แข่งขันไม่ได้,High number of competitors in the market: การแข่งขันที่รุนแรงจากจำนวนคู่แข่งที่เพิ่มขึ้นอาจส่งผลให้สูญเสียลูกค้า รายได้ และส่วนแบ่งทางการตลาด, Aggressive pricing strategies: การลดราคาหนักในตลาด รวมถึงการส่งสินค้าฟรี และมีโปรโมชั่นพิเศษอย่างต่อเนื่อง,High number of competitors in the market: ผู้ผลิตทั้ง Branded & OEM มีจำนวนมากขึ้น และมีการนำเข้าสินค้าจากต่างประเทศมากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยและบริษัทที่ทำธุรกิจจ้างผลิตที่มีต้นทุนการผลิตต่ำได้เปรียบในการแข่งขันด้านราคา, Other: กำลังซื้อของผู้บริโภคลดลง และการตัดสินใจซื้อยากขึ้น,High number of competitors in the market: จำนวนคู่แข่งในตลาดมีจำนวนมากทั้งในส่วนของจำนวน Manufacturer และจำนวน Brand , Aggressive pricing strategies: หลาย Brand ในตลาดกลุ่ม Economy และ Super Economy ใช้กลยุทธการแข่งขันด้านราคาเป็นหลัก ซึ่งทาง PCG อาจจะไม่สามารถแข่งขันโดยการใช้กลุยุทธการทำราคาถูกมากได้ , Other: คู่แข่งมีการทำตลาดอย่างเข้มข้นมากขึ้นทั้งส่วนของการใช้ Media การทำโปรโมชั่น และกิจกรรมต่างๆ ที่เข้าถึงผู้บริโภค รวมถึงใช้กลยุทธการตัดราคาในสินค้ากลุ่มที่ price sensitive
# - process: process :Marketing and Sales: จัดโปรโมชั่นพิเศษเฉพาะงาน,Research and Development: พัฒณาสูตรให้มีคุณภาพดีเท่าเดิม แต่สามารถลดต้นทุน RM ได้, Production: ผลิตได้มีประสิทธิภาพ สามารถลดต้นทุนการผลิตได้, Marketing and Sales: จัดรายการส่งเสริมการขายให้สามารถแข่งขันและกันคู่แข่งในตลาดโดยเฉพาะรายใหม่ที่เข้ามา และ
# จะต้องพัฒนาและออกผลิตภัณฑ์ใหม่ให้ได้ตามแผนที่วางไว้,Planning: ต้องใช้ข้อมูลด้านการตลาดและพฤติกรรมของลูกค้าเพื่อวางแผนทางการตลาดและกำหนดกลุ่มเป้าหมาย รวมถึงการใช้สื่อโฆษณาต่างๆให้เข้าถึงเป้าหมายที่ตรงกลุ่มชัดเจน วิเคราะห์กลยุทธ์ทางการตลาดและผลักดันให้ทันกับการแข่งขันในตลาดที่สูงในปัจจุบัน โดยเฉพาะบนช่องทางอีคอมเมิร์ซ  รวมถึงการประเมิณจัดสรรค่าใช้จ่าย ทั้งค่าโฆษณาและค่าใช้จ่ายอื่นๆ ให้อยู่ในความคุ้มค่าสูงสุดตามงบประมาณที่วางแผนไว้, Marketing and Sales: บริหารงานขาย ด้านราคาสินค้า , โปรโมชั่น และค่าใช้จ่ายๆ ต่างให้ตอบโจทย์และคุ้มค่ามากที่สุดจากการวัดที่ผลลัพธ์ โดยเปรียบเทียบกลยุทธ์เพิ่มเติมกับคู่แข่งในตลาด โฟกัสเป้าหมายและการเติบโตของช่องทางการขายในแต่ละแพลตฟอร์ม,Procurement: จัดซื้อสินค้าและวัตถุดิบที่ได้ต้นทุนที่แข่งขันได้, Quality Assurance: มี QA ตรวจสอบคุณภาพสินค้าก่อนออกสู่ตลาด, Planning: วางแผนเพื่อเตรียมให้สินค้าพร้อมในการขาย, Finance and Accounting: สนับสนุนข้อมูลด้านต้นทุนสินค้า และ P&L ได้ถูกต้องและรวดเร็ว, Marketing and Sales: เป็นหน่วยงานหลักในการวางแผนกลยุทธ์เพื่อแข่งขันได้, After Sale Service: การบริการหลังการขายเพื่อสร้างความพอใจให้ลูกค้า, Research and Development: พัฒนาสินค้าที่มีคุณภาพและแข่งขันได้, Warehouse: เก็บสินค้าที่เพียงพอและพร้อมในการขาย, Information Technology (IT): สนับสนุนพัฒนาระบบในการทำงานได้คล่องตัว สะดวก รวดเร็ว, Production: ผลิตสินค้าที่มีคุณภาพและเพียงพอกับความต้องการขาย, Transportation: จัดส่งสินค้าที่มีคุณภาพ รวดเร็ว ไม่ชำรุดเสียหาย,Research and Development: การพํฒนาสินค้าที่มีคุณภาพและตอบโจทย์ความต้องการของตลาดในต้นทุนที่สามารถแข่งขันได้, Production: การผลิตสินค้าที่มีคุณภาพ ด้วยเทคโนโลยีที่ทันสมัย สามารถผลิตสินค้าที่ตอบโจทย์ความต้องการของตลาดได้, Marketing and Sales: การวางกลยุทธการตลาดและการขายเชิงรุก เข้าถึงผู้บริโภคได้อย่างทั่วถึงและทุก touch point  ,Information Technology (IT): เครื่องมือเทคโนโลยี่ที่ทันสมัยช่วยสนับสนุนการทำงานทั้งด้านข้อมูล ความถูกต้อง สะดวก และทันต่อสถานการณ์, Research and Development: R&D มีความจำเป็นด้านพัฒนาสินค้าให้ตรงตามความต้องการของตลาด, Business Development: เทรนด์ตลาดมีการเปลี่ยนแปลงตลอด กระบวนการจัดการควรต้องมีการพัฒนาให้สอดคล้องกับตลาด, Planning: การวางแผนผลิต วางแผนกลยุทธ์ และวางแผนการทำงานทุกขั้นตอน มีความจำเป็นอย่างยิ่ง และสามารถปรับแผนการทำงานให้สอดคล้องกับตลาดได้, Production: ผลิตสินค้าคุณภาพให้เพียงพอและทันเวลากับความต้องการการขา, Quality Assurance: เป็นสิ่งสำคัญกับการสร้างความมั่นใจให้ลูกค้าและผู้บริโภค, Warehouse: คลังสินค้ามีพื้นที่เพียงพอในการเก็บสต้อคให้พร้อมกับการขาย และการจัดเก็บสินค้าที่ถูกต้อง มีการ FIFO และดูแลคุณภาพสินค้า, Distribution Center (DC): ช่วยให้การกระจายจัดส่งสินค้าได้ทันเวลา, Transportation: การขนส่งที่รวดเร็ว สินค้าไม่เกิดชำรุดเสียหาย, Marketing and Sales: หน่วยงานหลักของการวางกลยุทธ์เพื่อการขายและกระจายสินค้าเข้าสู่ตลาด, After Sale Service: สร้างความมั่นใจเชื่อมั่นให้ผู้บริโภค
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 31
#      29 print("here")
#      30 print(risk_a, risk_b)
# ---> 31 edge_relationship_a_b = classify_edge_relationship(
#      32     model_name=model_name, risk_a=risk_a, risk_b=risk_b
#      33 )
#      34 edge_relationship_b_a = classify_edge_relationship(
#      35     model_name=model_name, risk_a=risk_b, risk_b=risk_a
#      36 )
#      38 # all_result_list.append(
#      39 #     {
#      40 #         "model_name": model_name,
#    (...)     59 #     }
#      60 # )
#
# Cell In[16], line 13, in classify_edge_relationship(model_name, risk_a, risk_b)
#      11 risk_a_str = "\n".join([f"- {k}: {v}" for k, v in risk_a.items()])
#      12 print(risk_a_str)
# ---> 13 raise
#      14 try:
#      15     llm = get_llm(model_name=model_name)
#
# RuntimeError: No active exception to reraise

# %%
# create dataframe from all_result_list and save to exel
import pandas as pd
import pickle


df = pd.DataFrame(all_result_list)
df.to_excel("compare_new_relation_model.xlsx", index=False)

# %%
df.shape
# Out:
# (21, 7)

# %%
{
    "risk": "Intense market competition",
    "risk_desc": "ตลาดอาหารสัตว์เลี้ยงมีอัตราการเติบโตต่อเนื่องทุกปี  ทำให้เป็นแรงจูงใจให้ผู้ผลิตและผู้จัดจำหน่ายสินค้ากลุ่มอื่นๆ ทั้งรายเก่ามีการขยายธุรกิจมากขึ้น และรายใหม่ๆเข้ามาในธุรกิจนี้มากขึ้นด้วย,ตลาดอาหารสุนัขมีการเติบโตอย่างต่อเนื่อง มีสินค้าใหม่และ Brand ใหม่เกิดขึ้นในตลาดจำนวนมาก และหลายแบรนด์หลายบริษัทมีการทำการตลาดเชิงรุก หรืออาจจะมีการใช้กลยุทธการขายสินค้าราคาถูกมากในกลุ่มสินค้าที่ price sensitive เพื่อแย่งลูกค้าและส่วนแบ่งทางการตลาด ส่งผลให้ทาง PCG อาจจะไม่สามารถทำยอดขาย อัตราการเติบโต รวมถึงส่วนแบ่งตลาด ได้ตามที่วางแผนไว้,มีคู่แข่งรายใหม่เข้าสู่ตลาดหรือคู่แข่งเดิมใช้กลยุทธ์การตลาดเชิงรุก ส่งผลให้ยอดขายไม่เป็นไปตามเป้าหมาย,ความเสี่ยงจากการแข่งขันในตลาดบนช่องทางออนไลน์และอีคอมเมิร์ซ การแข่งขันที่รุนแรงจากแบรนด์เดิมและคู่แข่งรายใหม่ อาจส่งผลต่อยอดขายและการรักษาฐานลูกค้า,ขาดกิจกรรมที่ตอบสนองต่อความต้องการของลูกค้า,สถานการณ์ที่ธุรกิจต่างๆในอุตสาหกรรมเดียวกันมีการแข่งขันที่รุนแรง ซึ่งอาจส่งผลกระทบต่อกำไรและส่วนแบ่งตลาด",
    "rootcause": "rootcause :High number of competitors in the market: จำนวนคู่แข่งในตลาดมีจำนวนมากทั้งในส่วนของจำนวน Manufacturer และจำนวน Brand , Aggressive pricing strategies: หลาย Brand ในตลาดกลุ่ม Economy และ Super Economy ใช้กลยุทธการแข่งขันด้านราคาเป็นหลัก ซึ่งทาง PCG อาจจะไม่สามารถแข่งขันโดยการใช้กลุยุทธการทำราคาถูกมากได้ , Other: คู่แข่งมีการทำตลาดอย่างเข้มข้นมากขึ้นทั้งส่วนของการใช้ Media การทำโปรโมชั่น และกิจกรรมต่างๆ ที่เข้าถึงผู้บริโภค รวมถึงใช้กลยุทธการตัดราคาในสินค้ากลุ่มที่ price sensitive,High number of competitors in the market: ตลาดอาหารแมวในประเทศไทยเติบโตอย่างต่อเนื่อง มีคู่แข่งเข้ามาในตลาดจำนวนมากทั้งอาหารเม็ดและอาหารเปียก , Aggressive pricing strategies: คู่แข่งใช้กลยุทธ์ราคาถูกในการเข้าตลาด ได้แก่ สินค้าเป็นกลุ่มที่ดูเรื่อง Product benefits เป็นกลุ่ม Premium ตั้งราคาเท่ากลุ่ม Standard ให้ดูว่าจับต้องได้ง่าย หรือตลาดล่างที่เติบโตมาขึ้น ก็มีการเข้าตลาดด้วยการใช้กลยุทธ์ทำราคาถูกเช่นกัน,Aggressive pricing strategies: ราคาหรือโปรโมชั่นที่จำหน่ายในงานกิจกรรมต่างๆ สู้คู่แข่งขันไม่ได้,High number of competitors in the market: การแข่งขันที่รุนแรงจากจำนวนคู่แข่งที่เพิ่มขึ้นอาจส่งผลให้สูญเสียลูกค้า รายได้ และส่วนแบ่งทางการตลาด, Aggressive pricing strategies: การลดราคาหนักในตลาด รวมถึงการส่งสินค้าฟรี และมีโปรโมชั่นพิเศษอย่างต่อเนื่อง,High number of competitors in the market: ผู้ผลิตทั้ง Branded & OEM มีจำนวนมากขึ้น และมีการนำเข้าสินค้าจากต่างประเทศมากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยและบริษัทที่ทำธุรกิจจ้างผลิตที่มีต้นทุนการผลิตต่ำได้เปรียบในการแข่งขันด้านราคา, Other: กำลังซื้อของผู้บริโภคลดลง และการตัดสินใจซื้อยากขึ้น,High number of competitors in the market: ธุรกิจอาหารสัตว์เลี้ยงเติบโตมากอย่างต่อเนื่องทำให้ผู้ผลิตอาหารอื่นๆเข้ามาในตลาดนี้มากขึ้น, Aggressive pricing strategies: ผู้ผลิตรายย่อยที่มีต้นทุนต่ำได้เปรียบในการแข่นขันด้านราคา",
}
{
    "risk": "New competitor into the market",
    "risk_desc": "ตลาดอาหารสุนัขมีการเติบโตอย่างต่อเนื่อง ส่งผลให้มีคู่แข่งใหม่เข้าสู่ตลาดจำนวนมากทั้งคู่แข่งในประเทศและคู่แข่งจากต่างประเทศ ส่งผลให้มีการแข่งขันในตลาดสูงขึ้น และมีผู้เล่นที่มา share ยอดขายและ market share ในตลาดมากขึ้นด้วย รวมถึงคู่แข่งใหม่สามารถทำสินค้าที่มีคุณภาพดีแต่ขายในราคาที่ไม่แพงมาก จึงได้รับความสนใจจากผู้บริโภคได้ง่าย และขายได้ดี ดังนั้นอาจทำให้บริษัทฯ ไม่สามารถทำยอดขายหรืออัตราการเติบโตได้ตามเป้าหมายที่กำหนดไว้,ตลาดอาหารปลาคาร์พ  กระต่าย  นกแก้วและนกสวยงาม มักจะมีสินค้าใหม่เข้าสู่ตลาด ทั้งสินค้าที่ผลิตในประเทศและนำเข้าจากต่างประเทศ ซึ่งตลาดของผลิตภัณฑ์ดังกล่าวจะเป็นสินค้าเฉพาะกลุ่มอยู่แล้ว  และยิ่งมีแบรนด์ใหม่เข้ามาเพิ่ม จึงส่งผลให้กลยุทธ์การทำตลาดจะเน้นไปในเรื่องของกิจกรรมส่งเสริมการขาย เช่น จัด promotion ราคาพิเศษ หรือการแย่งชิงลูกค้ารายใหญ่เช่น การเข้าฟาร์ม หรือพื้นที่ดิสเพลย์ใน pet shop เป็นต้น   ดังนั้นหากไม่วางกลยุทธ์ที่สามารถกันคู่แข่งรายใหม่เหล่านี้ได้ ก็จะทำให้ส่งผลกระทบต่อยอดขาย และส่วนแบ่งการตลาดที่ลดลง,การเข้ามาขอคู่แข่งในตลาดอาหารแมวทั้งชนิดเปียก และแห้ง ทำให้เกิดการแข่งขันทั้งคุณภาพและราคา มีผลกระทบกับยอดขายสินค้าและตำแหน่งในตลาดของผลิตภัณฑ์ของบริษัท",
    "rootcause": "rootcause :Market growth potential or profitability: ตลาดอาหารแมวเติบโตอย่างต่อเนื่องในประเทศไทย, Market conditions that allow new competitors to enter with relatively low investment or operational requirements: มีคู่แข่งเข้ามาในตลาดหลากหลายไม่ว่าจะเป็นผู้ผลิตเอง หรือ จ้างผลิต รวมถึงนำเข้าจากต่างประเทศ โดยเสนอสินค้าที่มีคุณภาพดี มี functional benefit ในราคาที่จับต้องได้,Market conditions that allow new competitors to enter with relatively low investment or operational requirements: 1.ต้นทุนการผลิตของอาหารปลาคาร์พ กระต่าย นกแก้วและนกสวยงาม ไม่สูงมาก อาจทำให้ผู้ผลิตรายใหม่ หรือรายเดิม สามารถผลิตได้ง่าย\n2.สินค้าบางบริษัท บางแบรนด์ เลือกใช้วัตถุดิบหรือบรรจจุภัณฑ์ ที่จะส่งผลให้เกิดต้นทุนการผลิตที่ต่ำ เพื่อให้สามารถตั้งราคาขายที่ถูกกว่า, Changes in regulations that lower entry barriers or make it easier for new companies to enter the market: อาหารปลาคาร์พ นกแก้วและนกสวยงาม ไม่ต้องจดทะเบียนอาหารสัตว์ ไม่มีหน่วยงานราชการเข้ามาควบคุม มีอิสระในการผลิตและนำเข้าสินค้า สามารถ over claim สินค้าได้ จึงทำให้การออกสินค้าใหม่สามารถสร้างจุดขายสินค้าให้มีคุณภาพดีกว่าสินค้าจริงก็ทำได้โดยอิสระ , Other: สินค้าบางแบรนด์เข้าสู่ตลาดด้วยการเข้าไปจำหน่ายใน platform E-Commerce ช่วยให้เข้าถึงลูกค้าได้เร็ว ง่าย และกว้าง บางแบรนด์อาจจะไม่วางหรือไม่เน้นจำหน่ายในช่องทาง Pet Shop / Modern Trade ซึ่งสามารถลดต้นทุนในเรื่องของ trade margin  ที่ต้องให้ร้านค้า ส่งผลให้ลดต้นทุนสินค้าลงได้ และทำให้สามารถทำราคาพิเศษในช่องทาง E-Commerce ได้ ,Market growth potential or profitability: -, Market conditions that allow new competitors to enter with relatively low investment or operational requirements: เนื่องจากหลายบริษํทมีกำลังการผลิตที่สามารถผลิตอาหารสัตว์เลี้ยงได้ โดยไม่ต้องลงทุนมากนัก, Other: -",
}
