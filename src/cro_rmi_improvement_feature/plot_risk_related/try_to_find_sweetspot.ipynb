# %%
# I want to plot 2 graph on same plot
import matplotlib.pyplot as plt
import numpy as np

# x start from 50 to 314
# y is x*(x-1)/2
x = np.arange(50, 315)
print(len(x))
y1 = x * (x - 1) / 2
# y2 start from 60 to 250 with same step as x
y2 = np.linspace(60, 250, len(x))
plt.plot(x, y1)
plt.plot(x, y2)
plt.show()
# Out:
# 265

# %%
import pickle
import pandas as pd

data_df = "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/plot_risk_related/result/merge-company_risk_data_with_embedding.pkl"
data = pickle.load(open(data_df, "rb"))

df = pd.DataFrame(data)
df.company.value_counts()
# Out:
# company
# risk_catalog-250520    314
# risk_catalog-250528    314
# PCG                     66
# lotus_south             35
# Name: count, dtype: int64
