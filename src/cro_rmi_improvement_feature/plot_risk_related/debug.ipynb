# %%
import pickle

data_path = "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/plot_risk_related/result/merge-company_risk_data_with_embedding-edge_relationship.pkl"
with open(data_path, "rb") as f:
    data = pickle.load(f)
# print first 3 items
for k, v in list(data.items())[:3]:
    print(k, v)
# Out:
# ('Accounting errors', 'Decision-making errors') {'direction': [-1, 0], 'reason': 'Accounting errors can lead to flawed information, which in turn can result in poor decision-making by management.'}
# ('Business interruption from fire hazards', 'Business interruption from flood') {'direction': [0, 0], 'reason': 'The risks of business interruption from fire hazards and from flood are independent of each other, as they arise from different causes and do not influence one another.'}
# ('Business interruption from fire hazards', 'Business interruption from labor dispute') {'direction': [0, 0], 'reason': 'The risks of business interruption from fire hazards and labor disputes are independent of each other, as one does not cause or influence the other.'}

# %%
a_risk = "Debtor credit risk (External party)"
b_risk = "Debtor credit risk (Internal party)"
a_b_data = data[(a_risk, b_risk)]
a_b_data
# Out:
# {'direction': [1, 0],
#  'reason': "Both internal and external debtor credit risks can influence each other, as the financial performance of external debtors can impact internal debtors' ability to meet their obligations and vice versa."}

# %%
from post_proces_node import finalize_edge_relationship

risk_a_name = "Debtor credit risk (External party)"
risk_b_name = "Debtor credit risk (Internal party)"
edge_relationship_a_b = {
    "relationship": "be_a_caused_by_each_other",
    "reason": "Both external and internal debtor credit risks can influence each other, as a downgrade in credit ratings can affect both internal and external debtors' ability to meet their obligations.",
}
edge_relationship_b_a = {
    "relationship": "be_a_caused_by_each_other",
    "reason": "Both internal and external debtor credit risks can influence each other, as the financial performance of external debtors can impact internal debtors' ability to meet their obligations and vice versa.",
}
edge_relationship = finalize_edge_relationship(
    edge_relationship_a_b, edge_relationship_b_a, risk_a_name, risk_b_name
)
# Out:
# /Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/plot_risk_related
# real_data[0].keys()=dict_keys(['company', 'risk_cat', 'risk', 'risk_desc', 'risk_level', 'rootcause', 'process', ('embedding', 'risk'), ('embedding', 'risk', 'risk_desc'), ('embedding', 'risk', 'rootcause'), ('embedding', 'process', 'risk'), ('embedding', 'risk', 'risk_desc', 'rootcause'), ('embedding', 'process', 'risk', 'risk_desc'), ('embedding', 'process', 'risk', 'rootcause'), ('embedding', 'process', 'risk', 'risk_desc', 'rootcause')])
# avg_dist=np.float64(88.55363979438268)
# node_size_counter=Counter({1: 43, 2: 20, 3: 3})

# %%
edge_relationship
# Out:
# {'relationship': 'be_a_cause_to_each_other',
#  'reason': "Both internal and external debtor credit risks can influence each other, as the financial performance of external debtors can impact internal debtors' ability to meet their obligations and vice versa."}

# %%
import pandas as pd

risk_data_path = "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/plot_risk_related/result/merge-company_risk_data_with_embedding.pkl"
risk_data = pickle.load(open(risk_data_path, "rb"))
risk_data_df = pd.DataFrame(risk_data)
risk_data_df.head()
risk_data_df.columns
risk_data_df.columns.to_list()
risk_data_df.columns.to_list()
risk_data_df.columns.to_list()
# Out:
# ['company',
#  'risk_cat',
#  'risk',
#  'risk_desc',
#  'risk_level',
#  'rootcause',
#  'process',
#  ('embedding', 'risk'),
#  ('embedding', 'risk', 'risk_desc'),
#  ('embedding', 'risk', 'rootcause'),
#  ('embedding', 'process', 'risk'),
#  ('embedding', 'risk', 'risk_desc', 'rootcause'),
#  ('embedding', 'process', 'risk', 'risk_desc'),
#  ('embedding', 'process', 'risk', 'rootcause'),
#  ('embedding', 'process', 'risk', 'risk_desc', 'rootcause')]

# %%
risk_data_df.risk_cat.unique()
# Out:
# array(['Operational Risk', 'Strategic Risk', 'Credit Risk', 'Market Risk',
#        'Liquidity Risk', 'A. Setting up business\n\n',
#        'B. Business operation', 'C. Compliance and regulator',
#        'D. Policy', 'E. Raising Concerns and Seeking Guidance',
#        'F. Review, Assessment and Improvement'], dtype=object)

# %%
risk_data_df[risk_data_df.risk_cat == "A. Setting up business\n\n"]
# Out:
#                  company                    risk_cat  \
# 210  risk_catalog-250520  A. Setting up business\n\n
# 211  risk_catalog-250520  A. Setting up business\n\n
# 212  risk_catalog-250520  A. Setting up business\n\n
# 213  risk_catalog-250520  A. Setting up business\n\n
# 214  risk_catalog-250520  A. Setting up business\n\n
# 215  risk_catalog-250520  A. Setting up business\n\n
# 216  risk_catalog-250520  A. Setting up business\n\n
# 217  risk_catalog-250520  A. Setting up business\n\n
# 590  risk_catalog-250528  A. Setting up business\n\n
# 591  risk_catalog-250528  A. Setting up business\n\n
# 592  risk_catalog-250528  A. Setting up business\n\n
# 593  risk_catalog-250528  A. Setting up business\n\n
# 594  risk_catalog-250528  A. Setting up business\n\n
# 595  risk_catalog-250528  A. Setting up business\n\n
# 596  risk_catalog-250528  A. Setting up business\n\n
# 597  risk_catalog-250528  A. Setting up business\n\n
#
#                                                   risk  \
# 210                               Company registration
# 211                Underwriter recruitment and hiring
# 212  Submission for permission from the Securities ...
# 213   License application/renewal for a new enterprise
# 214                Factory license application/renewal
# 215                    Land leasing for business setup
# 216                              Building construction
# 217                         Building design adjustment
# 590                               Company registration
# 591                Underwriter recruitment and hiring
# 592  Submission for permission from the Securities ...
# 593   License application/renewal for a new enterprise
# 594                Factory license application/renewal
# 595                    Land leasing for business setup
# 596                              Building construction
# 597                         Building design adjustment
#
#                                              risk_desc  risk_level  \
# 210  Example of event:\nEmployees want to speed up ...           0
# 211  Example of event:\nEmployees pay bribes to und...           0
# 212  Example of event:\nEmployees pay bribes to the...           0
# 213  Example of event:\nEmployees under xxxx must a...           0
# 214  Example of event:\nThe company fails to renew ...           0
# 215  Example of event:\nEmployees under xxxx pay a ...           0
# 216  Example of event:\nBuilding design employees p...           0
# 217  Example of event:\nBuilding design employees r...           0
# 590  Example of event:\nEmployees want to speed up ...           0
# 591  Example of event:\nEmployees pay bribes to und...           0
# 592  Example of event:\nEmployees pay bribes to the...           0
# 593  Example of event:\nEmployees under xxxx must a...           0
# 594  Example of event:\nThe company fails to renew ...           0
# 595  Example of event:\nEmployees under xxxx pay a ...           0
# 596  Example of event:\nBuilding design employees p...           0
# 597  Example of event:\nBuilding design employees r...           0
#
#                                              rootcause process  \
# 210  - To speed up the process\n- To get a project ...
# 211  - To speed up the process\n- To get a project ...
# 212  - To speed up the process\n- To get a project ...
# 213  - To speed up the process\n- To get a project ...
# 214  - To speed up the process\n- To get a project ...
# 215
# 216  - To speed up the process\n- To get a project ...
# 217  - To speed up the process\n- To get a project ...
# 590  - To speed up the process\n- To get a project ...
# 591  - To speed up the process\n- To get a project ...
# 592  - To speed up the process\n- To get a project ...
# 593  - To speed up the process\n- To get a project ...
# 594  - To speed up the process\n- To get a project ...
# 595
# 596  - To speed up the process\n- To get a project ...
# 597  - To speed up the process\n- To get a project ...
#
#                                      (embedding, risk)  \
# 210  [-0.003971198573708534, 0.033084671944379807, ...
# 211  [-0.013893979601562023, -0.0070684258826076984...
# 212  [-0.02665930800139904, -0.0027731272857636213,...
# 213  [-0.029958080500364304, 0.007899904623627663, ...
# 214  [-0.017228275537490845, -0.009548299945890903,...
# 215  [0.013859612867236137, 0.01442769356071949, 0....
# 216  [0.007121204398572445, 0.0173141211271286, -0....
# 217  [-0.002017800696194172, -0.003810517257079482,...
# 590  [-0.003971198573708534, 0.033084671944379807, ...
# 591  [-0.013893979601562023, -0.0070684258826076984...
# 592  [-0.02665930800139904, -0.0027731272857636213,...
# 593  [-0.029958080500364304, 0.007899904623627663, ...
# 594  [-0.017228275537490845, -0.009548299945890903,...
# 595  [0.013859612867236137, 0.01442769356071949, 0....
# 596  [0.007121204398572445, 0.0173141211271286, -0....
# 597  [-0.002017800696194172, -0.003810517257079482,...
#
#                           (embedding, risk, risk_desc)  \
# 210  [-0.005665841046720743, -0.025364428758621216,...
# 211  [-0.01767314411699772, -0.0045499964617192745,...
# 212  [-0.022352255880832672, -0.0052741714753210545...
# 213  [-0.02682284452021122, 0.008631497621536255, -...
# 214  [-0.02187538705766201, -0.02047610841691494, -...
# 215  [-3.3792894100770354e-05, -0.00768930977210402...
# 216  [-0.00914420373737812, -0.026897666975855827, ...
# 217  [-0.012441914528608322, -0.027350759133696556,...
# 590  [-0.005665841046720743, -0.025364428758621216,...
# 591  [-0.01767314411699772, -0.0045499964617192745,...
# 592  [-0.022352255880832672, -0.0052741714753210545...
# 593  [-0.02682284452021122, 0.008631497621536255, -...
# 594  [-0.02187538705766201, -0.02047610841691494, -...
# 595  [-3.3792894100770354e-05, -0.00768930977210402...
# 596  [-0.00914420373737812, -0.026897666975855827, ...
# 597  [-0.012441914528608322, -0.027350759133696556,...
#
#                           (embedding, risk, rootcause)  \
# 210  [-0.01759100705385208, -0.013471594080328941, ...
# 211  [-0.020990731194615364, -0.018488187342882156,...
# 212  [-0.032234061509370804, -0.008412819355726242,...
# 213  [-0.01936488226056099, -0.005669116508215666, ...
# 214  [-0.01235145516693592, -0.023826703429222107, ...
# 215  [0.013892365619540215, 0.008203393779695034, -...
# 216  [-0.020441194996237755, -0.02743701823055744, ...
# 217  [-0.009159494191408157, -0.026429753750562668,...
# 590  [-0.01759100705385208, -0.013471594080328941, ...
# 591  [-0.020990731194615364, -0.018488187342882156,...
# 592  [-0.032234061509370804, -0.008412819355726242,...
# 593  [-0.01936488226056099, -0.005669116508215666, ...
# 594  [-0.01235145516693592, -0.023826703429222107, ...
# 595  [0.013892365619540215, 0.008203393779695034, -...
# 596  [-0.020441194996237755, -0.02743701823055744, ...
# 597  [-0.009159494191408157, -0.026429753750562668,...
#
#                             (embedding, process, risk)  \
# 210  [-0.013680276460945606, 0.02074078470468521, -...
# 211  [-0.020538944751024246, -0.007881904020905495,...
# 212  [-0.02834618091583252, -0.008303566835820675, ...
# 213  [-0.028785862028598785, -0.0014273395063355565...
# 214  [-0.019481969997286797, -0.01687898486852646, ...
# 215  [0.013892365619540215, 0.008203393779695034, -...
# 216  [-0.00298350234515965, 0.01299520954489708, -0...
# 217  [-0.0006131847039796412, -0.005399138666689396...
# 590  [-0.013680276460945606, 0.02074078470468521, -...
# 591  [-0.020538944751024246, -0.007881904020905495,...
# 592  [-0.02834618091583252, -0.008303566835820675, ...
# 593  [-0.028785862028598785, -0.0014273395063355565...
# 594  [-0.019481969997286797, -0.01687898486852646, ...
# 595  [0.013892365619540215, 0.008203393779695034, -...
# 596  [-0.00298350234515965, 0.01299520954489708, -0...
# 597  [-0.0006131847039796412, -0.005399138666689396...
#
#                (embedding, risk, risk_desc, rootcause)  \
# 210  [-0.01485742349177599, -0.02971484698355198, 0...
# 211  [-0.021361691877245903, -0.004590386524796486,...
# 212  [-0.025806864723563194, -0.007006068713963032,...
# 213  [-0.032746102660894394, 0.00494628818705678, -...
# 214  [-0.02299496904015541, -0.024886861443519592, ...
# 215  [0.0009651275468058884, -0.0038605101872235537...
# 216  [-0.014384033158421516, -0.019476311281323433,...
# 217  [-0.01832282915711403, -0.022938773036003113, ...
# 590  [-0.01485742349177599, -0.02971484698355198, 0...
# 591  [-0.021361691877245903, -0.004590386524796486,...
# 592  [-0.025806864723563194, -0.007006068713963032,...
# 593  [-0.032746102660894394, 0.00494628818705678, -...
# 594  [-0.02299496904015541, -0.024886861443519592, ...
# 595  [0.0009651275468058884, -0.0038605101872235537...
# 596  [-0.014384033158421516, -0.019476311281323433,...
# 597  [-0.01832282915711403, -0.022938773036003113, ...
#
#                  (embedding, process, risk, risk_desc)  \
# 210  [-0.008879746310412884, -0.024674834683537483,...
# 211  [-0.015875795856118202, -0.005526536609977484,...
# 212  [-0.023771215230226517, -0.007482087705284357,...
# 213  [-0.02988533489406109, 0.007945911027491093, -...
# 214  [-0.023388225585222244, -0.019901197403669357,...
# 215  [0.0009651275468058884, -0.0038605101872235537...
# 216  [-0.010266905650496483, -0.02704453282058239, ...
# 217  [-0.015016148798167706, -0.02687854878604412, ...
# 590  [-0.008879746310412884, -0.024674834683537483,...
# 591  [-0.015875795856118202, -0.005526536609977484,...
# 592  [-0.023771215230226517, -0.007482087705284357,...
# 593  [-0.02988533489406109, 0.007945911027491093, -...
# 594  [-0.023388225585222244, -0.019901197403669357,...
# 595  [0.0009651275468058884, -0.0038605101872235537...
# 596  [-0.010266905650496483, -0.02704453282058239, ...
# 597  [-0.015016148798167706, -0.02687854878604412, ...
#
#                  (embedding, process, risk, rootcause)  \
# 210  [-0.018432745710015297, -0.015578392893075943,...
# 211  [-0.021654250100255013, -0.01938282512128353, ...
# 212  [-0.03216393664479256, -0.010576698929071426, ...
# 213  [-0.017526794224977493, -0.00804624892771244, ...
# 214  [-0.011120378971099854, -0.026404276490211487,...
# 215  [0.012345017865300179, 0.008848145604133606, -...
# 216  [-0.018493106588721275, -0.028589719906449318,...
# 217  [-0.008157581090927124, -0.028612613677978516,...
# 590  [-0.018432745710015297, -0.015578392893075943,...
# 591  [-0.021654250100255013, -0.01938282512128353, ...
# 592  [-0.03216393664479256, -0.010576698929071426, ...
# 593  [-0.017526794224977493, -0.00804624892771244, ...
# 594  [-0.011120378971099854, -0.026404276490211487,...
# 595  [0.012345017865300179, 0.008848145604133606, -...
# 596  [-0.018493106588721275, -0.028589719906449318,...
# 597  [-0.008157581090927124, -0.028612613677978516,...
#
#       (embedding, process, risk, risk_desc, rootcause)
# 210  [-0.014291627332568169, -0.03103594481945038, ...
# 211  [-0.020594120025634766, -0.004468842409551144,...
# 212  [-0.025747697800397873, -0.008800635114312172,...
# 213  [-0.031888242810964584, 0.004700607154518366, ...
# 214  [-0.02245863899588585, -0.025531763210892677, ...
# 215  [-0.0003542938211467117, -0.002690370660275221...
# 216  [-0.016064591705799103, -0.020528823137283325,...
# 217  [-0.01715833693742752, -0.023274267092347145, ...
# 590  [-0.014291627332568169, -0.03103594481945038, ...
# 591  [-0.020594120025634766, -0.004468842409551144,...
# 592  [-0.025747697800397873, -0.008800635114312172,...
# 593  [-0.031888242810964584, 0.004700607154518366, ...
# 594  [-0.02245863899588585, -0.025531763210892677, ...
# 595  [-0.0003542938211467117, -0.002690370660275221...
# 596  [-0.016064591705799103, -0.020528823137283325,...
# 597  [-0.01715833693742752, -0.023274267092347145, ...
