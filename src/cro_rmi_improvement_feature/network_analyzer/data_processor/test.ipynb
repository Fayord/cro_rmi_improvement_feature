# %%
import pickle
from create_graph_data_library import (
    GraphDataLibrary,
    RiskDataWithEmbedding,
    RiskData,
    EdgeData,
    CompanyGraphData,
    RiskOverlayData,
    RiskDataNoEmbedding,
    RiskDataWithOutEmbedding,
    EdgeDataNoEmbedding,
    CompanyGraphDataNoEmbedding,
    RiskOverlayDataNoEmbedding,
    GraphDataLibraryNoEmbedding,
)

graph_data_library_path = "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/network_analyzer/data/graph/graph_data_library.pkl"
graph_data_library_path_no_embedding = "/Users/ford/Documents/coding_trae/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/network_analyzer/data/graph/graph_data_library_no_embedding.pkl"
graph_data_library: GraphDataLibrary = pickle.load(open(graph_data_library_path, "rb"))
graph_data_library_no_embedding: GraphDataLibraryNoEmbedding = pickle.load(
    open(graph_data_library_path_no_embedding, "rb")
)

graph_data_library.company_graph_datas
graph_data_library_no_embedding.company_graph_datas

# %%
lotus_south_company_graph_data = graph_data_library.company_graph_datas[
    "lotus_south|embedding_raw_user_data"
]
nodes = lotus_south_company_graph_data.nodes
len(nodes)
# Out:
# 66

# %%
pcg_company_graph_data = graph_data_library.company_graph_datas[
    "PCG|embedding_raw_user_data"
]
nodes = pcg_company_graph_data.nodes
len(nodes)
# Out:
# 66
