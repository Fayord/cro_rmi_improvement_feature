# %%
from cdlib import algorithms
import networkx as nx

G = nx.karate_club_graph()
# coms = algorithms.pycombo(
#     G,
#     weight="weight",
#     # max_communities=4,
#     modularity_resolution=5,
# )
coms = algorithms.scan(
    G,
    epsilon=0.5,
    mu=3,
)

# %%
coms.communities
# Out:
# [[13, 1, 0, 2, 3, 7, 17, 21, 12],
#  [5, 6, 4, 16, 10],
#  [29, 23, 26, 33],
#  [31, 24, 25, 28]]
