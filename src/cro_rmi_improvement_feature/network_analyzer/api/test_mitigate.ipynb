# %%
import requests
from dotenv import load_dotenv
import os

load_dotenv()


token = os.getenv("TOKEN_AUTH")
print(token[:5], token[-5:])
headers = {"accept": "application/json", "Authorization": f"Bearer {token}"}
# url = "http://0.0.0.0:7800/rmi_graph_based_recommendation/recommend_risk_to_assess"
# url = "http://172.16.100.50:7900/rmi_graph_based_recommendation/recommend_risk_to_mitigate"
url = "http://172.16.100.50:7990/rmi_graph_based_recommendation/recommend_risk_to_mitigate"
# Out:
# eyJhb VCvIQ

# %%
# /health
response = requests.get(
    url,
    headers=headers,
)
response.json()
# Out:
# {'detail': 'Method Not Allowed'}

# %%
import json

data_path = "example_request.json"
with open(data_path, "r") as f:
    data = json.load(f)

data.keys()
data["data_level"] = "company"

# %%
import requests

response = requests.post(
    url,
    json=data,
    headers=headers,
)
total_time = response.elapsed.total_seconds()
response.status_code
print(f"Total time: {total_time} seconds")
print(f"Status code: {response.status_code}")
# Out:
# Total time: 11.693722 seconds
# Status code: 200

# %%
# 2 : 25.793502, 22.448731
# 16: 13.222311, 11.693722

# %%
# response_non_parallel = response.json()
# response_non_parallel
response_parallel = response.json()
response_parallel
# Out:
# {'id': '8a3dcc6d-bcec-4ce7-aec5-dfa38930d9ce',
#  'recommendations_with_tags': [{'risk_data': {'id': '539',
#     'label': 'Non-compliance - business related regulations',
#     'risk': 'Non-compliance - business related regulations',
#     'risk_id': '539',
#     'risk_cat': 'Operational Risk',
#     'risk_desc': 'Non-compliance with laws or standards pertaining business operation, e.g.,\n- lack of permits and certifications for operations e.g. industrial factories operation or construction/ livestock or fishery businesses\n- non-compliance with standards regarding health and safety for livestock',
#     'cluster_id': -1,
#     'risk_score': 9,
#     'risk_impact': 3,
#     'risk_likelihood': 3,
#     'risk_level': 2,
#     'process': [{'id': '1', 'name': 'Human Resources', 'description': ''}],
#     'rootcause': [{'id': '2903',
#       'name': 'root_cause_2_EC002_(strategy)_lack_of_strategy_or_policy,_or_inadequate_consideration_in_strategic_planning',
#       'description': ''}],
#     'process_summary': '',
#     'rootcause_summary': '',
#     'risk_desc_summary': ''},
#    'is_central_risk': False,
#    'is_source_risk': True,
#    'is_high_risk': False,
#    'is_shared_root_cause': False,
#    'is_news_trended': False,
#    'is_emerging_risk': False},
#   {'risk_data': {'id': '795',
#     'label': 'Ineffective OT Operations Management',
#     'risk': 'Ineffective OT Operations Management',
#     'risk_id': '795',
#     'risk_cat': 'Operational Risk',
#     'risk_desc': 'This risk refers to situation where the activities related to management of OT operations are not performed properly resulting in system unavailability, slow down performance, or business disruptions etc. Examples of OT operations management include:\n- Capacity management\n- Data backup\n- Access log management\n- OT Change management\n- OT Patch management\n- System acquisition and development\n- OT Incident and problem management\n- OT Business continuity plan',
#     'cluster_id': -1,
#     'risk_score': 16,
#     'risk_impact': 4,
#     'risk_likelihood': 4,
#     'risk_level': 3,
#     'process': [{'id': '163',
#       'name': 'Sensor (e.g. Flow meters, , Vibration, Termperature, Pressure)',
#       'description': ''}],
#     'rootcause': [{'id': '4802',
#       'name': 'root_cause_2_OG003_lack_of_ot_resource_utilization_monitoring',
#       'description': ''}],
#     'process_summary': '',
#     'rootcause_summary': '',
#     'risk_desc_summary': ''},
#    'is_central_risk': False,
#    'is_source_risk': True,
#    'is_high_risk': False,
#    'is_shared_root_cause': False,
#    'is_news_trended': False,
#    'is_emerging_risk': False},
#   {'risk_data': {'id': '794',
#     'label': 'Inadequate Management of OT Third-party',
#     'risk': 'Inadequate Management of OT Third-party',
#     'risk_id': '794',
#     'risk_cat': 'Operational Risk',
#     'risk_desc': "This risk refers to situation where third-party vendors or service providers for various aspects of organizational OT infrastructure and OT operations (such as cloud hosting, software development and managed services) cause the disruption or negative impact on an organization's OT operations.",
#     'cluster_id': -1,
#     'risk_score': 20,
#     'risk_impact': 5,
#     'risk_likelihood': 4,
#     'risk_level': 4,
#     'process': [{'id': '161',
#       'name': 'SCADA Systems (Supervisory Control and Data Acquisition)',
#       'description': ''}],
#     'rootcause': [{'id': '4798',
#       'name': 'root_cause_2_OG002_improper_system/application/device_access_controls',
#       'description': ''}],
#     'process_summary': '',
#     'rootcause_summary': '',
#     'risk_desc_summary': ''},
#    'is_central_risk': False,
#    'is_source_risk': True,
#    'is_high_risk': False,
#    'is_shared_root_cause': False,
#    'is_news_trended': False,
#    'is_emerging_risk': False},
#   {'risk_data': {'id': '538',
#     'label': 'Contractual breach',
#     'risk': 'Contractual breach',
#     'risk_id': '538',
#     'risk_cat': 'Operational Risk',
#     'risk_desc': 'Breach of contracts or business agreements, e.g., unable to deliver or make payment as specified in contracts',
#     'cluster_id': -1,
#     'risk_score': 6,
#     'risk_impact': 3,
#     'risk_likelihood': 2,
#     'risk_level': 2,
#     'process': [{'id': '1', 'name': 'Human Resources', 'description': ''}],
#     'rootcause': [{'id': '2902',
#       'name': 'root_cause_2_EC001_(strategy)_lack_of_strategy_or_policy,_or_inadequate_consideration_in_strategic_planning',
#       'description': ''}],
#     'process_summary': '',
#     'rootcause_summary': '',
#     'risk_desc_summary': ''},
#    'is_central_risk': True,
#    'is_source_risk': False,
#    'is_high_risk': False,
#    'is_shared_root_cause': False,
#    'is_news_trended': False,
#    'is_emerging_risk': False}],
#  'graph_id': '047e87af'}

# %%
print(response_parallel == response_non_parallel)

print(response_parallel.keys())
print(
    response_parallel["recommendations_with_tags"]
    == response_non_parallel["recommendations_with_tags"]
)
# Out:
# False
# dict_keys(['id', 'recommendations_with_tags', 'graph_id'])
# False

# %%
print(
    len(response_parallel["recommendations_with_tags"]),
    len(response_non_parallel["recommendations_with_tags"]),
)
for recommendation_with_tag in response_parallel["recommendations_with_tags"]:
    print(recommendation_with_tag["risk_data"]["id"])
print()

for recommendation_with_tag in response_non_parallel["recommendations_with_tags"]:
    print(recommendation_with_tag["risk_data"]["id"])
# Out:
# 4 6
# 539
# 795
# 794
# 538
#
# 539
# 795
# 538
# 794
# 538
# 794

# %%
import json

interest_risk = []
for recommendation_with_tag in response_non_parallel["recommendations_with_tags"]:
    if recommendation_with_tag["risk_data"]["id"] == "538":
        recommendation_with_tag_str = json.dumps(recommendation_with_tag)
        interest_risk.append(recommendation_with_tag_str)
len(set(interest_risk))
for risk in interest_risk:
    print(risk)
    print()
# Out:
# {"risk_data": {"id": "538", "label": "Contractual breach", "risk": "Contractual breach", "risk_id": "538", "risk_cat": "Operational Risk", "risk_desc": "Breach of contracts or business agreements, e.g., unable to deliver or make payment as specified in contracts", "cluster_id": -1, "risk_score": 6, "risk_impact": 3, "risk_likelihood": 2, "risk_level": 2, "process": [{"id": "1", "name": "Human Resources", "description": ""}], "rootcause": [{"id": "2902", "name": "root_cause_2_EC001_(strategy)_lack_of_strategy_or_policy,_or_inadequate_consideration_in_strategic_planning", "description": ""}], "process_summary": "", "rootcause_summary": "", "risk_desc_summary": ""}, "is_central_risk": true, "is_source_risk": true, "is_high_risk": false, "is_shared_root_cause": false, "is_news_trended": false, "is_emerging_risk": false}
#
# {"risk_data": {"id": "538", "label": "Contractual breach", "risk": "Contractual breach", "risk_id": "538", "risk_cat": "Operational Risk", "risk_desc": "Breach of contracts or business agreements, e.g., unable to deliver or make payment as specified in contracts", "cluster_id": -1, "risk_score": 6, "risk_impact": 3, "risk_likelihood": 2, "risk_level": 2, "process": [{"id": "1", "name": "Human Resources", "description": ""}], "rootcause": [{"id": "2902", "name": "root_cause_2_EC001_(strategy)_lack_of_strategy_or_policy,_or_inadequate_consideration_in_strategic_planning", "description": ""}], "process_summary": "", "rootcause_summary": "", "risk_desc_summary": ""}, "is_central_risk": false, "is_source_risk": false, "is_high_risk": false, "is_shared_root_cause": false, "is_news_trended": false, "is_emerging_risk": false}

# %%
result = response.json()
print(result.keys())
recommendations = result["recommendations_with_tags"]
print(len(recommendations))
for recommendation in recommendations:
    print(recommendation.keys())
    print(recommendation["risk_data"])
    print("source_risk" if recommendation["is_source_risk"] else "")
    print("central_risk" if recommendation["is_central_risk"] else "")
    print("high_risk" if recommendation["is_high_risk"] else "")
    print("shared_root_cause" if recommendation["is_shared_root_cause"] else "")
    print("news_trended" if recommendation["is_news_trended"] else "")
    print("emerging_risk" if recommendation["is_emerging_risk"] else "")
    print()
# Out:
# dict_keys(['id', 'recommendations_with_tags', 'graph_id'])
# 4
# dict_keys(['risk_data', 'is_central_risk', 'is_source_risk', 'is_high_risk', 'is_shared_root_cause', 'is_news_trended', 'is_emerging_risk'])
# {'id': '539', 'label': 'Non-compliance - business related regulations', 'risk': 'Non-compliance - business related regulations', 'risk_id': '539', 'risk_cat': 'Operational Risk', 'risk_desc': 'Non-compliance with laws or standards pertaining business operation, e.g.,\n- lack of permits and certifications for operations e.g. industrial factories operation or construction/ livestock or fishery businesses\n- non-compliance with standards regarding health and safety for livestock', 'risk_score': 9, 'risk_impact': 3, 'risk_likelihood': 3, 'risk_level': 2, 'process': [{'id': '1', 'name': 'Human Resources', 'description': ''}], 'rootcause': [{'id': '2903', 'name': 'root_cause_2_EC002_(strategy)_lack_of_strategy_or_policy,_or_inadequate_consideration_in_strategic_planning', 'description': ''}], 'process_summary': '', 'rootcause_summary': '', 'risk_desc_summary': ''}
# source_risk
#
#
#
#
#
#
# dict_keys(['risk_data', 'is_central_risk', 'is_source_risk', 'is_high_risk', 'is_shared_root_cause', 'is_news_trended', 'is_emerging_risk'])
# {'id': '795', 'label': 'Ineffective OT Operations Management', 'risk': 'Ineffective OT Operations Management', 'risk_id': '795', 'risk_cat': 'Operational Risk', 'risk_desc': 'This risk refers to situation where the activities related to management of OT operations are not performed properly resulting in system unavailability, slow down performance, or business disruptions etc. Examples of OT operations management include:\n- Capacity management\n- Data backup\n- Access log management\n- OT Change management\n- OT Patch management\n- System acquisition and development\n- OT Incident and problem management\n- OT Business continuity plan', 'risk_score': 16, 'risk_impact': 4, 'risk_likelihood': 4, 'risk_level': 3, 'process': [{'id': '163', 'name': 'Sensor (e.g. Flow meters, , Vibration, Termperature, Pressure)', 'description': ''}], 'rootcause': [{'id': '4802', 'name': 'root_cause_2_OG003_lack_of_ot_resource_utilization_monitoring', 'description': ''}], 'process_summary': '', 'rootcause_summary': '', 'risk_desc_summary': ''}
# source_risk
#
#
#
#
#
#
# dict_keys(['risk_data', 'is_central_risk', 'is_source_risk', 'is_high_risk', 'is_shared_root_cause', 'is_news_trended', 'is_emerging_risk'])
# {'id': '794', 'label': 'Inadequate Management of OT Third-party', 'risk': 'Inadequate Management of OT Third-party', 'risk_id': '794', 'risk_cat': 'Operational Risk', 'risk_desc': "This risk refers to situation where third-party vendors or service providers for various aspects of organizational OT infrastructure and OT operations (such as cloud hosting, software development and managed services) cause the disruption or negative impact on an organization's OT operations.", 'risk_score': 20, 'risk_impact': 5, 'risk_likelihood': 4, 'risk_level': 4, 'process': [{'id': '161', 'name': 'SCADA Systems (Supervisory Control and Data Acquisition)', 'description': ''}], 'rootcause': [{'id': '4798', 'name': 'root_cause_2_OG002_improper_system/application/device_access_controls', 'description': ''}], 'process_summary': '', 'rootcause_summary': '', 'risk_desc_summary': ''}
# source_risk
#
#
#
#
#
#
# dict_keys(['risk_data', 'is_central_risk', 'is_source_risk', 'is_high_risk', 'is_shared_root_cause', 'is_news_trended', 'is_emerging_risk'])
# {'id': '793', 'label': 'Inadequate OT Governance', 'risk': 'Inadequate OT Governance', 'risk_id': '793', 'risk_cat': 'Operational Risk', 'risk_desc': "This risk refers to situation where the activities related to governance of OT are not performed properly resulting in inconsistency with business objectives. Examples areas of OT governance include:\n- OT related committee's roles and responsibilities\n- OT organization structure\n- OT staff management\n- OT risk awareness\n- OT risk governance related policies", 'risk_score': 16, 'risk_impact': 4, 'risk_likelihood': 4, 'risk_level': 3, 'process': [{'id': '160', 'name': 'Programmable Logic Controller (PLC)', 'description': ''}], 'rootcause': [{'id': '4792', 'name': 'root_cause_2_OG001_lack_of_established_ot_committees', 'description': ''}], 'process_summary': '', 'rootcause_summary': '', 'risk_desc_summary': ''}
#
# central_risk

# %%
import pickle
import sys

sys.path.append(
    "/home/thanatorn/coding/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/network_analyzer/data_processor"
)
from create_graph_data_library import (
    GraphDataLibrary,
    RiskDataWithEmbedding,
    RiskData,
    EdgeData,
    CompanyGraphData,
    RiskOverlayData,
    RiskDataNoEmbedding,
    RiskDataWithOutEmbedding,
    EdgeDataNoEmbedding,
    CompanyGraphDataNoEmbedding,
    RiskOverlayDataNoEmbedding,
    GraphDataLibraryNoEmbedding,
)

graph_data_library_path: GraphDataLibrary = (
    "/home/thanatorn/coding/cro_rmi_improvement_feature/src/cro_rmi_improvement_feature/network_analyzer/data/graph/graph_data_library.pkl"
)

with open(graph_data_library_path, "rb") as f:
    graph_data_library = pickle.load(f)

company_list = list(graph_data_library.company_graph_datas.keys())
company_list
# Out:
# env_path: /home/thanatorn/coding/cro_rmi_improvement_feature/.env
# /home/thanatorn/coding/cro_rmi_improvement_feature/.venv/lib/python3.12/site-packages/pydantic/_internal/_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)
# ['PCG|embedding_raw_user_data|oneway_run',
#  'PCG|embedding_risk_desc_catalog|oneway_run',
#  'PCG|embedding_summary_user_data|oneway_run',
#  'PCG|embedding_raw_user_data|twoway_run',
#  'PCG|embedding_risk_desc_catalog|twoway_run',
#  'PCG|embedding_summary_user_data|twoway_run',
#  'lotus_south|embedding_raw_user_data|oneway_run',
#  'lotus_south|embedding_risk_desc_catalog|oneway_run',
#  'lotus_south|embedding_summary_user_data|oneway_run',
#  'lotus_south|embedding_raw_user_data|twoway_run',
#  'lotus_south|embedding_risk_desc_catalog|twoway_run',
#  'lotus_south|embedding_summary_user_data|twoway_run',
#  '353|embedding_raw_user_data|oneway_run',
#  '1|embedding_raw_user_data|oneway_run',
#  '353|embedding_risk_desc_catalog|oneway_run']

# %%
company_graph_data_353 = graph_data_library.company_graph_datas[
    "353|embedding_risk_desc_catalog|oneway_run"
]
nodes = company_graph_data_353.nodes
edges = company_graph_data_353.edges
len(nodes), len(edges)
# Out:
# (8, 28)

# %%
from collections import Counter

counter_interdependency_type = Counter()
for edge in edges:
    interdependency_type = edge.interdependency_type
    type_interdependency_type = type(interdependency_type)
    counter_interdependency_type[type_interdependency_type] += 1
counter_interdependency_type
# Out:
# Counter({str: 16, NoneType: 12})
