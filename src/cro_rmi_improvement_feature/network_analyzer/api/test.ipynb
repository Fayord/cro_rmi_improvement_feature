# %%
import requests

url = "http://0.0.0.0:7800/rmi_graph_based_recommendation/recommend_risk_to_assess"
# url = (
#     "http://172.16.100.50:7900/rmi_graph_based_recommendation/recommend_risk_to_assess"
# )
data = {
    "id": "PCG|embedding_summary_user_data|oneway_run",
    # "id": "test",
    "data_level": "user",
    "year_quarter": "2024-Q1",
    "existing_risks": [
        {
            "risk_id": "risk_001",
            "user_id": "user_001",
            "company_id": "company_001",
            "country": "country_001",
            "risk_name": "Supply Chain Disruption",
            "risk_description": "Risk of disruption in supply chain operations",
            "processes": [
                {
                    "id": "1",
                    "name": "Procurement",
                    "description": "Vendor selection and management process",
                }
            ],
            "root_causes": [
                {
                    "id": "1",
                    "name": "Single source dependency",
                    "description": "Over-reliance on single supplier",
                }
            ],
            "risk_category": "operational",
            "score": {
                "impact": 4,
                "likelihood": 3,
                "score": 12,
                "risk_level": 3,
            },
        }
    ],
}

response = requests.post(url, json=data)
response.status_code
# Out:
# 200

# %%
result = response.json()
recommendations = result["recommendations"]
print(len(recommendations))
for recommendation in recommendations:
    print(recommendation.keys())
    print(recommendation["risk"])
    print()
# Out:
# 10
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Supply shortage
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Poor supply quality
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Unable to deliver product
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk caused by Cyber Supply Chain Attack
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Fluctuation in raw material products
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Inadequate Management of Third-party
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Low bargaining power with suppliers
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Inadequate Management of OT Third-party
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Outsourcing inefficiency
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Understocking inventory

# %%
import json

data_path = "example_request.json"
with open(data_path, "r") as f:
    data = json.load(f)

data.keys()
# Out:
# dict_keys(['id', 'data_level', 'year_quarter', 'existing_risks'])

# %%
import requests

url = "http://0.0.0.0:7800/rmi_graph_based_recommendation/recommend_risk_to_assess"
# url = (
#     "http://172.16.100.50:7900/rmi_graph_based_recommendation/recommend_risk_to_assess"
# )
response = requests.post(url, json=data)
total_time = response.elapsed.total_seconds()
response.status_code
print(f"Total time: {total_time} seconds")
print(f"Status code: {response.status_code}")

# %%
result = response.json()
recommendations = result["recommendations"]
print(len(recommendations))
for recommendation in recommendations:
    print(recommendation.keys())
    print(recommendation["risk"])
    print()
# Out:
# 46
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Ineffective IT Operations Management
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# OT Hardware Failure
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Non-compliance with laws/regulations related to OT
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk caused by Insecure Remote Access to OT environment
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# OT Software Failure
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk to OT systems caused by Misconfiguration
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Operational inefficiency
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Poor supply quality
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Supply shortage
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Unable to deliver product
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Poor service quality
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Outsourcing inefficiency
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Poor product quality
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Fluctuation in raw material products
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Losing key distributor/dealer
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Non-compliance with laws/regulations related to IT
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Non-compliance - cybersecurity, information mgmt.
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Non-compliance - PDPA
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Non-compliance - intellectual property, trade secret
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Non-compliance with laws/regulations related to OT
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Non-compliance - anittrust, anticompetition
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Compliance & Regulatory Breaches
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Non-compliance - capital market
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# OT Software Failure
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Hardware Failure
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Facility infrastructure failure and damage
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# OT Hardware Failure
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Operational inefficiency
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Machinery / equipment failure and damage
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Ineffective IT Operations Management
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Environmental Threats at IT Facility
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk caused by Misconfiguration
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Inadequate Management of Third-party
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk caused by Insecure Remote Access to OT environment
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk associated with Denial of Control
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk to OT systems caused by Cyber Supply Chain Attack
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk associated with Manipulation of Control
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk to OT systems caused by Insider Threat
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# OT Software Failure
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Non-compliance with laws/regulations related to OT
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Inadequate IT Governance
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk associated with Manipulation of Control
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# OT Software Failure
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk to OT systems caused by Misconfiguration
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# OT Hardware Failure
#
# dict_keys(['id', 'label', 'risk', 'risk_cat', 'risk_desc', 'risk_score', 'risk_impact', 'risk_likelihood', 'risk_level', 'process', 'rootcause', 'process_summary', 'rootcause_summary', 'risk_desc_summary'])
# Risk caused by Insecure Remote Access to OT environment
